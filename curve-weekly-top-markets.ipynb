# %% [markdown]
# # Curve Weekly Opportunities & Metrics HTML Generator Notebook

# %% [markdown]
# ## Imports and Constants

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import requests
import time
from datetime import datetime, timedelta
import pytz
from IPython.display import HTML
import random

# %%
POOL_TYPES = {
    'factory-twocrypto': 'cryptoswap',
    'factory-crvusd': 'stableswap',
    'factory-eywa': 'stableswap',
    'factory-stable-ng': 'stableswap', 
    'main': 'stableswap', 
    'factory': 'stableswap', 
    'factory-crypto': 'cryptoswap', 
    'crypto': 'cryptoswap', 
    'factory-tricrypto': 'cryptoswap',
}

POOL_TYPES_ASSETS = {
    'usd': ['usdc', 'usdt', 'usdm', 'crvusd', 'dola', 'dai', 'sdai', 'sdola', 'money', 'usds', 'susds', 'frax', 'lusd', 'susde', 'usde', 'gho', 'mim', 'susd', 'dyad', 's3CRV_e', 'sUSDC_m', 'scrvusd'],
    'btc': ['wbtc', 'renbtc', 'sbtc', 'hbtc', 'tbtc', 'obtc', 'pbtc', 'ibtc', 'bbtc', 'dbtc', 'ebtc', 'fbtc', 'gbtc', 'hbtc', 'jbtc', 'kbtc', 'lbtc', 'mbtc', 'nbtc', 'obtc', 'pbtc', 'qbtc', 'rbtc', 'sbtc', 'tbtc', 'ubtc', 'vbtc', 'wbtc', 'xbtc', 'ybtc', 'zbtc', 'abtc', 'bbtc', 'cbtc', 'dbtc', 'ebtc', 'fbtc', 'gbtc', 'hbtc', 'ibtc', 'jbtc', 'kbtc', 'lbtc', 'mbtc', 'nbtc', 'obtc', 'pbtc', 'qbtc', 'rbtc', 'sbtc', 'tbtc', 'ubtc', 'vbtc', 'wbtc', 'xbtc', 'ybtc', 'zbtc', 'abtc', 'bbtc', 'cbtc', 'dbtc', 'ebtc', 'fbtc', 'gbtc', 'hbtc', 'ibtc', 'jbtc', 'kbtc', 'lbtc', 'mbtc', 'nbtc', 'obtc', 'pbtc', 'qbtc', 'rbtc', 'sbtc', 'tbtc', 'ubtc', 'vbtc', 'wbtc', 'xbtc', 'ybtc', 'zbtc', 'abtc', 'bbtc', 'cbtc', 'dbtc', 'ebtc', 'fbtc', 'gbtc', 'hbtc', 'ibtc', 'jbtc', 'kbtc', 'lbtc', 'mbtc', 'nbtc', 'obtc', 'pbtc', 'qbtc', 'rbtc', 'sbtc', 'tbtc', 'ubtc', 'vbtc', 'wbtc', 'xbtc', 'ybtc', 'zbtc', 'abtc', 'bbtc', 'cbtc', 'dbtc', 'ebtc', 'fbtc', 'gbtc', 'hbtc', 'ibtc', 'jbtc', 'kbtc', 'lbtc', 'mbtc', 'nbtc', 'obtc', 'pbtc', 'qbtc', 's2BTC_e'],
    'crv': ['crv', 'sdcrv', 'asdcrv'],
    'eth': ['eth', 'weth', 'steth', 'frxeth', 'wsteth', 'seth', 'aleth', 'reth', 'oeth', 'sWETH_e'],
    'eur': ['eura', 'eurt', 'eurs', 'eurc', 'eure', 'ceur', 'seur']
}

POOL_TYPES_ASSET_DICT = {
    asset.lower(): pool_type 
    for pool_type, assets in POOL_TYPES_ASSETS.items() 
    for asset in assets
}

# Extra broken pools I hide
MY_HIDDEN_POOLS_FILTER = {
    '0x833e4b9740B4C73cC4870D28492A296d005E2895': 'polygon',
    '0xF1005aC82E89dE676449525c3Cb86959216864C1': 'ethereum',
    '0x29a3d66b30bc4ad674a4fdaf27578b64f6afbfe7': 'optimism',
    '0xdadd23929ca8efcbc43aaf8f677d426563cc40d7': 'arbitrum',
    '0x004C167d27ADa24305b76D80762997Fa6EB8d9B2': 'ethereum',
}

CRVUSD_MARKET_LINKS = {
    'all': {'link': 'https://crvusd.curve.fi/#/ethereum/markets', 'name': 'All'},
    '0x8472A9A7632b173c8Cf3a86D3afec50c35548e76': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/sfrxeth/create', 'name': 'sfrxETH (old)'},
    '0xEC0820EfafC41D8943EE8dE495fC9Ba8495B15cf': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/sfrxeth2/create', 'name': 'sfrxETH'},
    '0x100dAa78fC509Db39Ef7D04DE0c1ABD299f4C6CE': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/wsteth/create', 'name': 'wstETH'},
    '0x4e59541306910aD6dC1daC0AC9dFB29bD9F15c67': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/wbtc/create', 'name': 'WBTC'},
    '0xA920De414eA4Ab66b97dA1bFE9e6EcA7d4219635': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/weth/create', 'name': 'WETH'},
    '0x1C91da0223c763d2e0173243eAdaA0A2ea47E704': {'link': 'https://crvusd.curve.fi/#/ethereum/markets/tbtc/create', 'name': 'tBTC'},
}

CRVUSD_ADDR_LIST = {
    'scrvUSD': '0x0655977FEb2f289A4aB78af67BAB0d17aAb84367',
    'crvUSD': '0xf939E0A03FB07F59A73314E73794Be0E57ac1b4E',
}

# %%
HTML_STYLING = f"""<style>

.negative-change {{
  color: red;
}}

.metric-table td:first-child {{
    background-color: #F7F7F7;
}}

.chain-column td:first-child {{
    width: 50px;
}}

.crvusd-metric-column td:first-child {{
    min-width: 250px;
}}

.pool-column td:nth-child(2) {{
    min-width: 150px;
}}
  
.gh-content table.curve-table {{
    width: 100% !important;
    max-width: 100% !important;
    margin: 0 auto !important;
    display: table !important;
}}
  
.curve-table-container {{
    position: relative !important;
    width: 100% !important;
    overflow-x: auto !important;
    -webkit-overflow-scrolling: touch !important;
    margin-bottom: 1rem !important;
}}

.curve-table {{
    border-collapse: collapse !important;
    width: 100% !important;
    max-width: 100% !important;
    margin-left: auto !important;
    margin-right: auto !important;
    vertical-align: middle;
}}

.gh-content.gh-canvas {{
  scrollbar-width: none; /* Firefox */
  -ms-overflow-style: none; /* IE and Edge */
}}

.gh-content.gh-canvas::-webkit-scrollbar {{
  display: none; /* WebKit (Chrome/Safari) */
}}

.curve-table .network-cell {{
  display: flex;
  align-items: center;
  gap: 8px;
  width: fit-content;
  margin: 0 auto;
  vertical-align: middle;
}}

.curve-table .metrics-name-cell {{
  display: flex;
  align-items: left;
  gap: 8px;
  width: fit-content;
  vertical-align: middle;
}}

.curve-table .network-icon {{
  width: 24px;
  height: 24px;
  flex-shrink: 0;
}}

.curve-table .pool-link {{
  text-decoration: none !important;
  color: inherit;
  display: block;
  width: 100%;
  vertical-align: middle;
}}

.curve-table .pool-content {{
  display: flex;
  flex-wrap: wrap;
  gap: 8px;
  width: fit-content;
  max-width: 100%;
  vertical-align: middle;
}}

.curve-table .token-pill-pool {{
  background-color: #EEECEB;
}}

.curve-table .token-pill-borrow {{
  background-color: #BBEDC0;
  
}}

.curve-table .token-pill-collateral {{
  background-color: #DEDBD8;
}}

.token-pill-pool, .token-pill.collateral, .token-pill-borrow{{
  font-weight: bold !important;
  display: inline-flex;
  flex: 0 0 auto;
  align-items: center;
  gap: 4px;
  width: fit-content;
  white-space: nowrap;
  text-decoration: none !important;
  padding: 4px 8px;
  border-radius: 99999px;
}}

.token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{{
  background-color: #DEDBD8 !important;
  font-weight: bold !important;
  
}}

.curve-table .token-icon {{
  width: 24px;
  height: 24px;
  border-radius: 50%;
  flex-shrink: 0;
}}

/* Scope the th and td styles to our specific table */
.curve-table th,
.curve-table td {{
  text-align: left;
  padding: 8px;
  border: 1px solid #e0e0e0;
  vertical-align: middle;
}}

a{{
  text-decoration: none;
}}

a:hover{{
}}

thead{{
  background-color: #DEDBD8 !important;
  text-align: left;
  font-weight: bold !important;
}}

th{{
  background-color: #DEDBD8 !important; 
}}

tr th:last-child{{
  text-align: right !important;
}}

tr td:first-child{{
  font-weight: bold;
}}
tr td:last-child{{
  font-weight: bold;
  text-align: right !important;
}}

.curve-table th {{
  font-weight: bold;
  background-color: #f6f6f6;
}}


.curve-table td a {{
    text-decoration: none !important;
    color: inherit !important;
}}

.curve-table td a:hover {{
     color: #1F1E1B !important;
}}
  
.curve-table td .pool-content {{
  width: fit-content !important;
  display: flex !important;
  vertical-align: middle;
}}

.curve-table td .token-pill-pool {{
  width: fit-content !important;
  flex: 0 0 auto !important;
  vertical-align: middle;
}}

.curve-table td .token-pill-borrow {{
  width: fit-content !important;
  flex: 0 0 auto !important;
  vertical-align: middle;
}}

.curve-table td .token-pill-collateral {{
  width: fit-content !important;
  flex: 0 0 auto !important;
  vertical-align: middle;
}}
</style>"""

# %% [markdown]
# # Function Declarations

# %% [markdown]
# ### Misc

# %%
def epoch_time_formatter(str_time):
    try:
        dt = datetime.strptime(str_time, '%Y-%m-%dT%H:%M:%S')
    except:
        dt = datetime.strptime(str_time, '%Y-%m-%dT%H:%M:%S.%f')
    return int(dt.timestamp())


def get_cur_time():
    return int(time.time())


def url_exists(url):
    try:
        response = requests.head(url, timeout=5)
        return response.status_code == 200
    except requests.RequestException:
        return False


def format_number(x, sig_figures=4, max_decimals=2, use_suffixes=True):
    if not use_suffixes:
        # Original formatting logic
        sig_fig_str = f'{x:,.{sig_figures}g}'
        num = float(sig_fig_str.replace(',', ''))
        formatted = f'{num:,.{max_decimals}f}'
        if '.' in formatted:
            formatted = formatted.rstrip('0').rstrip('.')
        return formatted
    
    # Define suffix thresholds
    suffixes = [
        (1e9, 'B'),  # billion
        (1e6, 'M'),  # million
        (1e3, 'k'),  # thousand
        (1, '')      # default - no suffix
    ]
    
    # Find appropriate suffix
    for threshold, suffix in suffixes:
        if abs(x) >= threshold:
            # Scale the number down
            scaled_num = x / threshold
            # Format with sig figures
            sig_fig_str = f'{scaled_num:.{sig_figures}g}'
            num = float(sig_fig_str)
            # Format with max decimals
            formatted = f'{num:.{max_decimals}f}'
            # Strip unnecessary zeros and decimal point
            if '.' in formatted:
                formatted = formatted.rstrip('0').rstrip('.')
            return f'{formatted}{suffix}'
    
    # For numbers less than 1
    sig_fig_str = f'{x:.{sig_figures}g}'
    num = float(sig_fig_str)
    formatted = f'{num:.{max_decimals}f}'
    if '.' in formatted:
        formatted = formatted.rstrip('0').rstrip('.')
    return formatted

# %% [markdown]
# ### Curve Prices API

# %%
def prices_api_request(method):
    base_url = "https://prices.curve.fi"
    url = base_url + method
    response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Failed to retrieve data. Status code: {response.status_code}")
    

def get_all_chains():
    data = prices_api_request("/v1/chains/")
    chains = []
    for item in data['data']:
        chains.append(item["name"])
    return chains


def get_chain_tx_count(start, end):
    url = f"/v1/chains/activity/transactions?start={start-(end-start)}&end={end}"
    data = prices_api_request(url)
    tx_counts = {'all': {}}

    # go through each chain in the data set
    for raw_chain in data['data']:
        tx_counts[raw_chain['chain']] = {}
        chain_data = tx_counts[raw_chain['chain']]
        for raw_day in raw_chain['transactions']:
            app_type = raw_day['type']
            ts = epoch_time_formatter(raw_day['timestamp'])
            if app_type not in chain_data:
                chain_data[app_type] = {'cur_week': [], 'prev_week': [], 'cur_week_total': 0, 'prev_week_total': 0}
            if end-ts > 86400 and ts >= start-86400:
                chain_data[app_type]['cur_week'].append(raw_day['transactions'])
                chain_data[app_type]['cur_week_total'] += raw_day['transactions']
            elif start-ts > 86400 and ts >= (start-(end-start))-86400:
                chain_data[app_type]['prev_week'].append(raw_day['transactions'])
                chain_data[app_type]['prev_week_total'] += raw_day['transactions']
        for app_type in chain_data:
            if app_type not in tx_counts['all']:
                tx_counts['all'][app_type] = {
                    'cur_week_total': chain_data[app_type]['cur_week_total'], 
                    'prev_week_total': chain_data[app_type]['prev_week_total']
                }
            else:
                tx_counts['all'][app_type]['cur_week_total'] += chain_data[app_type]['cur_week_total']
                tx_counts['all'][app_type]['prev_week_total'] += chain_data[app_type]['prev_week_total']
    return tx_counts


def get_chain_user_stats(start, end):
    url = f"/v1/chains/activity/users?start={start-(end-start)}&end={end}"
    data = prices_api_request(url)
    user_stats = {}

    # go through each chain in the data set
    for raw_chain in data['data']:
        user_stats[raw_chain['chain']] = {}
        chain_data = user_stats[raw_chain['chain']]
        for raw_day in raw_chain['users']:
            user_type = raw_day['type']
            ts = epoch_time_formatter(raw_day['timestamp'])
            if user_type not in chain_data:
                chain_data[user_type] = {'cur_week': [], 'prev_week': []}
            if end-ts > 86400 and ts >= start-86400:
                chain_data[user_type]['cur_week'].append(raw_day['users'])
            elif start-ts > 86400 and ts >= (start-(end-start))-86400:
                chain_data[user_type]['prev_week'].append(raw_day['users'])

    return user_stats


def get_chain_pools(chain):
    chain_pools = {}
    url = f"/v1/chains/{chain}"
    data = prices_api_request(url)

    chain_pools['tvl'] = data['total']['total_tvl']

    chain_pools['contracts'] = {}
    for contract in data['data']:
        address = contract['address']

        chain_pools['contracts'][address] = { \
            'name': contract['name'], \
            'address': address, \
            'tvl_usd': contract['tvl_usd'], \
            'base_weekly_apr': contract['base_weekly_apr'], \
            'coins': contract['coins'], \
            'type': 'pool' \
        }
    
    return chain_pools


def get_all_chain_pools(chains):
    all_pools = {}
    for chain in chains:
        all_pools[chain] = get_chain_pools(chain)
    
    return all_pools


def get_chain_lending_markets(chain):
    chain_lending_markets = {}
    url = f"/v1/lending/markets/{chain}"
    data = prices_api_request(url)
    
    if data['count'] == 0:
        return None

    chain_lending_markets['contracts'] = {}
    for contract in data['data']:
        controller = contract['controller']

        if contract['total_debt_usd'] == 0:
            utilization = 0
        else:
            utilization = float(contract['total_debt_usd']) / contract['total_assets_usd']

        available_assets = contract['total_assets'] * (1 - utilization)
        available_assets_usd = contract['total_assets_usd'] - contract['total_debt_usd']

        chain_lending_markets['contracts'][controller] = { \
            'name': contract['name'], \
            'controller': controller, \
            'vault': contract['vault'], \
            'llamma': contract['llamma'], \
            'policy': contract['policy'], \
            'oracle': contract['oracle'], \
            'oracle_pools': contract['oracle_pools'], \
            'rate': contract['rate'], \
            'borrow_apy': contract['borrow_apy'], \
            'lend_apy': contract['lend_apy'], \
            'n_loans': contract['n_loans'], \
            'total_assets': contract['total_assets'], \
            'total_assets_usd': contract['total_assets_usd'], \
            'collateral_balance': contract['collateral_balance'], \
            'collateral_balance_usd': contract['collateral_balance_usd'], \
            'total_debt': contract['total_debt'], \
            'total_debt_usd': contract['total_debt_usd'], \
            'available_assets': available_assets, \
            'available_assets_usd': available_assets_usd, \
            'utilization': utilization, \
            'collateral_token': contract['collateral_token'], \
            'borrowed_token': contract['borrowed_token'], \
            'type'  : 'lending' \
        }
        pass
    
    return chain_lending_markets


def get_all_chain_lending_markets(chains):
    all_chains_lending_markets = {}
    for chain in chains:
        all_chains_lending_markets[chain] = get_chain_lending_markets(chain)
    
    return all_chains_lending_markets


def get_crvusd_markets():
    url = "/v1/crvusd/markets/ethereum"
    data = prices_api_request(url)
    crvusd_markets = {}

    crvusd_markets = {}
    for contract in data['data']:
        address = contract['address']
        crvusd_markets[address] = { \
            'address': address, \
            'llamma': contract['llamma'], \
            'collateral_token': contract['collateral_token'], \
            'stablecoin_token': contract['stablecoin_token'], \
            'type'  : 'crvusd' \
        }
    
    return crvusd_markets


def get_pool_volume(chain, address, start, end):
    prev_start = start - (end - start)
    prev_end = start
    url = f"/v1/volume/usd/{chain}/{address}?interval=day&start={prev_start}&end={end}"
    data = prices_api_request(url)
    volume_usd = 0
    fees_usd = 0
    prev_volume_usd = 0
    prev_fees_usd = 0
    if data['data'] != []:
        for day in data['data']:
            ts = day['timestamp']
            if ts > start-86400 and ts <= end-86400:
                #print(f"Volume Data TS: {datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')} think it's within start and end: {datetime.fromtimestamp(start).strftime('%Y-%m-%d %H:%M:%S')} and {datetime.fromtimestamp(end).strftime('%Y-%m-%d %H:%M:%S')}")
                volume_usd += day['volume']
                fees_usd += day['fees']
            elif ts > (prev_start-86400) and ts <= prev_end-86400:
                #print(f"Volume Data TS: {datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')} think it's within prev start and end: {datetime.fromtimestamp(prev_start).strftime('%Y-%m-%d %H:%M:%S')} and {datetime.fromtimestamp(prev_end).strftime('%Y-%m-%d %H:%M:%S')}")
                prev_volume_usd += day['volume']
                prev_fees_usd += day['fees']
    return volume_usd, fees_usd, prev_volume_usd, prev_fees_usd


def get_tvl_for_period(chain, address, start, end):
    tvl_data = {    
            'tvl': 0,
            'tvl_snapshot': None,
            'token_supply': 0,
            'token_supply_snapshot': None,
            'virtual_price_snapshot': None,
        }

    url = f"/v1/snapshots/{chain}/{address}/tvl?start={start}&end={end}&unit=none"
    data = prices_api_request(url)
    if data['data'] != []:
        for item in data['data']:
            if item['tvl_usd'] != None and tvl_data['tvl_snapshot'] == None:
                tvl_data['tvl'] = item['tvl_usd']
                tvl_data['tvl_snapshot'] = item
            if item['token_supply'] != None and tvl_data['token_supply_snapshot'] == None:
                tvl_data['token_supply'] = item['token_supply']
                tvl_data['token_supply_snapshot'] = item
            if tvl_data['tvl_snapshot'] != None and tvl_data['token_supply_snapshot'] != None:
                break
    
        if tvl_data['tvl_snapshot'] == None and tvl_data['token_supply_snapshot'] != None:
            # couldn't get usd tvl from the snapshot, try getting it from virtual price
            url = f"/v1/snapshots/{chain}/{address}?start={start}&end={end}&unit=none"
            pool_virtual_data = prices_api_request(url)
            for item in pool_virtual_data['data']:
                if item['virtual_price'] != None:
                    tvl_data['tvl'] = tvl_data['token_supply'] * item['virtual_price'] / 10**18
                    tvl_data['virtual_price_snapshot'] = item
                    break
    return tvl_data
    

def get_tvl(chain, address, creationTs, start, end=None):
    tvl_data = {
        'start': None,
        'end': None,
    }

    # get tvl data for the pool
    tvl_data['start'] = get_tvl_for_period(chain, address, creationTs, start)
    if end != None:
        tvl_data['end'] = get_tvl_for_period(chain, address, creationTs, end)
    
    # check if we have tvl data for the pool
    if  tvl_data['start']['tvl_snapshot'] == None and tvl_data['start']['virtual_price_snapshot'] == None:
        if  tvl_data['end']['tvl_snapshot'] == None and tvl_data['end']['virtual_price_snapshot'] == None:
            raise Exception(f"Error: no tvl data found for pool {address} on chain {chain}")
        else:
            print(f"Warning: no tvl data found for pool {address} on chain {chain} for start period {start}, new pool?")

    return tvl_data


def prices_get_lending_snapshots(chain, address, start, end):
    url = f"/v1/lending/markets/{chain}/{address}/snapshots?fetch_on_chain=true&agg=day"
    data = prices_api_request(url)
    prev_snapshot = None
    cur_snapshot = None
    for snapshot in data['data']:
        ts = epoch_time_formatter(snapshot['timestamp'])
        if ts <= start and start - ts < 86400:
            prev_snapshot = snapshot
        elif ts <= end and end - ts < 86400:
            cur_snapshot = snapshot
    return prev_snapshot, cur_snapshot


def aggregate_crvusd_snapshots(base_items, start_index, end_index):
    """
    Aggregate metrics with custom functions for each field over a specified range.
    
    Args:
        items: List of dictionaries containing the metrics
        start_index: Starting index (inclusive)
        end_index: Ending index (inclusive)
    
    Returns:
        Dictionary with aggregated values for each field using appropriate functions
    """
    items = base_items.copy()
    if not items or start_index > end_index or start_index < 0 or end_index >= len(items):
        return None
    
    selected_items = items[start_index:end_index + 1]
    count = len(selected_items)
    
    # Define aggregation functions for each field
    aggregations = {
        'rate': lambda x: sum(item['rate'] for item in x) / count,
        'minted': lambda x: max(item['minted'] for item in x) / count,
        'redeemed': lambda x: max(item['redeemed'] for item in x) / count,
        'total_collateral': lambda x: sum(item['total_collateral'] for item in x) / count,
        'total_collateral_usd': lambda x: sum(item['total_collateral_usd'] for item in x) / count,
        'total_stablecoin': lambda x: sum(item['total_stablecoin'] for item in x) / count,
        'total_debt': lambda x: sum(item['total_debt'] for item in x) / count,
        'n_loans': lambda x: max(item['n_loans'] for item in x),  # Maximum
        'amm_price': lambda x: sum(item['amm_price'] for item in x) / count,
        'price_oracle': lambda x: sum(item['price_oracle'] for item in x) / count,
        'base_price': lambda x: sum(item['base_price'] for item in x) / count,
        'min_band': lambda x: min(item['min_band'] for item in x),  # Minimum
        'max_band': lambda x: max(item['max_band'] for item in x),  # Maximum
        'borrowable': lambda x: sum(item['borrowable'] for item in x) / count,
        'loan_discount': lambda x: sum(item['loan_discount'] for item in x) / count,
        'liquidation_discount': lambda x: sum(item['liquidation_discount'] for item in x) / count,
        'sum_debt_squared': lambda x: sum(item['sum_debt_squared'] for item in x) / count
    }
    
    # Calculate aggregations
    result = {}
    for field, agg_func in aggregations.items():
        try:
            result[field] = agg_func(selected_items)
        except (KeyError, TypeError):
            continue  # Skip if field is missing or invalid
    
    # Add the time range for reference
    result['time_range'] = {
        'start': selected_items[0]['dt'],
        'end': selected_items[-1]['dt']
    }
    
    return result


def prices_get_crvusd_market_snapshots(address):
    url = f"/v1/crvusd/markets/ethereum/{address}/snapshots?fetch_on_chain=true&agg=day"
    data = prices_api_request(url)
    cur_snapshot = data['data'][0]
    prev_snapshot = data['data'][7]
    week_snapshot = aggregate_crvusd_snapshots(data['data'], 1, 7)
    prev_week_snapshot = aggregate_crvusd_snapshots(data['data'], 8, 15)
    return [cur_snapshot, week_snapshot, prev_snapshot, prev_week_snapshot]


def prices_get_lending_liquidations(chain, address, start, end):
    prev_start = start - (end - start)
    prev_end = start
    url = f"/v1/lending/liquidations/{chain}/{address}/history/detailed?start={prev_start}&end={end}"
    data = prices_api_request(url)
    liqs = 0
    prev_liqs = 0
    self_liqs = 0
    prev_self_liqs = 0
    for item in data['data']:
        ts = epoch_time_formatter(item['dt'])
        if ts >= start and ts <= end:
            liqs += 1
            if item['self'] == True:
                self_liqs += 1
        elif ts >= prev_start and ts <= prev_end:
            prev_liqs += 1
            if item['self'] == True:
                prev_self_liqs += 1

    return liqs, prev_liqs, self_liqs, prev_self_liqs

# %% [markdown]
# ### Curve Frontend-JS API

# %%
def frontend_api_request(method):
    base_url = "https://api.curve.fi/v1"
    url = base_url + method
    response = requests.get(url)

    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Failed to retrieve data. Status code: {response.status_code}")
    
def get_hidden_pools():
    method = "/getHiddenPools"
    data = frontend_api_request(method)
    hidden_pools = {}
    for chain in data['data']:
        hidden_pools[chain] = {}
        for pool in data['data'][chain]:
            hidden_pools[chain][pool] = True
    for pool in MY_HIDDEN_POOLS_FILTER:
        chain = MY_HIDDEN_POOLS_FILTER[pool]
        if chain not in hidden_pools:
            hidden_pools[chain] = {}
        hidden_pools[chain][pool] = True
    return hidden_pools

def get_all_pools(chains):
    all_pools = []
    for chain in chains:
        for pool_type in POOL_TYPES:
            method = f'/getPools/{chain}/{pool_type}'
            data = frontend_api_request(method)
            for pool in data['data']['poolData']:
                pool['blockchainId'] = chain
                pool['type'] = POOL_TYPES[pool_type]
                pool['registryId'] = pool_type
                all_pools.append(pool)
    return all_pools

def get_all_lending_markets():
    method = '/getLendingVaults/all'
    data = frontend_api_request(method)
    return data['data']['lendingVaultData'], data['data']['tvl']

def get_all_gauges():
    method = '/getAllGauges'
    data = frontend_api_request(method)
    gauge_data = {}
    for gauge in data['data']:
        gauge = data['data'][gauge]
        chain = gauge['blockchainId']
        if chain not in gauge_data:
            gauge_data[chain] = {}
        gauge_data[chain][gauge['gauge']] = gauge
    return gauge_data

test = get_all_gauges()

def get_volumes(chains):
    method = "/getVolumes/"
    volume_data = {}
    for chain in chains:

        chain_data = frontend_api_request(method + chain)
        volume_data[chain] = {}
        for item in chain_data['data']['pools']:
            address = item['address']
            volume_data[chain][address] = item

    return volume_data

# %% [markdown]
# ### HTML Generation

# %%
def make_metric_html(name, value, prevValue, showPercentChange=True, valuePrefix='', valuePostfix='', customValueFormat=None, changeFormatting=",.2f", reversed=False):
    try:
        if reversed == False:
            if showPercentChange:
                if value > prevValue:
                    change = f"""<span class="positive-change">+{format((value - prevValue)/prevValue*100, changeFormatting)}%</span>"""
                else:
                    change = f"""<span class="negative-change">{format((value - prevValue)/prevValue*100, changeFormatting)}%</span>"""
            else:
                if value > prevValue:
                    change = f"""<span class="positive-change">+{valuePrefix}{format(value - prevValue, changeFormatting)}{valuePostfix}</span>"""
                else:
                    change = f"""<span class="negative-change">-{valuePrefix}{format(prevValue - value, changeFormatting)}{valuePostfix}</span>"""
        else:
            if showPercentChange:
                if value > prevValue:
                    change = f"""<span class="negative-change">+{format((value - prevValue)/prevValue*100, changeFormatting)}%</span>"""
                else:
                    change = f"""<span class="positive-change">{format((value - prevValue)/prevValue*100, changeFormatting)}%</span>"""
            else:
                if value > prevValue:
                    change = f"""<span class="negative-change">+{valuePrefix}{format(value - prevValue, changeFormatting)}{valuePostfix}</span>"""
                else:
                    change = f"""<span class="positive-change">-{valuePrefix}{format(prevValue - value, changeFormatting)}{valuePostfix}</span>"""

        if customValueFormat:
            value = customValueFormat
        else:
            value = f"${format_number(value, 4, 3)}"

        return {'Metric': name, 'Value': value, 'Change': change}
    except:
        pass


def make_chain_with_icon_html(chain):
    return f"""<div class="network-cell"><img title={chain.capitalize()} src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/{chain}.png' class="network-icon"></div>"""


def make_name_link_html(name, url=None, img_link=None):
    if img_link:
        return f"""<a href='{url}'><div class="network-cell">{img_link}<span>{name}</span><</div></a>"""
    if url:
        return f"""<a href='{url}'><div class="pool-content">{name}</div></a>"""
    else:
        return f"""<div class="pool-content">{name}</div>"""


def get_coin_image_url(address, chain, url_dict):
    if chain == 'ethereum':
        base_image_url = 'https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/'
    else:
        base_image_url = f'https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets-{chain}/'

    coin_image_url = f'{base_image_url}{address.lower()}.png'
    if (chain in url_dict and address in url_dict[chain] and url_dict[chain][address] != "") or url_exists(coin_image_url):
        if chain not in url_dict:
            url_dict[chain] = {}
        image_link = f"""<img src='{coin_image_url}' class="token-icon">"""
    else:
        image_link = ""
    url_dict[chain][address] = image_link
    return image_link, url_dict


def get_coin_html(coin, chain, url_dict, market_type):
    image_link, url_dict = get_coin_image_url(coin['address'], chain, url_dict)
    coin_pill = f"""<div class="token-pill-{market_type}">{image_link}<span>{coin['symbol']}</span></div>"""
    return coin_pill, url_dict


def df_to_html(df, classes='curve-table'):

    html_str = "<div class='curve-table-container'>"           
    html_str += df.to_html( 
        index=False, 
        classes=classes,
        border=0,
        justify='left',
        escape=False
    )
    html_str += "</div>"
    return html_str


def make_metric_name_with_images(content):
    html_str = f"""<div class="metrics-name-cell">"""
    for item in content:
        if item['type'] == 'img_html':
            html_str += item['content']
        elif item['type'] == 'text':
            html_str += f"""<span>{item['content']}</span>"""
    html_str += "</div>"
    return html_str


def display_curve_table(df_html, html_styling):
    
    # Add necessary classes to the table
    df_html = df_html.replace('<table', '<div class="curve-table-container"><table class="curve-table"')
    df_html = df_html.replace('</table>', '</table></div>')
    
    # Wrap everything in a gh-content container for proper styling
    final_html = f"""
    <div class="gh-content gh-canvas">
        {html_styling}
        {df_html}
    </div>
    """
    
    return HTML(final_html)

# %% [markdown]
# ### Dataframe Processing

# %%
def get_top_yielding_lending_markets(base_df, print_num, minSupplied=0, normalize=True, columns_to_show=['Chain', 'Market', 'Yield']):
    df = base_df.copy()

    if len(df) == 0:
        return pd.DataFrame(columns=columns_to_show)

    if normalize:
        df['yieldMin'] = np.where(df['suppliedUsd'] < minSupplied,
                                df['borrowApy']*(df['borrowedUsd'] / minSupplied) + df['rewardsMinApy']*(df['suppliedUsd'] / minSupplied),
                                df['borrowApy']*(df['borrowedUsd'] / df['suppliedUsd']) + df['rewardsMinApy']
        )

        df['yieldMax'] = np.where(df['suppliedUsd'] < minSupplied,
                                df['borrowApy']*(df['borrowedUsd'] / minSupplied) + df['rewardsMaxApy']*(df['suppliedUsd'] / minSupplied),
                                df['borrowApy']*(df['borrowedUsd'] / df['suppliedUsd']) + df['rewardsMaxApy']
        )
    else:
        df = df[df['suppliedUsd'] >= minSupplied]
        df['yieldMin'] = df['lendApy'] + df['rewardsMinApy']
        df['yieldMax'] = df['lendApy'] + df['rewardsMaxApy']
    
    df = df.sort_values('yieldMin', ascending=False).head(print_num)
    df['yieldStr'] = df['yieldMin'].apply(lambda x: format_number(x)) + '%'

    df = df.rename(columns={'nameLink': 'Market',
                                    'chainWithIcon': 'Chain',
                                    'yieldStr': 'Yield'})  
    
    return df[columns_to_show]


def get_top_pool_yields_pools(base_df, print_num, minTvl=0, normalize=True, asset=None, columns_to_show=['Chain', 'Pool', 'Type', 'Yield']):
    df = base_df.copy()
    if asset:
        df = df[df['assetType'] == asset]
        df['assetType'] = df['assetType'].str.upper()

    if len(df) == 0:
        return pd.DataFrame(columns=columns_to_show)

    if normalize == True:
        df['yieldMin'] = np.where(df['tvlUsd'] < minTvl,
                                df['lstApy'] + (df['tradingApy'] + df['rewardsMinApy']) * (df['tvlUsd'] / (minTvl)),
                                df['lstApy'] + df['tradingApy'] + df['rewardsMinApy'])

        df['yieldMax'] = np.where(df['tvlUsd'] < minTvl,
                                df['lstApy'] + (df['tradingApy'] + df['rewardsMaxApy']) * (df['tvlUsd'] / (minTvl)),
                                df['lstApy'] + df['tradingApy'] + df['rewardsMaxApy'])
        df['tvlUsd'] = np.where(df['tvlUsd'] < minTvl, (minTvl), df['tvlUsd'])
        df['tvlUsd'] = df['tvlUsd'].map('${:,.0f}'.format)
    else:
        df = df[df['tvlUsd'] > minTvl]
        df['yieldMin'] = df['lstApy'] + df['tradingApy'] + df['rewardsMinApy']
        df['yieldMax'] = df['lstApy'] + df['tradingApy'] + df['rewardsMaxApy']
        df['tvlUsd'] = df['tvlUsd'].map('${:,.0f}'.format)

    df = df.sort_values('yieldMin', ascending=False)
    df['yieldStr'] = df['yieldMin'].apply(lambda x: format_number(x)) + '%'
    df = df.rename(columns={'nameLink': 'Pool',
                                    'chainWithIcon': 'Chain',
                                    'tvlUsd': 'TVL',
                                    'yieldStr': 'Yield',
                                    'assetType': 'Type'})  
    
    return df[columns_to_show].head(print_num)


def sort_pool_df_to_html(base_df, item_num, sort_column, columns_to_show, ascending=False):
    df = base_df.copy()
    sorted_df = df.sort_values(sort_column, ascending=ascending).head(item_num)
    sorted_df['liqUtilizationDaily'] = sorted_df['liqUtilizationDaily'].map('{:,.2f}%'.format)
    sorted_df['feesUsd'] = sorted_df['feesUsd'].apply(lambda x: f"${format_number(x, 4, 3)}")
    sorted_df['volumeUsd'] = sorted_df['volumeUsd'].apply(lambda x: f"${format_number(x, 4, 3)}")
    sorted_df['tvlUsd'] = sorted_df['tvlUsd'].apply(lambda x: f"${format_number(x, 4, 3)}")
    sorted_df['baseWeeklyApy'] = sorted_df['baseWeeklyApy'].map('{:,.2f}%'.format)
    column_name_list = {'nameLink': 'Pool',
                                'chainWithIcon': 'Chain',
                                'tvlUsd': 'TVL',
                                'yieldStr': 'Yield',
                                'assetType': 'Type',
                                'volumeUsd': 'Volume',
                                'feesUsd': 'Fees',}
    sorted_df = sorted_df.rename(columns=column_name_list)
    renamed_column_list = [column_name_list[column] for column in columns_to_show]

    return df_to_html(sorted_df[renamed_column_list], classes='curve-table chain-column pool-column')

# %% [markdown]
# # Data Collection

# %% [markdown]
# ### Get Times

# %%
# Get the times required for the weekly thursday - thursday period
now = datetime.now(pytz.utc)
recent_thursday = now - timedelta(days=(now.weekday() + 4) % 7, hours=now.hour, minutes=now.minute, seconds=now.second, microseconds=now.microsecond)
previous_thursday = recent_thursday - timedelta(days=7)
epoch_start = int(previous_thursday.timestamp())
epoch_end = int(recent_thursday.timestamp())

# %% [markdown]
# ### Load asset image dictionary (if available)

# %%
try:
    with open('curve-assets-image-html.dict', 'r') as file:
        coin_image_html_dict = literal_eval(file.read())
except FileNotFoundError:
    print("curve-assets-image-html.dict not found, this run will generate this file, but will take a little longer to run.")
    coin_image_html_dict = {}

# %% [markdown]
# ### Get Basic Data from Curve Prices API

# %%
chains = get_all_chains()
prices_chain_transactions = get_chain_tx_count(epoch_start, epoch_end)
prices_chain_users = get_chain_user_stats(epoch_start, epoch_end)
prices_pools = get_all_chain_pools(chains)
prices_lending_markets = get_all_chain_lending_markets(chains)
prices_crvusd_markets = get_crvusd_markets()

# %% [markdown]
# ### Get Basic Data From Curve Frontend-JS API

# %%
hidden_pools = get_hidden_pools()
fe_pool_data_raw = get_all_pools(chains)
volume_data = get_volumes(chains)
fe_lending_data_raw, lending_tvl = get_all_lending_markets()
fe_gauge_data = get_all_gauges()

# %% [markdown]
# # Specific Market Data Acquisition & Processing

# %% [markdown]
# ## Lending Markets

# %%
# Processes lending market data and grabs historical data, takes around 1-3mins to run

fe_lending_data = fe_lending_data_raw.copy()
kill_flag = False


market_num = 0
for market in fe_lending_data:

    if kill_flag:
        break
    market_num += 1
    print(f"Processing market {market_num} of {len(fe_lending_data)}")

    chain = market['blockchainId']
    address = market['address']
    gauge = None

    if 'gaugeAddress' in market and market['gaugeAddress'] in fe_gauge_data:
        gauge = fe_gauge_data[market['gaugeAddress']]

    # make hyperlink for market
    coin_collateral, coin_image_html_dict = get_coin_html(market['assets']['collateral'], chain, coin_image_html_dict, 'pool')
    coin_borrow, coin_image_html_dict = get_coin_html(market['assets']['borrowed'], chain, coin_image_html_dict, 'borrow')
    market_str = f"""{coin_borrow}{coin_collateral}"""
    try: 
        market['nameLink'] = make_name_link_html(market_str, market['lendingVaultUrls']['deposit'])
    except:
        market['nameLink'] = make_name_link_html(market_str)

    # make network with icon
    market['chainWithIcon'] = make_chain_with_icon_html(chain)

    # get historical data for each market
    try:
        prev_snapshot, cur_snapshot = prices_get_lending_snapshots(chain, market['controllerAddress'], epoch_start, epoch_end)
        market['liqs'], market['prev_liqs'], market['self_liqs'], market['prev_self_liqs'] = prices_get_lending_liquidations(chain, market['controllerAddress'], epoch_start, epoch_end)
        market['prevUtilization'] = 0
        if prev_snapshot['total_debt_usd'] != 0 and prev_snapshot['total_assets_usd'] != 0:
            market['prevUtilization'] = prev_snapshot['total_debt_usd'] / prev_snapshot['total_assets_usd'] * 100
        
        market['prevBorrowApy'] = prev_snapshot['borrow_apy']
        market['prevLendApy'] = prev_snapshot['lend_apy']
        market['prevBorrowedUsd'] = prev_snapshot['total_debt_usd']
        market['prevSuppliedUsd'] = prev_snapshot['total_assets_usd']
        market['prevCollateralUsd'] = prev_snapshot['collateral_balance_usd']
        market['prevTvlUsd'] = prev_snapshot['total_assets_usd'] - prev_snapshot['total_debt_usd'] + prev_snapshot['collateral_balance_usd']
        market['prevNumLoans'] = prev_snapshot['n_loans']
        market['numLoans'] = cur_snapshot['n_loans']
        market['prevSnapshot'] = prev_snapshot
        market['curSnapshot'] = cur_snapshot
    except:
        market['prevUtilization'] = 0
        market['prevBorrowApy'] = 0
        market['prevLendApy'] = 0
        market['prevBorrowedUsd'] = 0
        market['prevSuppliedUsd'] = 0
        market['prevSnapshot'] = None
        market['tvlUsd'] = 0
        market['prevCollateralUsd'] = 0
        market['prevTvlUsd'] = 0

    # Make various stats for the market
    market['utilization'] = 0
    if market['borrowed']['usdTotal'] != 0 and market['totalSupplied']['usdTotal'] != 0:
        market['utilization'] = market['borrowed']['usdTotal'] / market['totalSupplied']['usdTotal'] * 100
    
    market['borrowApy'] = market['rates']['borrowApyPcent']
    market['lendApy'] = market['rates']['lendApyPcent']
    market['borrowedUsd'] = market['borrowed']['usdTotal']
    market['suppliedUsd'] = market['totalSupplied']['usdTotal']
    if 'ammBalances' in market \
            and 'ammBalanceCollateralUsd' in market['ammBalances'] \
            and 'ammBalanceBorrowedUsd' in market['ammBalances'] \
            and market['ammBalances']['ammBalanceBorrowedUsd'] != None \
            and market['ammBalances']['ammBalanceCollateralUsd'] != None:
        market['collateralUsd'] = market['ammBalances']['ammBalanceBorrowedUsd'] + market['ammBalances']['ammBalanceCollateralUsd']
    else:
        market['collateralUsd'] = 0
    market['tvlUsd'] = market['suppliedUsd'] - market['borrowedUsd'] + market['collateralUsd']

    # Make rewards APYs for the market
    market['rewardsMinApy'] = 0
    market['rewardsMaxApy'] = 0
    if gauge != None and 'gaugeCrvApy' in gauge and gauge['gaugeCrvApy'] != [] and gauge['gaugeCrvApy'] != [None, None]:
        market['rewardsMinApy'] += gauge['gaugeCrvApy'][0]
        market['rewardsMaxApy'] += gauge['gaugeCrvApy'][1]

    if 'gaugeRewards' in market and market['gaugeRewards'] != []:
        for reward in market['gaugeRewards']:
            market['rewardsMinApy'] += reward['apy']
            market['rewardsMaxApy'] += reward['apy']
# Out:
# Processing market 1 of 59
# Processing market 2 of 59
# Processing market 3 of 59
# Processing market 4 of 59
# Processing market 5 of 59
# Processing market 6 of 59
# Processing market 7 of 59
# Processing market 8 of 59
# Processing market 9 of 59
# Processing market 10 of 59
# Processing market 11 of 59
# Processing market 12 of 59
# Processing market 13 of 59
# Processing market 14 of 59
# Processing market 15 of 59
# Processing market 16 of 59
# Processing market 17 of 59
# Processing market 18 of 59
# Processing market 19 of 59
# Processing market 20 of 59
# Processing market 21 of 59
# Processing market 22 of 59
# Processing market 23 of 59
# Processing market 24 of 59
# Processing market 25 of 59
# Processing market 26 of 59
# Processing market 27 of 59
# Processing market 28 of 59
# Processing market 29 of 59
# Processing market 30 of 59
# Processing market 31 of 59
# Processing market 32 of 59
# Processing market 33 of 59
# Processing market 34 of 59
# Processing market 35 of 59
# Processing market 36 of 59
# Processing market 37 of 59
# Processing market 38 of 59
# Processing market 39 of 59
# Processing market 40 of 59
# Processing market 41 of 59
# Processing market 42 of 59
# Processing market 43 of 59
# Processing market 44 of 59
# Processing market 45 of 59
# Processing market 46 of 59
# Processing market 47 of 59
# Processing market 48 of 59
# Processing market 49 of 59
# Processing market 50 of 59
# Processing market 51 of 59
# Processing market 52 of 59
# Processing market 53 of 59
# Processing market 54 of 59
# Processing market 55 of 59
# Processing market 56 of 59
# Processing market 57 of 59
# Processing market 58 of 59
# Processing market 59 of 59

# %%
lending_df = pd.DataFrame(fe_lending_data)

# Not currently using top lending market yields in report
lending_top_yields_df = get_top_yielding_lending_markets(lending_df, 5, 10000, normalize=True)

# Make the metrics for the lending markets
metrics_list = []

metrics_list.append(make_metric_html('Lending TVL', lending_df['tvlUsd'].sum(), lending_df['prevTvlUsd'].sum()))
metrics_list.append(make_metric_html('Supplied', lending_df['suppliedUsd'].sum(), lending_df['prevSuppliedUsd'].sum()))
metrics_list.append(make_metric_html('Borrowed', lending_df['borrowedUsd'].sum(), lending_df['prevBorrowedUsd'].sum()))
metrics_list.append(make_metric_html('Collateral', lending_df['collateralUsd'].sum(), lending_df['prevCollateralUsd'].sum()))
metrics_list.append(make_metric_html(
        'Loans', 
        int((lending_df['numLoans']).sum()), 
        int((lending_df['prevNumLoans']).sum()), 
        showPercentChange=False, 
        changeFormatting=",.0f",
        customValueFormat=str(int((lending_df['numLoans']).sum()))
    ))

lending_metrics_html = df_to_html(pd.DataFrame(metrics_list), classes='curve-table')

# %% [markdown]
# ## Pools

# %% [markdown]
# #### Data Acquisition

# %%
# This has to do a few calls to different APIs for each pool, so it takes a while to run, around 30-90mins
# To speed it up, increase the TVL threshold so it only processes pools with a TVL above that threshold
TVL_THRESHOLD = 100

# %%
fe_pool_data = fe_pool_data_raw.copy()

# shuffle the list so pool estimated time remaining is more accurate
random.shuffle(fe_pool_data)

num_pools = len(fe_pool_data)
i_pool = 0
kill_flag = False
good_pool_data = []
time_start = int(time.time())

for pool in fe_pool_data:
    if kill_flag == True:
        break

    chain = pool['blockchainId']
    address = pool['address']
    i_pool += 1

    time_elapsed = int(time.time()) - time_start
    time_per_item = time_elapsed / i_pool
    est_time_remaining = int((num_pools - i_pool) * time_per_item)

    if (chain in hidden_pools and pool['id'] in hidden_pools[chain]) \
            or (address in MY_HIDDEN_POOLS_FILTER and MY_HIDDEN_POOLS_FILTER[address] == chain) \
            or pool['isBroken'] == True \
            or chain not in volume_data \
            or chain not in chains \
            or pool['usdTotal'] < TVL_THRESHOLD:
        print(f"Skipping pool {pool['name']} ({i_pool}/{num_pools}), {chain}-{address}, TVL: {pool['usdTotal']}, est. time remaining: {est_time_remaining//60}m{est_time_remaining%60}s")
        continue
    
    pool_volume = volume_data[chain][address]
    
    # get volume data and fees from prices.curve.fi if available
    pool['volumeUsd'] = 0
    pool['feesUsd'] = 0
    pool['prevVolumeUsd'] = 0
    pool['prevFeesUsd'] = 0
    pool['prevTvlUsd'] = 0
    pool['prevTokenSupply'] = 0
    pool['tokenSupply'] = int(pool['totalSupply'])/10**18
    pool['baseWeeklyApy'] = pool_volume['latestWeeklyApyPcent']

    print(f"Processing {pool['name']} ({i_pool}/{num_pools}), {chain}-{address}, est. time remaining: {est_time_remaining//60}m{est_time_remaining%60}s")
    try:
        pool['volumeUsd'], pool['feesUsd'], pool['prevVolumeUsd'], pool['prevFeesUsd'] = get_pool_volume(chain, address, epoch_start, epoch_end)
    except:
        print(f"Failed getting volume data for pool {pool['name']} ({i_pool}/{num_pools}): apr {pool['baseWeeklyApy']}, tvl {pool['usdTotal']}, {chain}-{address}")
        continue
    try:
        tvl_data = get_tvl(chain, address, pool['creationTs'], epoch_start, get_cur_time())
        pool['prevTvlUsd'] = tvl_data['start']['tvl']
        pool['prevTokenSupply'] = tvl_data['start']['token_supply']
        pool['tvlData'] = tvl_data
        if tvl_data['end']['token_supply_snapshot'] != None:
            pool['tvlUsd'] = tvl_data['end']['tvl']
            pool['tokenSupply'] = tvl_data['end']['token_supply']
    except:
        print(f"Failed getting tvl data for pool {pool['name']} ({i_pool}/{num_pools}): apr {pool['baseWeeklyApy']}, tvl {pool['usdTotal']}, {chain}-{address}")
        continue
    
    good_pool_data.append(pool)
# Out:
# Skipping pool KNOX/eUSD (1/3794), arbitrum-0x96e5F3F6e055ecc4C84302f3AD5295c47cD59914, TVL: 0, est. time remaining: 0m0s
# Skipping pool BTC (2/3794), fantom-0x6A1C781B7B280E3c8BF04FDfb86C112C9Ac70a89, TVL: 0, est. time remaining: 0m0s
# Skipping pool wrapped Bitcoin Pax Gold (3/3794), polygon-0xF2ce93d54e0b043fbe654eA73aAde9DFB092d2cc, TVL: 0, est. time remaining: 0m0s
# Skipping pool AMPH/WETH/wUSDA (4/3794), ethereum-0x05CA1ff6fF45e55906c86Ad0d3FB2EbFaE9E0891, TVL: 0, est. time remaining: 0m0s
# Processing frxETH/afETH (5/3794), ethereum-0x55Faa4a58f6510f78c1466C71C63200D62a197D2, est. time remaining: 0m0s
# Processing SETH/ETH (6/3794), arbitrum-0x390C6eB1E824A7CCa2E646e47D8fCba4263E9E38, est. time remaining: 42m5s
# Processing crvUSD/cncCRVUSD (7/3794), ethereum-0xe3E637f8aCC097244A065791142c29fbF5877D18, est. time remaining: 99m11s
# Skipping pool USD0/USDC (8/3794), ethereum-0x7FE188ACa91077353c9Edb0E9e4f34B60210711f, TVL: 0, est. time remaining: 110m25s
# Processing Curve.fi Factory Crypto Pool: Spectra-PT/IBT (9/3794), ethereum-0x952Ac974fF2f3ee5c05534961B661FE70fD38B8A, est. time remaining: 98m7s
# Skipping pool Curve.fi Factory USD Metapool: RC_INV_350_DAI_2021_5_31 (10/3794), ethereum-0x883F7d4B6B24F8BF1dB980951Ad08930D9AEC6Bc, TVL: 0, est. time remaining: 132m26s
# Skipping pool Curve.fi Factory Plain Pool: OptimisticFuture pool (11/3794), optimism-0xAEA4DEBbB349a54Cc27419aBBbbA94AB0Bd276A7, TVL: 0, est. time remaining: 120m22s
# Skipping pool Curve.fi Factory Crypto Pool: FRAXBP/USDS (12/3794), ethereum-0xf5d5305790c1af08e9dF44b30A1afe56cCda72df, TVL: 0, est. time remaining: 110m18s
# Skipping pool FRAX Liquid miMATIC-Peg (13/3794), fantom-0x011E998D2d794424DE95935d55a6Ca81822Ecb2b, TVL: 0, est. time remaining: 101m47s
# Skipping pool Curve.fi Factory Crypto Pool: ARTH/3pool (14/3794), ethereum-0xaeB6f2ABE64EE5ed210e8AE33B1F0f5E4B3e28Fc, TVL: 3.1139999999999998e-18, est. time remaining: 94m30s
# Processing deUSD/USDT (15/3794), ethereum-0x7C4e143B23D72E6938E06291f705B5ae3D5c7c7C, est. time remaining: 88m10s
# Skipping pool weth/usdc (16/3794), arbitrum-0x77146B0a1d08B6844376dF6d9da99bA7F1b19e71, TVL: 0, est. time remaining: 90m30s
# Skipping pool Curve.fi Factory Crypto Pool: Risky Ethereum (17/3794), base-0xC3D776ccF70478EB27A60ED16F6b438Abd91f3e5, TVL: 7.855978026515782, est. time remaining: 85m10s
# Skipping pool Curve.fi Factory Crypto Pool: GSTF/MATIC (18/3794), polygon-0xAC10D17dA3616a08baeA44fADcCDc4dd46F58A3c, TVL: 0, est. time remaining: 80m24s
# Skipping pool USDT/WETH (19/3794), polygon-0x0fF26A978A61d40F6591fc700EF878E96aF6C2C0, TVL: 0, est. time remaining: 76m9s
# Skipping pool Curve.fi Factory USD Metapool: TUS-USDC-USDT (20/3794), arbitrum-0x59a3eF790bE58413471267b8D02993bc0ea2F669, TVL: 0, est. time remaining: 72m20s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator TKN1/PLL-f} (21/3794), fantom-0x12FA77685728ABcBe1d5c7C11638d2C8dF250478, TVL: 0, est. time remaining: 68m52s
# Processing sEUR/crvUSD (22/3794), optimism-0x39F301784B5b680D302B4e989d01B31DB14E8231, est. time remaining: 65m43s
# Failed getting tvl data for pool sEUR/crvUSD (22/3794): apr 0, tvl 187.896533184927, optimism-0x39F301784B5b680D302B4e989d01B31DB14E8231
# Skipping pool Curve.fi Factory Plain Pool: BRLA/BRZ (23/3794), polygon-0x30E0b18e6A32d80b626Fc4fd785eC26f4b94dDB3, TVL: 0, est. time remaining: 65m34s
# Skipping pool Curve.fi Factory Plain Pool: USDC/USDT/WBTC (24/3794), arbitrum-0x93004D8477f117eA359b71ec02f2706c8175c55c, TVL: 0, est. time remaining: 62m50s
# Skipping pool Curve.fi Factory USD Metapool: busd (25/3794), polygon-0x4356a01C4F873ae8fA46E1d2cFAEE249560c5e6e, TVL: 0, est. time remaining: 60m18s
# Skipping pool Curve.fi Factory Crypto Pool: BENT/FraxBP (26/3794), ethereum-0x825722AF244432319C1E32b6b18AdED2d4A014Df, TVL: 1.129656494634381e-18, est. time remaining: 57m58s
# Skipping pool Curve.fi Factory Plain Pool: Vaya/crvUSD (27/3794), base-0xC2327746d0dA4183f77c813B76450a17852A38Ef, TVL: 0, est. time remaining: 55m48s
# Skipping pool Curve.fi Factory Crypto Pool: MSCL/ROK (28/3794), polygon-0x8E6692B6Fc3bCE7d5291C96ff02bA24E1a329C60, TVL: 0, est. time remaining: 53m48s
# Skipping pool Curve.fi Factory USD Metapool: PSOL /MATIC (29/3794), polygon-0x81E94148a68AafCac58F7BDb63A2CA71773A5de5, TVL: 0, est. time remaining: 51m55s
# Skipping pool Curve.fi Factory Crypto Pool: PlataToken/WMATIC (30/3794), polygon-0x311A794F0643F938143AD0Bfbd6b956d53EB8E01, TVL: 40.638146976087924, est. time remaining: 50m11s
# Skipping pool TUSDC/rTBL/B (31/3794), polygon-0x55Dc62594d21C04D2eCd7f8c13558efdEd7ce3d7, TVL: 0, est. time remaining: 48m33s
# Processing Curve.fi Factory Crypto Pool: DYDX/ETH (32/3794), ethereum-0x8b0aFa4b63a3581b731dA9D79774a3eaE63B5ABD, est. time remaining: 47m1s
# Processing sUSX/sUSDe (33/3794), ethereum-0xf93893040759009e975f3D46eCD4DC91FE438574, est. time remaining: 53m11s
# Skipping pool Curve.fi Factory Crypto Pool: ARTH/ETH (34/3794), ethereum-0x19a0CA9a0dc2A5034F47DcC164169Cffd7ed2410, TVL: 85.33596379656305, est. time remaining: 55m17s
# Skipping pool WETH/WETH (35/3794), arbitrum-0xF3d9af60Daa2F5e48dCC0E318B626faD4C4A7314, TVL: 2.03073280931834, est. time remaining: 53m42s
# Skipping pool CURVEBOBR Pool (36/3794), fraxtal-0x5f0985A8aAd85e82fD592a23Cc0501e4345fb18c, TVL: 0, est. time remaining: 52m11s
# Skipping pool PHIL/ETH (37/3794), ethereum-0x01e744407B357cAd2a92e95ED1D52db0534b6a26, TVL: 0, est. time remaining: 50m46s
# Skipping pool USD/USDC/DAI (38/3794), fantom-0xBf96977d361d7DAA67F91F46Fa4fE373771F0362, TVL: 0, est. time remaining: 49m25s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDC/USDT (39/3794), polygon-0xEC9447b3a7F639458469d97DB5ca1F6DFa93b811, TVL: 0, est. time remaining: 48m8s
# Skipping pool Curve.fi Factory USD Metapool: DSU (40/3794), ethereum-0x9fED7a930d86Dfe5980040E18C92B1B0d381eC19, TVL: 0, est. time remaining: 46m55s
# Processing Curve.fi Factory Plain Pool: 2eur (EURT) (41/3794), polygon-0x2C3cc8e698890271c8141be9F6fD6243d56B39f1, est. time remaining: 45m46s
# Skipping pool Curve.fi Factory Plain Pool: MAI3Pool (42/3794), fantom-0x84f21b7ceb64906320E2b62cF73Ff03dcFd137dC, TVL: 15.79362755149211, est. time remaining: 47m38s
# Skipping pool sUSDe/USDe (43/3794), arbitrum-0x61F9b3A9062e198D8e098a2939d2300595Fd0B2B, TVL: 0, est. time remaining: 46m31s
# Skipping pool Curve.fi Factory Plain Pool: USDDI (44/3794), base-0x467FC771586e28597a5153b4cb5B63Daa39b0B6E, TVL: 0, est. time remaining: 45m27s
# Skipping pool MaticUsdcD (45/3794), polygon-0x368B54D2fAe1B60d1f40C15F3e9e72726a4D8ae3, TVL: 0, est. time remaining: 44m25s
# Processing Curve.fi Factory Plain Pool: bentCVX (46/3794), ethereum-0xf083FBa98dED0f9C970e5a418500bad08D8b9732, est. time remaining: 43m27s
# Skipping pool crvUSD/DAI (47/3794), arbitrum-0xE79aDd96d145B88cE99a730af7D7A180702fA4c4, TVL: 0, est. time remaining: 45m10s
# Skipping pool zunETH/pufETH (48/3794), ethereum-0x50f627FA35D3C47D9A99F4E4cdf40C6E94679bf6, TVL: 0, est. time remaining: 44m13s
# Skipping pool Curve.fi Factory Plain Pool: cvxCrv/Crv (49/3794), ethereum-0x5007c634BD59dd211875346A5D0cfd10DFD1CdC0, TVL: 0, est. time remaining: 43m18s
# Processing Curve.fi Factory Crypto Pool: CRV/PROS (50/3794), polygon-0x2a3f0d76E32b2395ca8D0c441C1346326410Abfe, est. time remaining: 42m25s
# Skipping pool crv/eth (51/3794), base-0x513Fd781e908540030FbFfB88BeBf0f21FFfd4E0, TVL: 0, est. time remaining: 44m2s
# Skipping pool Curve.fi Factory Plain Pool: handleEUR (52/3794), ethereum-0x8DF0713B2a047c45a0BEf21c3B309bcEF91afd34, TVL: 0, est. time remaining: 43m10s
# Processing Curve.fi Factory USD Metapool: Titanium Dollar (53/3794), ethereum-0xA77d09743F77052950C4eb4e6547E9665299BecD, est. time remaining: 42m21s
# Processing Curve.fi Factory Crypto Pool: USDC/UAHT (54/3794), polygon-0xC962fe734eCbEa2739c205e3BdB3Bf7e3fBE3C2B, est. time remaining: 43m51s
# Skipping pool Curve.fi Factory USD Metapool: Fantom USD (55/3794), fantom-0xe1bA291eED6Ed14A4e65dCbe6a4936Fe15B3A1a4, TVL: 0, est. time remaining: 45m19s
# Skipping pool wfrxETH (56/3794), fraxtal-0xC65d17166d0894A926AFE30885a9fb713E7C39ee, TVL: 0.08278639229805249, est. time remaining: 44m30s
# Skipping pool Curve.fi Factory Crypto Pool: liq_CRV_FANTOM (57/3794), ethereum-0x3272C5D11644deBB2e9d04C302796EbE8DF35457, TVL: 0, est. time remaining: 43m42s
# Skipping pool Curve.fi Factory Pool: alETH (58/3794), ethereum-0xC4C319E2D4d66CcA4464C0c2B32c9Bd23ebe784e, TVL: 0, est. time remaining: 42m56s
# Skipping pool Rentonewusd (59/3794), fantom-0x561f8A3dd9c7cf92b43aAd2f76517b4bB6272eE5, TVL: 0, est. time remaining: 42m12s
# Processing Curve.fi Factory Plain Pool: crvUSD/USDT (60/3794), ethereum-0x390f3595bCa2Df7d23783dFd126427CCeb997BF4, est. time remaining: 41m29s
# Skipping pool Curve.fi Factory USD Metapool: deBridge-FRAX (61/3794), arbitrum-0xaa9dFbf31d2f807cA4d9f7BE281D75cA7BDCE64D, TVL: 0, est. time remaining: 47m56s
# Skipping pool Curve.fi Factory USD Metapool: Liquidity Luk (62/3794), polygon-0x8Aa1D5874e9Cd918d66FDbE0D3cAA65301995Be0, TVL: 8.757042374947442, est. time remaining: 47m9s
# Processing Curve.fi Factory Crypto Pool: eUSD/USDC (63/3794), ethereum-0x880F2fB3704f1875361DE6ee59629c6c6497a5E3, est. time remaining: 46m23s
# Skipping pool Curve.fi Factory Crypto Pool: USDC/DAI (64/3794), polygon-0xB8d53c82D627C36020a917cc1d22C52eec179f3C, TVL: 0, est. time remaining: 47m35s
# Skipping pool Curve.fi Factory Plain Pool: de-Eth-Pool (65/3794), arbitrum-0x878B2efD1dBEF551F63b34734240B2896ef917b3, TVL: 0, est. time remaining: 46m51s
# Skipping pool K/WFETH (66/3794), fraxtal-0xc0806D02B4E9ac39278300A1D169564758B02433, TVL: 0, est. time remaining: 46m7s
# Skipping pool STARV3-USDC/StarSeeds Protocol.  (67/3794), polygon-0x9A88B956012968B6f519f9Db1d3bb5514163b856, TVL: 0, est. time remaining: 45m25s
# Skipping pool Curve.fi Factory Plain Pool: crvMiner (68/3794), polygon-0xf462219aA7d7E7de1B1b5CB6c707288FD87d24BD, TVL: 0.07743377552515368, est. time remaining: 44m44s
# Skipping pool sDAI/crvUSD (69/3794), xdai-0xF7Fed8Ae0c5B78c19Aadd68b700696933B0Cefd9, TVL: 0, est. time remaining: 44m5s
# Processing LLAMAwnft/ETH (70/3794), ethereum-0x4484A052A0be82af20896ea3C8D891a3d11e8D1A, est. time remaining: 43m26s
# Processing USDe/USDx (71/3794), arbitrum-0x096A8865367686290639bc50bF8D85C0110d9Fea, est. time remaining: 45m26s
# Processing USD3/USDM (72/3794), ethereum-0x8999EB39237DD9E3C184fb2f10780a95a34A14ef, est. time remaining: 46m31s
# Processing Curve.fi Factory Plain Pool: eUSD/crvUSD (73/3794), base-0x798D81d60966d2E909468d87e7e4b6A8DAFB1C36, est. time remaining: 48m25s
# Skipping pool Curve.fi Factory Crypto Pool: IRONTiT$ (74/3794), polygon-0x41904e5cbc0903f527f0AAE1d29D558300D76ef3, TVL: 0.021297427506787335, est. time remaining: 49m25s
# Processing Curve.fi Factory Plain Pool: stLINK/LINK (75/3794), ethereum-0x1c899dED01954d0959E034b62a728e7fEbE593b0, est. time remaining: 48m45s
# Skipping pool Curve.fi Factory Plain Pool: ibZAR/ZARP (76/3794), ethereum-0xcbD5cC53C5b846671C6434Ab301AD4d210c21184, TVL: 1.096305325976771, est. time remaining: 49m44s
# Skipping pool wXYZ/USDC (77/3794), arbitrum-0xf42cD1Ecb5e79baC6fC7810878568E030a54B099, TVL: 0, est. time remaining: 49m4s
# Skipping pool Curve.fi Factory Plain Pool: 3PoolBUSD (78/3794), xdai-0xd8883EeC56cB95F9bbdccaa9b453e3cC19a90e72, TVL: 0.48729614641353514, est. time remaining: 48m26s
# Skipping pool Curve.fi Factory Crypto Pool: cvxPrismaETH (79/3794), ethereum-0xdD238c928d177d775399D13eEcAb876486679268, TVL: 3.66438145526e-15, est. time remaining: 47m48s
# Skipping pool AUSD/USDC (80/3794), ethereum-0xFa883807fdf5D3F5c408F1f6D78707753Af1FFE7, TVL: 15.010416868803855, est. time remaining: 47m11s
# Skipping pool Curve.fi Factory Crypto Pool: RAI/DAI (81/3794), polygon-0xDcE686fB06954DD54a2C73D4Da97e46692D3990A, TVL: 5.009464e-18, est. time remaining: 46m36s
# Skipping pool Curve.fi Factory Pool: TESTABC + TESTZRX (82/3794), polygon-0xBE775DEB31B4ee5841a8B4564c9F3294987023Fe, TVL: 0, est. time remaining: 46m1s
# Skipping pool Curve.fi Factory Crypto Pool: RAI/DAI-2 (83/3794), polygon-0x7aC0401b1D49A8E01daf46Cb5198654F89e64Dc5, TVL: 5.009464e-18, est. time remaining: 45m27s
# Processing mkUSDUSDe (84/3794), ethereum-0x1ab3D612EA7df26117554ddDD379764EBcE1A5Ad, est. time remaining: 44m54s
# Skipping pool Curve.fi Factory Crypto Pool: wbtc/fusdt (85/3794), fantom-0xF4f2c1710e4470E58e4841ea0653f949bdDDD67f, TVL: 0, est. time remaining: 46m32s
# Skipping pool nativeFRAX/lzFRAX (86/3794), fraxtal-0x53f8F4e154F68C2D29a0D06BD50f82bCf1bd95dB, TVL: 2.375933425140523, est. time remaining: 45m59s
# Skipping pool usdcw (87/3794), base-0xc270F555892D063AADCbDFC1Fedc8d4215a84e32, TVL: 0, est. time remaining: 45m26s
# Skipping pool Curve.fi Factory Crypto Pool: Fv (88/3794), fantom-0x41cE0136B3a9EE7c82D79fB72Ff48360BD5a3263, TVL: 0, est. time remaining: 44m55s
# Skipping pool test (89/3794), arbitrum-0xaF108C4ef8F579f2e1bC0c1e692Aec3c8C8e587e, TVL: 0, est. time remaining: 44m24s
# Skipping pool Curve.fi Factory Crypto Pool: CRV/PROS (90/3794), polygon-0x6eb269e6C36b142B688E620a6365C5e6812fB316, TVL: 0, est. time remaining: 43m53s
# Skipping pool FRAX/WETH (91/3794), fraxtal-0xb9c79bD5e5561Bdcc281e2b530CeFBbeBC9976aC, TVL: 0, est. time remaining: 43m24s
# Skipping pool Curve.fi Factory Crypto Pool: LIL/MAT (92/3794), polygon-0x4Bb9AFee82F25c9BC60eaEb46615df1B717D40bd, TVL: 0, est. time remaining: 42m55s
# Skipping pool Curve.fi Factory Plain Pool: PolyEuro (EURT/EUROC) (93/3794), polygon-0x9073c66c88D64b77189f17dD646a3599d8bB7020, TVL: 0, est. time remaining: 42m26s
# Processing senUSD/USDC (94/3794), ethereum-0xBeCDF453a9d69aa67d27fd391E81FD96A8b9Ade5, est. time remaining: 41m59s
# Skipping pool Curve.fi Factory Crypto Pool: SNT/ETH (95/3794), ethereum-0x4B036A6769D5f1abb5A249a489348389C2907334, TVL: 3.6723848904800004e-15, est. time remaining: 42m49s
# Skipping pool Curve.fi Factory USD Metapool: TRUEHN/USDT (96/3794), polygon-0xfd5BB985A536Fb0242224c5F4dF52b54fe5FCF9C, TVL: 0, est. time remaining: 42m22s
# Processing Tether Alloy (97/3794), ethereum-0x8F476f43bAA2D4b6C215d2408340919bF7DE0520, est. time remaining: 41m55s
# Processing sfrxETH/sFRAX (98/3794), fraxtal-0xaCDc85AFCD8B83Eb171AFFCbe29FaD204F6ae45C, est. time remaining: 42m44s
# Processing TricryptoUSDT (99/3794), ethereum-0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4, est. time remaining: 44m9s
# Skipping pool Curve.fi Factory USD Metapool: Dola-2pool Curve Metapool (100/3794), fantom-0x28368D7090421Ca544BC89799a2Ea8489306E3E5, TVL: 11.604075191858083, est. time remaining: 46m47s
# Processing sxETH/ETH (101/3794), ethereum-0x8b0fb150FbA4fc25cd4f6F5bd8a8F6944ad65Af0, est. time remaining: 46m18s
# Skipping pool Curve.fi Factory Crypto Pool: MMX/USDT (102/3794), ethereum-0x68175Aa7FeE7e6A4709640Ac8C912EC3C50b3AF5, TVL: 0, est. time remaining: 46m27s
# Skipping pool Curve.fi Factory Crypto Pool: 3PUSDRMAI-Compounding (103/3794), polygon-0xfb9786a7585b093dc551d0fF45124e65094E8E71, TVL: 0, est. time remaining: 45m59s
# Processing MaticX/WMatic V3 (104/3794), polygon-0xcC9841c942ec72e6Ac74da8fb2Fb45cF3b1A099C, est. time remaining: 45m32s
# Skipping pool Curve.fi Factory Plain Pool: jBRL+BRZ+BRZ (105/3794), polygon-0x54A8F4FBc322C31Ee2d85a60CF6F9c1d53bE1c52, TVL: 0, est. time remaining: 46m15s
# Skipping pool Curve.fi Factory Plain Pool: 2gold (CACHE) (106/3794), polygon-0xb70aA4aD7fd5352eB2EbDd052De17f2F29971ecB, TVL: 0, est. time remaining: 45m48s
# Skipping pool Curve.fi Factory USD Metapool: CoUsd/Usdc (107/3794), fantom-0xf51B20668593CaAB20c56015fabCBE67963e17c7, TVL: 0, est. time remaining: 45m22s
# Skipping pool Curve.fi Factory Crypto Pool: CRV/am3CRV (108/3794), polygon-0xF8F569aAf3aBD1e1c5e75d9445C8938D42fEBd1C, TVL: 0.1076549113126305, est. time remaining: 44m56s
# Processing Curve.fi Factory Plain Pool: ibAUD/sAUD (109/3794), ethereum-0x3F1B0278A9ee595635B61817630cC19DE792f506, est. time remaining: 44m30s
# Skipping pool Curve.fi Factory USD Metapool: complexPool (110/3794), fantom-0xcae2925267Ad62B6115881169b8606AdEaA7BA50, TVL: 0, est. time remaining: 45m12s
# Processing USDC/GRAI (111/3794), arbitrum-0x7004aE8cd7FfC6DB8b15E4d5B6692FE1D7EADcDA, est. time remaining: 44m47s
# Skipping pool Curve.fi Factory Plain Pool: rAXX/USDT (112/3794), xdai-0xEad043133aa7DbbebEAa986eEB9C85d61962cd91, TVL: 0, est. time remaining: 45m28s
# Skipping pool Curve.fi Factory Plain Pool: sdCRV (113/3794), ethereum-0x323b3a6e7a71c1b8C257606Ef0364D61df8AA525, TVL: 0, est. time remaining: 45m3s
# Skipping pool Curve.fi Factory Crypto Pool: BENT/FRAX (114/3794), ethereum-0xd3301B7CAA76f932816a6Fc7Ef0b673238e217ad, TVL: 1.0659754468809753e-18, est. time remaining: 44m39s
# Processing crvUSD/USDC.e (115/3794), polygon-0x864490Cf55dc2Dee3f0ca4D06F5f80b2BB154a03, est. time remaining: 44m15s
# Processing Curve EURT-3Crv (116/3794), ethereum-0x9838eCcC42659FA8AA7daF2aD134b53984c9427b, est. time remaining: 45m26s
# Skipping pool StablePool (117/3794), fantom-0x00305355C57264f962FCB0795a8D482D1c0C08E3, TVL: 0, est. time remaining: 46m5s
# Skipping pool Curve.fi Factory Plain Pool: SETH/WSTETH (118/3794), optimism-0x047fE1fB7b3a2C13BDf4ee9ecA20da21CDCc9E1c, TVL: 0, est. time remaining: 46m12s
# Skipping pool MatUsdc (119/3794), polygon-0x9A54DB0Ff0EaB92f34a96B4639C9Be4f4F230859, TVL: 0, est. time remaining: 45m48s
# Skipping pool tricrypto (120/3794), base-0xeC6a886148B38C233B07cc6732142dccaBF1051D, TVL: 0, est. time remaining: 45m24s
# Skipping pool My AAVE pool. (121/3794), optimism-0x58EC27D2f6af45BB630aC67F9869D8117B6C4Aa9, TVL: 0, est. time remaining: 45m1s
# Skipping pool Curve.fi Factory Plain Pool: 3CRVUSD+AMIS (122/3794), polygon-0xE0Eb3CA0b2759344477a7D4E0F8F1f3944Da1Ba7, TVL: 3.628312485201006, est. time remaining: 44m38s
# Processing CRV/vsdCRV/asdCRV (123/3794), polygon-0xB1B1F3BA475A7CCf6EdF709E1B90A970F6B5fED6, est. time remaining: 44m16s
# Failed getting volume data for pool CRV/vsdCRV/asdCRV (123/3794): apr 5.02, tvl 109072.03581937484, polygon-0xB1B1F3BA475A7CCf6EdF709E1B90A970F6B5fED6
# Processing Curve.fi Factory Plain Pool: rETH/wstETH (124/3794), ethereum-0x447Ddd4960d9fdBF6af9a790560d0AF76795CB08, est. time remaining: 43m54s
# Skipping pool Curve.fi Factory Crypto Pool: USDR+MAI+3CRV (Compounding) (125/3794), polygon-0x17626Ae92a2C638EC911B26a121b02BbE90C1180, TVL: 2.4220917224277107e-18, est. time remaining: 45m0s
# Skipping pool btc (126/3794), fantom-0x16A3a047fC1D388d5846a73ACDb475b11228c299, TVL: 0, est. time remaining: 44m38s
# Skipping pool Curve.fi Factory Plain Pool: eUSDC (127/3794), fantom-0xBEF8C18a6aeB67f696A18698a067fBED2766D5b8, TVL: 19.64766815957641, est. time remaining: 44m16s
# Skipping pool Curve.fi Factory Plain Pool: wmUSD (128/3794), polygon-0xe23CB450722F6B5466e60D036981b4160721D146, TVL: 1.175200320172729, est. time remaining: 43m54s
# Skipping pool Curve.fi Factory Crypto Pool: Spectra-PT/IBT (129/3794), ethereum-0x870754e9Cb1555c427dd7b433A55aEAcCd7e4e1F, TVL: 1.1407788412636689e-17, est. time remaining: 43m33s
# Skipping pool L1/2CRV (130/3794), arbitrum-0xB37bAfCf451160fE4d04814C119ca648E565B44B, TVL: 0, est. time remaining: 43m12s
# Processing wfrxETH/WETH (131/3794), fraxtal-0xf8474c80dfE3AF4794Eac64672137ad390AAbB0A, est. time remaining: 42m52s
# Processing Curve.fi Factory Crypto Pool: pxETH/mkUSD (132/3794), ethereum-0x71Db3764d6841D8B01Dc27C0Fd4A66A8A34b2BE0, est. time remaining: 43m27s
# Skipping pool Curve.fi Factory Plain Pool: Staging USDC/USDM (133/3794), polygon-0x8070116a3Bc74c16840Faa349B79c54e3AEBCf4d, TVL: 0, est. time remaining: 44m2s
# Skipping pool Curve.fi Factory Plain Pool: eEUR/eUSD (134/3794), polygon-0xd6b27977Bbde997B7FcB4e5ED0341e2858F2E213, TVL: 0, est. time remaining: 43m42s
# Processing Curve.fi Factory Pool: ETHx-ETH (135/3794), ethereum-0x59Ab5a5b5d617E478a2479B0cAD80DA7e2831492, est. time remaining: 43m21s
# Skipping pool Curve.fi Factory Plain Pool: USDT/USDCL (136/3794), arbitrum-0x8Cb640A9Ce064Efae27BA7374c3765CB8f53503f, TVL: 0, est. time remaining: 44m22s
# Skipping pool MAI x3CRV (137/3794), xdai-0x2922cAb0d192afaad4a8561012202Bf539d0FC9E, TVL: 0, est. time remaining: 44m2s
# Processing Curve.fi Factory USD Metapool: Binance USD (138/3794), ethereum-0x4807862AA8b2bF68830e4C8dc86D0e9A998e085a, est. time remaining: 43m42s
# Processing wolf/usdc (139/3794), ethereum-0x05001F08E5Ab5A4c6B6996BdfB5C7F5Ed3fb3809, est. time remaining: 44m42s
# Processing Curve EUROC-3Crv (140/3794), ethereum-0xE84f5b1582BA325fDf9cE6B0c1F087ccfC924e54, est. time remaining: 44m48s
# Processing FRAX/USDC (141/3794), fraxtal-0xa8eB7B41fe8dF7Ea3de982397AD183721784D987, est. time remaining: 45m20s
# Skipping pool Curve.fi Factory Crypto Pool: DUCK/3CRV (142/3794), ethereum-0xb49B238aB6106216Dc26854ed3a009EAc1C419A9, TVL: 0, est. time remaining: 45m51s
# Skipping pool wBTC (143/3794), arbitrum-0x5785126d474463Fa21B1FD037d4788b7F8Fd6202, TVL: 0, est. time remaining: 45m31s
# Skipping pool Curve.fi Factory Crypto Pool: aPolCRV/CRV (144/3794), polygon-0x9a54FfCe103D4722940b6e24187442824F6a4F71, TVL: 0, est. time remaining: 45m12s
# Processing crvUSD/USDT (145/3794), arbitrum-0x73aF1150F265419Ef8a5DB41908B700C32D49135, est. time remaining: 44m52s
# Skipping pool Curve.fi Factory Plain Pool: WETH/WBTC/USDC (146/3794), arbitrum-0x5Aa2a79293424bf39171d704A364FDE3B641DB25, TVL: 0, est. time remaining: 49m33s
# Processing Curve.fi Factory Crypto Pool: CLEV/ETH (147/3794), ethereum-0x342D1C4Aa76EA6F5E5871b7f11A019a0eB713A4f, est. time remaining: 49m12s
# Skipping pool V11 MATIC-S - StarSeeds Protocol (148/3794), polygon-0x19d2B5CE188Ca60790755204691E38102749297b, TVL: 0, est. time remaining: 50m5s
# Skipping pool Curve.fi Factory USD Metapool: ibBTC (149/3794), polygon-0xf0016fA1b5CB0036425AE47510aC9DEb40d3f273, TVL: 0, est. time remaining: 49m44s
# Skipping pool TST/USDT (150/3794), polygon-0x86EA1191a219989d2dA3a85c949a12A92f8ED3Db, TVL: 0, est. time remaining: 49m23s
# Processing Curve.fi Factory Plain Pool: axlUSDC/USDC (151/3794), polygon-0xfBA3b7Bb043415035220b1c44FB4756434639392, est. time remaining: 49m3s
# Skipping pool T (152/3794), arbitrum-0x5708933B1D6464B6c697E34d0E23Ae1f97156869, TVL: 0, est. time remaining: 49m7s
# Skipping pool Curve.fi Factory Crypto Pool: jpyusd (153/3794), ethereum-0x611a95bf3cc0EF593f22c4E4D8EB4d6C937E006C, TVL: 23.316467248180672, est. time remaining: 48m47s
# Processing Curve.fi Factory Plain Pool: sGNO/GNO (154/3794), xdai-0xBdF4488Dcf7165788D438b62B4C8A333879B7078, est. time remaining: 48m27s
# Skipping pool StableBond Reservation (155/3794), ethereum-0xaB19bd4A0912962930573A0Bb723b63e38173c5F, TVL: 0, est. time remaining: 48m54s
# Skipping pool USD0/USDC (156/3794), polygon-0x8015524239750723e455bfAD40B982e111aA65fD, TVL: 0, est. time remaining: 48m35s
# Skipping pool Curve.fi Factory Crypto Pool: FXS/ETH (157/3794), ethereum-0x6ec176b5449DD7C1a87CA8d97aceCC531C0Ca0d8, TVL: 0, est. time remaining: 48m15s
# Processing Curve.fi Factory Plain Pool: 2jpy-2 (158/3794), polygon-0xaA91CDD7abb47F821Cf07a2d38Cc8668DEAf1bdc, est. time remaining: 47m56s
# Skipping pool btc (159/3794), fantom-0x0fF26A978A61d40F6591fc700EF878E96aF6C2C0, TVL: 0, est. time remaining: 49m9s
# Skipping pool Curve.fi Factory Crypto Pool: LLAMAwnft/ETH (160/3794), ethereum-0xaCf9cc3b3e8F4031131CD72e40a0FdAa99d3E209, TVL: 3.820220832776995e-10, est. time remaining: 48m49s
# Skipping pool STAR-Power/ETH StarSeedsProtocol (161/3794), polygon-0x9F4d521f28055f489AB4D6c65A0Cd472f3A72bae, TVL: 0, est. time remaining: 48m30s
# Processing TriCRV-OPTIMISM (162/3794), optimism-0xd8dD9a8b2AcA88E68c46aF9008259d0EC04b7751, est. time remaining: 48m12s
# Skipping pool Curve.fi Factory Pool: csMATIC + MATIC (163/3794), polygon-0x6FFA69b570d169317Ec8d619Ae6FA2D662a03d28, TVL: 0, est. time remaining: 57m55s
# Skipping pool Curve.fi Factory Plain Pool: ZALOOP/STB (164/3794), polygon-0xf7c3DBD6Bb38285412C02d3FDecef317fDCfB5B4, TVL: 0.4734527329668293, est. time remaining: 57m32s
# Skipping pool crvUSD/stUSDT (165/3794), ethereum-0x678053c553B963f83798b54D7F69deC086D527BA, TVL: 9.689240000000001e-19, est. time remaining: 57m11s
# Skipping pool Curve.fi Factory Plain Pool: StarSeeds Protocols STARDollars (166/3794), polygon-0x8393713289D80c10f8B95e392CB07adC964A34D0, TVL: 0.000124, est. time remaining: 56m49s
# Processing Curve.fi Factory USD Metapool: xim (167/3794), ethereum-0x6d8fF88973b15dF3e2dc6ABb9aF29Cad8C2B5Ef5, est. time remaining: 56m28s
# Skipping pool OD/USDC Stability Pool (168/3794), arbitrum-0x69CAe865bb5EfEc4990692BdEb2DaCAAcC77086F, TVL: 0, est. time remaining: 57m33s
# Skipping pool Curve.fi Factory Plain Pool: pxETH/WETH (169/3794), ethereum-0x270d74e9Cc8DC75ef55d91c0D469E3285E581E77, TVL: 0, est. time remaining: 57m11s
# Skipping pool Curve.fi Factory Crypto Pool: CADC/3CRV (170/3794), ethereum-0x595146ED98c81Dde9bD23d0c2Ab5b807C7Fe2D9f, TVL: 0, est. time remaining: 56m50s
# Skipping pool SWEEP/USDC (171/3794), polygon-0xcFDE19f1a09206bb024F5C4Bf61c40670FDfF449, TVL: 5.504910603011487, est. time remaining: 56m29s
# Skipping pool KNOX/eUSD (172/3794), arbitrum-0x026e0d0F00980854D60A914fe6eC0ed3252325E8, TVL: 0, est. time remaining: 56m9s
# Skipping pool Rolls Royce (173/3794), base-0x9eddab5B9a8ff0A243c26105C3aA5F52C4457D69, TVL: 0, est. time remaining: 55m48s
# Skipping pool rev alUSD (174/3794), ethereum-0xF5a7906b41B858B66d3A7cBe167dF1fB43FfE977, TVL: 3.90885692124606, est. time remaining: 55m28s
# Skipping pool psOLY (175/3794), polygon-0x0C21CDB8D1875b0b11190181A8CAA55B8cfa1252, TVL: 0, est. time remaining: 55m8s
# Skipping pool Curve.fi Factory USD Metapool: USDS/FRAXBPv2 (176/3794), arbitrum-0x7A56266db1CF99F26a3E737ba36C4004a66bD5b3, TVL: 0, est. time remaining: 54m49s
# Skipping pool axlUSDC/FRAX (177/3794), fraxtal-0x602C281D739357ccd54479960b3196f27571e5da, TVL: 18.13532186496093, est. time remaining: 54m29s
# Skipping pool stable dai/usdt/usdc (178/3794), polygon-0xf8CD2b492BfDF2a95512174Cb96685e41Cc06767, TVL: 0, est. time remaining: 54m10s
# Skipping pool Curve.fi Factory Crypto Pool: wbtc (179/3794), polygon-0xbA78F530319D536b0A708656fD77ffFbF09Ec435, TVL: 0, est. time remaining: 53m51s
# Skipping pool Curve.fi Factory Plain Pool: USDV/axlUSDC (180/3794), fantom-0x78ed6aF913D66F60d339d81CF5C5188473785070, TVL: 0, est. time remaining: 53m32s
# Skipping pool Curve.fi Factory Crypto Pool: bLUSD_LUSD3CRV (181/3794), ethereum-0x9A7168Ea321121A8FaF52147fC596b73e07Ab8a3, TVL: 0, est. time remaining: 53m13s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDC/USDT (182/3794), polygon-0x2Aa37697b511ca05b75d12bf304A0D18B2862248, TVL: 0, est. time remaining: 52m55s
# Skipping pool Curve.fi Factory Plain Pool: AAVE Market Trading Bot (183/3794), polygon-0x7Ad57384090277F53F00560dB37aF182323384d6, TVL: 0, est. time remaining: 52m37s
# Skipping pool Curve.fi Factory Crypto Pool: wMATIC/EMI (184/3794), polygon-0x6bdD11CF1f64712b13F3897C1fDE57AB60002861, TVL: 0, est. time remaining: 52m19s
# Skipping pool fxUSD/fxncrvUSD (185/3794), arbitrum-0xC44b7e6Fe6b1c4700f313822F640596c01c2aA0B, TVL: 2.1333902704015815, est. time remaining: 52m1s
# Skipping pool dmtUSDT (186/3794), polygon-0x2226cD6F85332634ba9e244D9Ae137126d033541, TVL: 0, est. time remaining: 51m43s
# Skipping pool MATIC-S/USDC StarSeeds Protocol (187/3794), polygon-0xea7A3cc19B96691FBf3bbf2e4458D74b20f05147, TVL: 0, est. time remaining: 51m26s
# Skipping pool OP-ETH-WBTC (188/3794), optimism-0x3a1dD9E51777bA066fC641462c5Cfe1e8A4F7EB7, TVL: 0, est. time remaining: 51m8s
# Skipping pool FD/wfrxETH (189/3794), fraxtal-0x696dbfe3B5861120B2c4b7d5c28B1325E8b232F4, TVL: 3.6658999999999966, est. time remaining: 50m51s
# Skipping pool Curve.fi Factory Crypto Pool: CLever Locked CVX v2 Ini1.057 (190/3794), polygon-0xAc0345C5fabe186c113bD763c542a254fd8e96e1, TVL: 0, est. time remaining: 50m34s
# Processing crvUSD/USDT (191/3794), optimism-0xD1b30BA128573fcd7D141C8A987961b40e047BB6, est. time remaining: 50m18s
# Skipping pool Curve.fi Factory USD Metapool: pHBD/am3CRV (192/3794), polygon-0x63E271a9A8b8eAa47C684732770592320b6cdd80, TVL: 3.192696625767256, est. time remaining: 53m28s
# Skipping pool Curve.fi Factory USD Metapool: Curve Magic Internet Money (193/3794), fantom-0xaD9c5054CC31f8AA822AEb9247298D2Ecf48c5cf, TVL: 0, est. time remaining: 53m10s
# Processing LYU/USD (194/3794), ethereum-0x31b46c84e4fb0704dE69DBf4B054b5Cb81Aa3736, est. time remaining: 52m53s
# Skipping pool Curve.fi Factory Crypto Pool: PXBTRFLY/BTRFLY (195/3794), ethereum-0x38c60BcCa6AE0FDBD34466Fe8999BE15ee4e699e, TVL: 58.54879635932114, est. time remaining: 53m12s
# Skipping pool Curve.fi Factory Plain Pool: sLINK/LINK (196/3794), optimism-0x7C13F8fdbed6fa2dc567b2F7C85f116E0c5aB5c3, TVL: 0, est. time remaining: 52m55s
# Skipping pool Curve.fi Factory Crypto Pool: DeFi Franc (197/3794), ethereum-0x7f87a8b46A662131b87D29B2316B2d9CBD7e3B02, TVL: 0, est. time remaining: 52m38s
# Skipping pool Curve.fi Factory Plain Pool: EUSD (198/3794), fantom-0x4560262B27655C9C2978b030CCF7815777D7A3f1, TVL: 0, est. time remaining: 52m21s
# Skipping pool cgUSD/wcgUSD (199/3794), base-0x2ed6f166938e7b80B86AB493dC7D869dAd444bb8, TVL: 0, est. time remaining: 52m5s
# Processing fETH/ETH/xETH (200/3794), arbitrum-0xF7Fed8Ae0c5B78c19Aadd68b700696933B0Cefd9, est. time remaining: 51m48s
# Processing Curve USD-BTC-ETH (201/3794), polygon-0x92215849c439E1f8612b6646060B4E3E5ef822cC, est. time remaining: 52m26s
# Processing Blotix (202/3794), ethereum-0x126331661101057C3a5879ac6Af3F30CaC6c66e2, est. time remaining: 62m32s
# Skipping pool Curve.fi Factory USD Metapool: bBtc MARCO (203/3794), polygon-0xB00680Df0B1f3F39Ef1FbB9ec1AA0a7Fa14b4Cd9, TVL: 0, est. time remaining: 63m5s
# Processing Curve.fi Factory Plain Pool: yCRV (204/3794), ethereum-0x453D92C7d4263201C69aACfaf589Ed14202d83a4, est. time remaining: 62m45s
# Processing FLEET/MATIC (205/3794), ethereum-0x9A74FaAabb5B24e3340CF4332E9Be4C3AD82EbdE, est. time remaining: 63m36s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator TKN1/TKN2PL21312312 (206/3794), fantom-0x8E6692B6Fc3bCE7d5291C96ff02bA24E1a329C60, TVL: 0, est. time remaining: 64m44s
# Skipping pool Curve.fi Factory Plain Pool: AMIS+am3CRV (207/3794), polygon-0x19b4ff57Ccd45e7B0a22a454619921eF284460fe, TVL: 7.607755383014559, est. time remaining: 64m24s
# Skipping pool Curve.fi Factory Crypto Pool: USDC/WMATIC (208/3794), polygon-0x5DC6033426283E6973dbFD2Af70Eb69e2BA24b3C, TVL: 9.997050000010358e-07, est. time remaining: 64m4s
# Skipping pool Curve.fi Factory Plain Pool: fDAI/Stable test (209/3794), fantom-0xBd7D823eb731435472028faD5C50379b109d0e6D, TVL: 0, est. time remaining: 63m45s
# Skipping pool TUSDC/rTBL/V (210/3794), polygon-0xB995F9b14725e5F0Ebcd9dead95A71d31BE26df3, TVL: 0, est. time remaining: 63m25s
# Processing Curve.fi Factory Crypto Pool: swETH/frxETH (211/3794), ethereum-0x67e0bDbe0A2C5999A60D048f50e794218056b767, est. time remaining: 63m6s
# Skipping pool USDC/WBTC (212/3794), polygon-0x46dcAe44a3c3ef0982E75Cd50939f6CD30DB9004, TVL: 0, est. time remaining: 63m55s
# Skipping pool Curve.fi Factory Crypto Pool: FXS/ETH (213/3794), ethereum-0x03470B57B05089EE40c651dAC9E0387F1f3cb46f, TVL: 0, est. time remaining: 63m36s
# Processing ZERO2HERO (214/3794), arbitrum-0x2922cAb0d192afaad4a8561012202Bf539d0FC9E, est. time remaining: 63m17s
# Skipping pool Curve.fi Factory Plain Pool: crv/usdc (215/3794), optimism-0x143e5E81f608F89a2a18c4C82D180F6522471341, TVL: 0, est. time remaining: 64m38s
# Skipping pool Curve.fi Factory Plain Pool: CPI2Pool (216/3794), ethereum-0xC38cA214c7a82b1EE977232F045aFb6d425cfFf0, TVL: 0, est. time remaining: 64m19s
# Skipping pool MATIC-S by StarSeeds Protocol V1 (217/3794), polygon-0x10196C1871E52D2192d1aa675705F096aeF089E2, TVL: 0, est. time remaining: 64m0s
# Skipping pool Stabletokens (218/3794), polygon-0x54138E8b40Df7C3639e6A044dc57173EB830b972, TVL: 33.32136233551476, est. time remaining: 63m42s
# Skipping pool WBTC/MATIC (219/3794), polygon-0x8c65CeC3847ad99BdC02621bDBC89F2acE56934B, TVL: 0, est. time remaining: 63m23s
# Skipping pool Curve.fi Factory Plain Pool: Usd (220/3794), optimism-0xBdc3F64362DBC7C55eD86D1b3C434C715FA4928A, TVL: 0, est. time remaining: 63m5s
# Processing Curve.fi Factory Crypto Pool: LPXCVX/CVX (221/3794), ethereum-0x72725C0C879489986D213A9A6D2116dE45624c1c, est. time remaining: 62m47s
# Skipping pool Curve.fi Factory Crypto Pool: RAI/Meta3Crv (222/3794), ethereum-0xBE084cf7dB8fDfD6f17C041F958AbCcaF8C76603, TVL: 5.081181736656986e-18, est. time remaining: 63m17s
# Skipping pool Curve.fi Factory USD Metapool: tsc (223/3794), arbitrum-0x268C6c52B84A484Fe4A8f36311BF418d22036A86, TVL: 0, est. time remaining: 62m59s
# Skipping pool Curve.fi Factory Plain Pool: fx5eur (224/3794), polygon-0x87733C1F9516467A74AE5236Cf7d3Ef1600F4f71, TVL: 0, est. time remaining: 62m41s
# Skipping pool Curve.fi Factory USD Metapool: tusd-3pool (225/3794), ethereum-0xAc5f019a302c4c8caAC0a7F28183ac62E6e80034, TVL: 6.112023849376638, est. time remaining: 62m23s
# Skipping pool Curve.fi Factory Crypto Pool: cbETH/MAAT (226/3794), base-0x4A4EC09F69E586e8080aAe6B89101bb5Edf22e19, TVL: 3.97012e-15, est. time remaining: 62m5s
# Skipping pool dai/usdc (227/3794), fantom-0x17e06509067B762C288F3Ef1ff16f1f83B352edf, TVL: 0, est. time remaining: 61m48s
# Skipping pool Curve.fi Factory Plain Pool: PEPE/DAI (228/3794), polygon-0xc9d602ecfAA46d9420721eCfa329E2de4D132091, TVL: 0, est. time remaining: 61m31s
# Skipping pool Kuro (229/3794), polygon-0x2782056B3C804743f5cB2a044f1F8507665a4462, TVL: 0, est. time remaining: 61m13s
# Skipping pool Curve.fi Factory USD Metapool: MAIPool (230/3794), arbitrum-0xc5536d59D026BE19b4267810f43aC083cD607b64, TVL: 1.2703710473208478, est. time remaining: 60m56s
# Skipping pool HFXB/FRAX (231/3794), arbitrum-0xC9bF909acf287C64c4799D9F38eEaB4a3491C307, TVL: 0, est. time remaining: 60m40s
# Skipping pool WMATIC/NAD/USDC (232/3794), polygon-0x89ac565de4640Fd14EaBF95E346249598848EAf5, TVL: 0, est. time remaining: 60m23s
# Skipping pool fdgbfg (233/3794), base-0xb757fc30bB2d96782188C45B6eBf20defE165AC7, TVL: 0, est. time remaining: 60m6s
# Skipping pool CMPT/USDC (234/3794), ethereum-0x6c5c791B20faB13303E3624E074D80c92f06a58e, TVL: 0, est. time remaining: 59m50s
# Skipping pool Curve.fi Factory Plain Pool: EXIT (235/3794), polygon-0x8660108c91098F400C412529cf5BE3E0a9eeAC9d, TVL: 0, est. time remaining: 59m34s
# Skipping pool Curve.fi Factory Plain Pool: UglyPugly (236/3794), xdai-0xab033557743fbB4B9aF4C408B5267C0A4d28E15A, TVL: 0, est. time remaining: 59m18s
# Skipping pool Curve.fi Factory Crypto Pool: DONUT+FRAXBP (237/3794), ethereum-0x44358617cABC3312B3EBeDa4f7d75351bC45B114, TVL: 0, est. time remaining: 59m1s
# Skipping pool rTBLo/TUSDC (238/3794), polygon-0x8F043ddc578Da04c26763A572Cefe50263e710cc, TVL: 0, est. time remaining: 58m46s
# Processing Curve.fi Factory Crypto Pool: STG/USDC (239/3794), ethereum-0x3211C6cBeF1429da3D0d58494938299C92Ad5860, est. time remaining: 58m30s
# Skipping pool eth (240/3794), polygon-0x0F5c2743ba071Df77C2Fcd1F96d7e44c3572efED, TVL: 0, est. time remaining: 58m59s
# Skipping pool Curve.fi Factory Crypto Pool: MB$Matic (241/3794), polygon-0xE0Cb556eB1e99863613f6a0284E7eB1Ba5d38432, TVL: 1.2186798327140569, est. time remaining: 58m43s
# Skipping pool Curve.fi Factory Crypto Pool: crv (242/3794), polygon-0x945E8cAF58F4E529E392f900337cEB383ddc722F, TVL: 0, est. time remaining: 58m27s
# Processing Curve.fi Factory Plain Pool: Zunami zETH/frxETH (243/3794), ethereum-0xfC89b519658967fCBE1f525f1b8f4bf62d9b9018, est. time remaining: 58m12s
# Skipping pool Curve.fi Factory USD Metapool: CRV/GNO (244/3794), ethereum-0x172A54Ba45783049216F90F85FE5E5f6BC1c08fe, TVL: 0, est. time remaining: 58m40s
# Skipping pool Arbidaimat (245/3794), arbitrum-0x28260B823723D689F6ae01bbb0E4C4D8C9725082, TVL: 0, est. time remaining: 58m25s
# Skipping pool R  (246/3794), xdai-0x9aB48f4eE1811037a1b8bAc7fF232d6f9d6f6eD9, TVL: 0, est. time remaining: 58m10s
# Processing FRAX/DAI (247/3794), fraxtal-0x86d7FA03a70c428D3E28092F4509a16f16eC5b7C, est. time remaining: 57m55s
# Skipping pool nARS/USDC (248/3794), base-0x0fB2C121D75f4b64E24412AB9C7d0bc93FCdBD61, TVL: 0.4877529013148982, est. time remaining: 58m23s
# Skipping pool Curve.fi Factory USD Metapool: darkputziksusd (249/3794), optimism-0x7Eb9405e4f0Bc813ad4439FCa77BeEAD64c2bE26, TVL: 0, est. time remaining: 58m8s
# Skipping pool Curve.fi Factory Crypto Pool: fETH/DOLA (250/3794), ethereum-0x294B61367B4B36521291A6cc74f0B6037e4319D6, TVL: 2.9130215887155594e-18, est. time remaining: 57m53s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDC/USDT (251/3794), polygon-0x6aFf27de34C184dD288a2a0CF922A31baF3ED758, TVL: 0, est. time remaining: 57m38s
# Skipping pool Curve.fi Factory Plain Pool: KTA/ETH (252/3794), polygon-0x1BeB4686fD6798D33B45566AEbf2AC1940541120, TVL: 0, est. time remaining: 57m23s
# Skipping pool Curve.fi Factory USD Metapool: REUSD/2CRV (253/3794), arbitrum-0xF0f89e16c2a86fB81675A0A39701A8B688025146, TVL: 0.30348841823619394, est. time remaining: 57m9s
# Skipping pool Curve.fi Factory Plain Pool: Safe 2pool (254/3794), fantom-0x27F073ca3EEaad81A505B39ff73f95F59010B894, TVL: 0, est. time remaining: 56m54s
# Skipping pool Wetn (255/3794), polygon-0x9a439269c2779D5900ccFDE02f2fDF8F839E5fD1, TVL: 0, est. time remaining: 56m40s
# Skipping pool Wbtc (256/3794), polygon-0x15A7B920C2B4685d6db43C857788641613a37Dcc, TVL: 0, est. time remaining: 56m25s
# Processing Curve.fi Factory USD Metapool: DEI (257/3794), ethereum-0x6870F9b4DD5d34C7FC53D0d85D9dBd1aAB339BF7, est. time remaining: 56m11s
# Processing USDe-crvUSD (258/3794), ethereum-0xF55B0f6F2Da5ffDDb104b58a60F2862745960442, est. time remaining: 56m25s
# Processing USDtb-USDe (259/3794), ethereum-0x2D9Bf9C1beFd77C094461df615bdbE905895f7C6, est. time remaining: 57m5s
# Warning: no tvl data found for pool 0x2D9Bf9C1beFd77C094461df615bdbE905895f7C6 on chain ethereum for start period 1733961600, new pool?
# Skipping pool Curve.fi Factory Plain Pool: 3USD/USDR/MAI-Stable-Autocomp (260/3794), polygon-0x6f8b5D01c0b917028eadB0C56FD9392ce314b941, TVL: 0, est. time remaining: 57m18s
# Skipping pool Curve.fi Factory Crypto Pool: PAXG/USDC-v0 (261/3794), polygon-0x36fae0c62fE24C7Db4983af90c8901C1D7612cD4, TVL: 9.997050026253698e-07, est. time remaining: 57m4s
# Skipping pool sDOLA/USDz (262/3794), ethereum-0x432c5AdfB430238F46723B8DFc3B63097c0B38a2, TVL: 1.4071958053359404, est. time remaining: 56m50s
# Skipping pool Hellonhiday (263/3794), base-0xeE454138083b9B9714cac3c7cF12560248d76D6B, TVL: 0.029982688254354392, est. time remaining: 56m36s
# Processing Curve.fi Factory USD Metapool: wormhole v2 UST-3Pool (264/3794), ethereum-0xCEAF7747579696A2F0bb206a14210e3c9e6fB269, est. time remaining: 56m22s
# Processing Curve.fi Factory Plain Pool: crvUSD/MAI (265/3794), ethereum-0x1982Fe483f4bff067A2183c98fA231423d41E92B, est. time remaining: 56m49s
# Processing shezUSD/USDC (266/3794), ethereum-0x0418205C250A5Eb1F4ECAab5f7C76C08b57b5aaf, est. time remaining: 57m15s
# Skipping pool Curve.fi Factory Crypto Pool: PSL/ETH (267/3794), ethereum-0xd434eaf67bbA1903F61CdD3EDE6700caC74a5fF2, TVL: 0, est. time remaining: 58m7s
# Processing Curve.fi Factory USD Metapool: eUSD+FRAX/USDC (FRAXBP) (268/3794), ethereum-0xAEda92e6A3B1028edc139A4ae56Ec881f3064D4F, est. time remaining: 57m53s
# Skipping pool Curve.fi Factory USD Metapool: bTri MARCO (269/3794), polygon-0x20e3f345E229bE9CE08488Ae79E906955183EBAB, TVL: 6.633099265289256, est. time remaining: 58m18s
# Skipping pool Curve.fi Factory Plain Pool: yCRV (270/3794), ethereum-0x0309A528bBa0394dC4A2Ce59123C52E317A54604, TVL: 0, est. time remaining: 58m4s
# Processing Curve.fi Factory Plain Pool: ibEUR/sEUR (271/3794), ethereum-0x19b080FE1ffA0553469D20Ca36219F17Fcf03859, est. time remaining: 57m51s
# Skipping pool test3 (272/3794), polygon-0xDa6e0302801690890aD61c749bF09c3685543697, TVL: 0, est. time remaining: 58m16s
# Skipping pool Curve.fi Factory USD Metapool: Curve.fi Factory Pool: IN+FRAXBP (273/3794), arbitrum-0x32F24d6Ed1d8AB126E45a605ACc44AA1C3BB4e1C, TVL: 0, est. time remaining: 58m2s
# Skipping pool Curve.fi Factory USD Metapool: MTBT/3CRV (274/3794), ethereum-0x23afFc32cBe3c1a2a79376361A2D6f51CA7C9005, TVL: 33.528756669330235, est. time remaining: 57m48s
# Skipping pool Curve.fi Factory Plain Pool: wstTAO/wTAO (275/3794), ethereum-0x3f67dc2AdBA4B1beB6A48c30AB3AFb1c1440d35B, TVL: 0, est. time remaining: 57m35s
# Skipping pool Curve.fi Factory USD Metapool: USDT/DAI (276/3794), ethereum-0x3DcC3AC50cB42F7e443d7F548DD2c48EDaa8f59a, TVL: 0, est. time remaining: 57m21s
# Skipping pool Curve.fi Factory USD Metapool: Az USD (277/3794), polygon-0xe5C9C1782220138F871C48ebfE20be708f948d51, TVL: 0, est. time remaining: 57m8s
# Skipping pool Kuro (278/3794), polygon-0x33A0F8F4F1608bA033bb64EFFb53fD88c416a4C2, TVL: 0, est. time remaining: 56m54s
# Skipping pool Curve.fi Factory Crypto Pool: USDx/ETH (279/3794), base-0xa0D1d973E5C30382382E58fD3B31C4D96B2855aC, TVL: 0.07312, est. time remaining: 56m41s
# Skipping pool Curve.fi Factory Plain Pool: AA/EE (280/3794), fantom-0xF029C305dF2695fD55614B9be93260AbF5dAcC42, TVL: 0, est. time remaining: 56m28s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDC/USDT (281/3794), polygon-0xACC86D051dD45cc2d140762CeE6C512128a85dc0, TVL: 0, est. time remaining: 56m15s
# Skipping pool GG/POL (282/3794), polygon-0x4F656f5014eC1D6aa62f0a76a56e36c90C1d83eC, TVL: 0, est. time remaining: 56m2s
# Skipping pool Curve.fi Factory Plain Pool: CLever CVX (283/3794), ethereum-0x8c1de7a8F8852197B109Daf75A6fbB685C013315, TVL: 0, est. time remaining: 55m49s
# Processing eETH/ETH (284/3794), ethereum-0xeAC874aeD7761460dD4c89778Ba6db7d320911a8, est. time remaining: 55m36s
# Processing OpenMoney USD / USDCUSDT (285/3794), ethereum-0x42E03280C99579B048Bc001531Bf7015Bc252653, est. time remaining: 56m1s
# Skipping pool Curve.fi Factory USD Metapool: USK/FRAXBP (286/3794), ethereum-0x6D09C6513e620778632D36784F5C3b4b2309bd96, TVL: 1.9200477109271825, est. time remaining: 56m37s
# Skipping pool Curve.fi Factory Crypto Pool: USD1/USD91 (287/3794), polygon-0x6Aaf3cb86389bAa6CD61592C372f8bF06B2D48e4, TVL: 0, est. time remaining: 56m24s
# Skipping pool PNT/BAL (288/3794), polygon-0x16A3a047fC1D388d5846a73ACDb475b11228c299, TVL: 0, est. time remaining: 56m12s
# Skipping pool Curve.fi Factory Plain Pool: Safe 2pool (289/3794), fantom-0x3a93B1a8c565648379d2975dc9d3Cc1DA309F221, TVL: 0, est. time remaining: 55m59s
# Skipping pool Curve.fi Factory USD Metapool: 1INCH/ETH(TEST) (290/3794), ethereum-0xA4C231fA5a02992b740e6169F1fbfCD35d5719e1, TVL: 0, est. time remaining: 55m46s
# Processing Curve.fi Factory Crypto Pool: aCRV/CRV (291/3794), polygon-0xd9F354177Edd66E7A6669F33d0Ec64C14E153b38, est. time remaining: 55m34s
# Skipping pool Curve.fi Factory Plain Pool: C4C/DAI (292/3794), polygon-0x87e5433c5436E50D6C1FEf64371Fa1b8D4bfA19b, TVL: 0, est. time remaining: 55m46s
# Processing Curve.fi Factory Crypto Pool: CVG/FRAXBP (293/3794), ethereum-0xa7B0E924c2dBB9B4F576CCE96ac80657E42c3e42, est. time remaining: 55m33s
# Processing Curve.fi ETH/wstETH (294/3794), arbitrum-0x6eB2dc694eB516B16Dc9FBc678C60052BbdD7d80, est. time remaining: 55m45s
# Skipping pool Curve.fi Factory Crypto Pool: Litra WNFT PoolArchebase Test Nf (295/3794), polygon-0x524d913F42bC78e02c80e1E99439A3EEe3a005dd, TVL: 1.0358680000000002e-05, est. time remaining: 56m8s
# Skipping pool WFTM/USD (296/3794), fantom-0xEA3a08FEEC44C7F0F578FcbAC86c5962ED70e810, TVL: 0, est. time remaining: 55m56s
# Processing Curve.fi Factory Crypto Pool: crDAI/FRAXBP (297/3794), ethereum-0xce756104D10E1FDC60C9c32A84B1BB19712E52bA, est. time remaining: 55m43s
# Failed getting tvl data for pool Curve.fi Factory Crypto Pool: crDAI/FRAXBP (297/3794): apr 0, tvl 200.90086172109983, ethereum-0xce756104D10E1FDC60C9c32A84B1BB19712E52bA
# Processing Curve.fi Factory Crypto Pool: O/ETH (298/3794), ethereum-0xdc013262350d8aDd77b2e00D4fd48F87db916352, est. time remaining: 55m55s
# Skipping pool mio (299/3794), polygon-0x1d5385D9262972DE59b37F8D34c084137eae7EA3, TVL: 0, est. time remaining: 56m6s
# Skipping pool cvxFxs/Fxs (300/3794), fraxtal-0xbCdB3980De7f477263A6E49fc75A38DCc1c0e67a, TVL: 0, est. time remaining: 55m54s
# Skipping pool Curve.fi Factory Crypto Pool: AlgorithmX (301/3794), polygon-0xE01Daf5A0Eda822221bd71dd7d96b37FF1581697, TVL: 0, est. time remaining: 55m42s
# Skipping pool Curve.fi Factory Pool: LATAM Peso (302/3794), polygon-0xcdb4f70AD54940CFE42f4A74E34C2a965ae66931, TVL: 0, est. time remaining: 55m30s
# Skipping pool Curve.fi Factory Plain Pool: CLever Locked CVX Test100 (303/3794), polygon-0x8cC4E7bEEf42887946C91e94a33fbe133daE4186, TVL: 0, est. time remaining: 55m18s
# Skipping pool Curve.fi Factory Plain Pool: 4crv (304/3794), polygon-0xFd185a4CE6EA5386c248936621E5484cd6F752D9, TVL: 0, est. time remaining: 55m6s
# Skipping pool crvUSD/OD ForexPreset (305/3794), arbitrum-0x5e5Bf6647AeD285EB1305b99dAeD4502D3af7350, TVL: 0, est. time remaining: 54m54s
# Skipping pool USDC/BONK (306/3794), polygon-0x0cB950575fa92BC74164DE98eA1Dc069aB23e590, TVL: 0, est. time remaining: 54m42s
# Skipping pool Curve.fi Factory Plain Pool: Gold Based (307/3794), polygon-0xCBE4F9714b10d5cBA9f0bBb6285B3b71725fE258, TVL: 0, est. time remaining: 54m31s
# Skipping pool Curve.fi Factory Crypto Pool: STARV1-USDR (308/3794), polygon-0x44F8E3C20F65587D7E2e5C8CA5d935F1D9b01CE9, TVL: 9.006765769444188e-05, est. time remaining: 54m19s
# Skipping pool Curve.fi Factory Plain Pool: USDC/USDT (309/3794), polygon-0xcf6234491CAA85850f4483189ae295E731D08Ca7, TVL: 0, est. time remaining: 54m8s
# Processing LMDA/ETH (310/3794), ethereum-0x6EdBF3adA7B6D9524c3248955538D573AAE449CF, est. time remaining: 53m56s
# Skipping pool Curve.fi Factory Plain Pool: TOMB-wFTM (311/3794), fantom-0x36586206bFc13ED520597b3DAE1313C8b1496388, TVL: 0.023, est. time remaining: 54m7s
# Skipping pool Curve.fi Factory USD Metapool: EURe/3CRV (312/3794), xdai-0x149bF4A7e0561D38Db264B973225dAA7209A7d20, TVL: 0, est. time remaining: 53m56s
# Skipping pool ezpz dynamic (313/3794), ethereum-0x0F5c2743ba071Df77C2Fcd1F96d7e44c3572efED, TVL: 0, est. time remaining: 53m45s
# Skipping pool Curve.fi Factory Crypto Pool: COW/ETH (314/3794), ethereum-0x61FDdD212F02F46fEa58DDfE3BE92D07B1249bCC, TVL: 0, est. time remaining: 53m34s
# Processing mwstETH-WPUNKS-30/wstETH (315/3794), ethereum-0x89d4ED54caE922264B9C82Cfc38E3952F5Fe88DD, est. time remaining: 53m22s
# Skipping pool Curve.fi Factory Crypto Pool: CVX_LOOKS_Pair (316/3794), ethereum-0x408CbC416DBF4168143B011bF5C297DA82cE03ed, TVL: 0, est. time remaining: 53m33s
# Processing Curve.fi Factory Plain Pool: ApeUSD-FRAX (317/3794), ethereum-0x1977870a4c18a728C19Dd4eB6542451DF06e0A4b, est. time remaining: 53m22s
# Skipping pool Curve.fi Factory USD Metapool: darkputziksusd (318/3794), optimism-0xb327d8D0372034EC53BBC07E2D2899B18B0131C0, TVL: 0, est. time remaining: 53m33s
# Skipping pool Curve.fi Factory USD Metapool: L3USD + 2pool (319/3794), fantom-0x377d52CDec942F4C139c7394E5b3d6893A8728D8, TVL: 0, est. time remaining: 53m22s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDC/USDT (320/3794), polygon-0xD16C34DBb28F881FbEfEbfBec770b8F6E784B100, TVL: 0, est. time remaining: 53m11s
# Skipping pool Curve.fi Factory Plain Pool: SYNTHWBTC (321/3794), optimism-0x2dB56A985293A5EB637a4167f979276524082042, TVL: 0.0030191059112262496, est. time remaining: 53m0s
# Skipping pool Curve.fi Factory Plain Pool: sUSD/LUSD (322/3794), optimism-0x1522b6CcD111BcbF37CfE088F3594B89a4784968, TVL: 0, est. time remaining: 52m50s
# Processing Curve.fi Factory USD Metapool: USDDFRAXBP (323/3794), ethereum-0x4606326b4Db89373F5377C316d3b0F6e55Bc6A20, est. time remaining: 52m39s
# Skipping pool Curve.fi Factory Crypto Pool: wftm/usdc (324/3794), fantom-0x6D1C8e33c9F45cFd41135705528afF3d2010498F, TVL: 1.4933403656309536, est. time remaining: 53m0s
# Processing Curve.fi Factory USD Metapool: Silver (325/3794), fantom-0xf864fED8ACFE622d5f92568A0cD50A625CaFeeFE, est. time remaining: 52m50s
# Skipping pool stARB/ARB (326/3794), arbitrum-0x011E998D2d794424DE95935d55a6Ca81822Ecb2b, TVL: 0, est. time remaining: 53m0s
# Skipping pool USDC/axlUSDC (327/3794), fraxtal-0xBD43A29b40efa5C1862c9E2590072637aE024cc8, TVL: 0, est. time remaining: 52m50s
# Skipping pool Curve.fi Factory USD Metapool: NEF/USDT (328/3794), polygon-0x96903FBE71447d16D3D922F3Bc7839cE3993ad5d, TVL: 0, est. time remaining: 52m39s
# Skipping pool AUSTROLAB (329/3794), arbitrum-0xA26cD2c09dD169a3dD64F3896e00298fbB4BD0a7, TVL: 0, est. time remaining: 52m29s
# ...
# Skipping pool Curve.fi Factory USD Metapool: axlUST + 3Pool (3685/3794), polygon-0x6f73928cD742aFCC7254abB6f632b1a00C05790B, TVL: 0, est. time remaining: 1m9s
# Processing Curve.fi Factory Crypto Pool: Spectra-PT/IBT (3686/3794), ethereum-0xBCE4E65b4A68Ac2095C7747992250D2075d82edc, est. time remaining: 1m9s
# Processing Curve.fi Factory Plain Pool: frxETHpETH (3687/3794), ethereum-0x320B564Fb9CF36933eC507a846ce230008631fd3, est. time remaining: 1m8s
# Skipping pool Curve.fi Factory Plain Pool: renUSDC (3688/3794), fantom-0xAD6D5548c45b1b198A4A563Cba1C3D384AFc44C6, TVL: 0, est. time remaining: 1m8s
# Processing EURe/EURC (3689/3794), xdai-0x845C8bc94610807fCbaB5dd2bc7aC9DAbaFf3c55, est. time remaining: 1m7s
# Processing RestakeFi rmETH/mETH (3690/3794), ethereum-0xDD4316c777a2295D899ba7ad92E0eFa699865f43, est. time remaining: 1m6s
# Skipping pool USD/EUR (3691/3794), polygon-0xCA8C228aEb376949d072bF23347A062f76d64ad3, TVL: 0, est. time remaining: 1m6s
# Skipping pool Curve.fi Factory USD Metapool: wbtc (3692/3794), polygon-0x7fc15ad43ad327662D0aEF3b250741974750E5Ea, TVL: 0, est. time remaining: 1m5s
# Skipping pool CrossCurve crvUSDT (3693/3794), fantom-0xf211FAeB742c6f7c4b0a97b7bBc98393BfefEF53, TVL: 0, est. time remaining: 1m4s
# Processing sol.ibcUSDT/USDT (3694/3794), ethereum-0x8655521A3B237872707B3eC001c4B8C991A63724, est. time remaining: 1m4s
# Skipping pool Curve.fi Factory Crypto Pool: Pos (3695/3794), polygon-0x72DEa814d44Ecc0e771928a19BACf78638f996c3, TVL: 0, est. time remaining: 1m3s
# Skipping pool Curve.fi Factory Crypto Pool: LargeA (3696/3794), polygon-0xD3e95868154C86c4260E7B663b749bec27284793, TVL: 0, est. time remaining: 1m3s
# Skipping pool Curve.fi Factory USD Metapool: PUSd (3697/3794), ethereum-0xeb07FcD7A8627281845ba3aCbed24435802d4B52, TVL: 0, est. time remaining: 1m2s
# Processing sdFXS/FXS (3698/3794), fraxtal-0x3df1658e3E76d14eF3C4d410829EA7575bB83B9B, est. time remaining: 1m1s
# Skipping pool Curve.fi Factory Plain Pool: gTrade gDAI/DAI (3699/3794), arbitrum-0x7C01B05DDE0FbB38e2902a9fC3447BEb877d9455, TVL: 0, est. time remaining: 1m1s
# Skipping pool Curve.fi Factory Plain Pool: KPAPA/WMATIC (3700/3794), polygon-0x6a8a65883C212aD0900373422E025f5762055646, TVL: 0, est. time remaining: 1m0s
# Skipping pool Curve.fi Factory Plain Pool: TT/USD (3701/3794), polygon-0x3018Fa476030Db01914536b04B2108F73f613D6B, TVL: 0, est. time remaining: 0m59s
# Processing Curve.fi Factory Plain Pool: agEUR-jEUR (3702/3794), polygon-0x2fFbCE9099cBed86984286A54e5932414aF4B717, est. time remaining: 0m59s
# Skipping pool Curve.fi Factory Plain Pool: crvUSD-USDLR (3703/3794), ethereum-0x602a9Abb10582768Fd8a9f13aD6316Ac2A5A2e2B, TVL: 0, est. time remaining: 0m58s
# Skipping pool Curve.fi Factory Plain Pool: USD1/pUSDT (3704/3794), polygon-0x3f87d3258dBF9580Db405Ff8F05aB2704E31F192, TVL: 0, est. time remaining: 0m57s
# Skipping pool rsTAO/wTAO (3705/3794), ethereum-0x2A5AC0B7f2CA61B8b1ea8Cff2d9a8624074E7caa, TVL: 0, est. time remaining: 0m57s
# Skipping pool Curve.fi Factory Plain Pool: EXIT (3706/3794), polygon-0x83f60431108CCBe6d6d8d0c442905E5435f7257D, TVL: 0, est. time remaining: 0m56s
# Skipping pool Curve.fi Factory Plain Pool: SDP/DAI (3707/3794), polygon-0x0b37581ccd14B5073704445cB9e5dD10A09795a5, TVL: 0, est. time remaining: 0m55s
# Processing Curve.fi Factory USD Metapool: alUSDFRAXBP (3708/3794), ethereum-0xB30dA2376F63De30b42dC055C93fa474F31330A5, est. time remaining: 0m55s
# Processing Curve.fi Factory Crypto Pool: asdCRV (3709/3794), polygon-0x5D8c2b31e80a35E211D51e62B1c7FB70322cbf25, est. time remaining: 0m54s
# Processing Dola/fxUSD (3710/3794), ethereum-0x189B4e49B5cAf33565095097b4B960F14032C7D0, est. time remaining: 0m54s
# Skipping pool Curve.fi Factory Crypto Pool: Spectra-PT/IBT (3711/3794), ethereum-0x9429E06FFD09Cf97007791B8bF3845171f1425E8, TVL: 0, est. time remaining: 0m53s
# Processing Curve.fi Factory USD Metapool: multiBTC+WBTC/sBTC (3712/3794), ethereum-0x2863a328A0B7fC6040f11614FA0728587DB8e353, est. time remaining: 0m52s
# Skipping pool Curve.fi Factory Crypto Pool: INV/ETH (3713/3794), ethereum-0x1DF0Bae5add689D6BE57aC6fd18b1e4a27B4498B, TVL: 0, est. time remaining: 0m52s
# Skipping pool Curve.fi Factory Plain Pool: 2080BAL/TETUBAL (3714/3794), polygon-0xCE400d027b3486634Ff20f383A26aa01B96A79f4, TVL: 0, est. time remaining: 0m51s
# Skipping pool Curve.fi Factory Plain Pool: CurveWmatic (3715/3794), polygon-0x43910e07554312FC7A43e4B71D16A72dDCB5Ec5F, TVL: 64.11807697278148, est. time remaining: 0m50s
# Skipping pool Ensuro/USDC (3716/3794), polygon-0x28F209844029755FC563c1bD4FD21f42DC7CE0e4, TVL: 0, est. time remaining: 0m50s
# Skipping pool USDT/MATIC (3717/3794), polygon-0xC2E5E6EDdCA0f09529Bd26733bF9Bedd4186F2Ef, TVL: 0, est. time remaining: 0m49s
# Skipping pool alXAI/XAI (3718/3794), arbitrum-0xF36e9F19a47FA7ae7dafc8e9000e9aD8E553eC74, TVL: 0, est. time remaining: 0m48s
# Skipping pool Reusdcdedai (3719/3794), polygon-0xbB614b9e86a1cCb162A56DB18F681e4f67ee45DC, TVL: 0, est. time remaining: 0m48s
# Skipping pool USD MXAPEMX (3720/3794), base-0x8f78E0671f238c06fd07B947b7981cCc092986b2, TVL: 1.9705189030058214, est. time remaining: 0m47s
# Skipping pool crvUSD/USDT/XA9 (3721/3794), polygon-0x0D149c9A4c51472A4DCFd9607AE70E7e426ceB3a, TVL: 4.486487134884987, est. time remaining: 0m46s
# Processing Curve.fi Factory Crypto Pool: TOKE/ETH (3722/3794), ethereum-0xe0e970a99bc4F53804D8145beBBc7eBc9422Ba7F, est. time remaining: 0m46s
# Skipping pool Curve.fi Factory Crypto Pool: GROSH/LMRT (3723/3794), polygon-0x8c95873fae9234b601e8177C32eF19CB74Fbee34, TVL: 0, est. time remaining: 0m45s
# Processing Curve.fi Factory Plain Pool: 2eur (EURe) (3724/3794), polygon-0x2F3E9CA3bFf85B91D9fe6a9f3e8F9B1A6a4c3cF4, est. time remaining: 0m44s
# Processing GMAC/ETH/USDC (3725/3794), ethereum-0x80441ed630A10f2A36955c993c2D45bd9F848AF5, est. time remaining: 0m44s
# Skipping pool Curve.fi Factory Crypto Pool: IRON$ (3726/3794), polygon-0xfBD717f818c414174c5999C42fF94d6eE218A323, TVL: 0.042452625720873924, est. time remaining: 0m43s
# Processing stMatic/MaticX V3 (3727/3794), polygon-0x7243Bd9E4aCe21DBeB4c11E7916505B89Ad6B107, est. time remaining: 0m43s
# Processing Curve.fi Factory Plain Pool: Overnight/Curve (3728/3794), base-0xda3de145054ED30Ee937865D31B500505C4bDfe7, est. time remaining: 0m42s
# Processing pyUSD/fxUSD (3729/3794), ethereum-0xd6982da59F1D26476E259559508f4135135cf9b8, est. time remaining: 0m41s
# Skipping pool Curve.fi Factory Plain Pool: jJPY+JPYC (3730/3794), polygon-0x1F93F301F7DFb0c301199DB35062945bE35d0aE6, TVL: 0, est. time remaining: 0m41s
# Skipping pool Toppa (3731/3794), base-0xBA272A4b7Eb646484669351bd1E4f6908e824c5f, TVL: 0, est. time remaining: 0m40s
# Skipping pool Great (3732/3794), base-0xbC3705b2bfD42d38e8FA2c8EFDC3Fdda645C3b2a, TVL: 0.19999860000000003, est. time remaining: 0m39s
# Skipping pool USD-S/ETH - StarSeeds Protocol  (3733/3794), polygon-0x9A74FaAabb5B24e3340CF4332E9Be4C3AD82EbdE, TVL: 0, est. time remaining: 0m39s
# Processing Curve.fi Factory Crypto Pool: PAR/USDC (3734/3794), ethereum-0xDaD60C5B748306BA5a0c9a3c3482A8D1153DAd2a, est. time remaining: 0m38s
# Skipping pool sfrxETH - sFRAX (3735/3794), fraxtal-0x0b9036F639f4E7498aFA34751a2710159373fC7B, TVL: 0, est. time remaining: 0m38s
# Processing sfrxETH/AsfrxETH (3736/3794), ethereum-0x76b0F0C02008e2Fb3f43C809629568e3147A57a0, est. time remaining: 0m37s
# Skipping pool MININGCOMPANY (3737/3794), base-0xDa6097361B32488eaDc9664A3F41938e2200b68B, TVL: 0, est. time remaining: 0m36s
# Skipping pool Curve.fi Factory USD Metapool: LUSD (3738/3794), arbitrum-0x9C907Ee3bC1da92095a81B806Ae8cBA6c597703c, TVL: 0.2016079187963572, est. time remaining: 0m36s
# Skipping pool B-01-22-21 (3739/3794), polygon-0x9c7809c813BcC67e288c56d5Ce5e0225996bFcD2, TVL: 0, est. time remaining: 0m35s
# Processing coveYFI/YFI (3740/3794), ethereum-0xa3f152837492340dAAf201F4dFeC6cD73A8a9760, est. time remaining: 0m34s
# Skipping pool 2PoolB (3741/3794), fantom-0x119806f0e93a213029b599D7bBAE50bD965C2cC4, TVL: 0, est. time remaining: 0m34s
# Skipping pool super (3742/3794), base-0xC65d17166d0894A926AFE30885a9fb713E7C39ee, TVL: 0, est. time remaining: 0m33s
# Skipping pool Curve.fi Factory Plain Pool: StarSeeds Protocol STAR Dollars (3743/3794), polygon-0x9d3f4d8913a0006ba0222c0ea3D23F2BCB63761a, TVL: 0, est. time remaining: 0m32s
# Skipping pool sBTC/WETH (3744/3794), optimism-0x6DC311B6633989e790783AE9cB4bD88948aF9E0E, TVL: 0, est. time remaining: 0m32s
# Skipping pool Kuro (3745/3794), polygon-0x38A947189Da329235f94d9037d179A7003244460, TVL: 0, est. time remaining: 0m31s
# Skipping pool crvUSD/CJPY (3746/3794), ethereum-0x0fF26A978A61d40F6591fc700EF878E96aF6C2C0, TVL: 0, est. time remaining: 0m30s
# Skipping pool Curve.fi Factory Crypto Pool: MATIC/WBTC (3747/3794), polygon-0xEC5AFc9590964f2fA0FeED54f0fBB2A34480908D, TVL: 21.80427676659604, est. time remaining: 0m30s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator USDT/USDC (3748/3794), polygon-0xc0097f5a174287D16519f759Eb87f60bfde209AB, TVL: 0, est. time remaining: 0m29s
# Skipping pool crvUSD/HAI (3749/3794), optimism-0x5850ddA4235B04765b09710Eb4DcDc10c395E650, TVL: 0, est. time remaining: 0m28s
# Skipping pool Curve.fi Factory Plain Pool: Iron_Cloud TOR/DAI-LP (3750/3794), fantom-0xc87dc1E718E5dAbB438e69E8F3A1a6979dd46868, TVL: 0, est. time remaining: 0m28s
# Skipping pool www (3751/3794), polygon-0x6EdBF3adA7B6D9524c3248955538D573AAE449CF, TVL: 0, est. time remaining: 0m27s
# Processing Curve.fi Factory Crypto Pool: OHM/ETH (3752/3794), ethereum-0x6ec38b3228251a0C5D491Faf66858e2E23d7728B, est. time remaining: 0m27s
# Processing 2BTC-ng (3753/3794), arbitrum-0x186cF879186986A20aADFb7eAD50e3C20cb26CeC, est. time remaining: 0m26s
# Skipping pool Curve.fi Factory USD Metapool: sUSD/CRV (3754/3794), optimism-0x44A3e148fdE06FB56CEF741CeB886d37A25430b8, TVL: 0, est. time remaining: 0m25s
# Skipping pool Curve.fi Factory Crypto Pool: ETH+/pxETH (3755/3794), ethereum-0xaEC7dB1bE1be14af32d00BBF31487a03cb6925eD, TVL: 61.25024502242728, est. time remaining: 0m25s
# Processing Curve.fi Factory Plain Pool: 2eur (PAR) (3756/3794), polygon-0x0f110c55EfE62c16D553A3d3464B77e1853d0e97, est. time remaining: 0m24s
# Skipping pool inwstETHs/wstETH (3757/3794), ethereum-0x5Fc50C99E175DFeB8Faa7613e050645583Ac1501, TVL: 93.82641896590395, est. time remaining: 0m23s
# Skipping pool Curve.fi Factory Plain Pool: alETH/frxETH (3758/3794), ethereum-0x97Ba76a574bC5709b944bB1887691301c72337Ca, TVL: 3.938150335929322, est. time remaining: 0m23s
# Skipping pool Curve.fi Factory Crypto Pool: Concentrator TKN2/PLL-f (3759/3794), fantom-0x36fae0c62fE24C7Db4983af90c8901C1D7612cD4, TVL: 0, est. time remaining: 0m22s
# Skipping pool Curve.fi Factory Crypto Pool: eUSD/USDC (3760/3794), ethereum-0x1cDF9650cd7c47dCfe63159924440E7A439B91f4, TVL: 9.994620000019881e-07, est. time remaining: 0m21s
# Skipping pool Curve.fi Factory Plain Pool: Space Station (3761/3794), polygon-0xe8f661f157b0E3a1acbF2D0aAE8Ac07436490667, TVL: 0, est. time remaining: 0m21s
# Processing ZAI/sZAI (3762/3794), ethereum-0x53ad9268a66Cef20A4c458D759EEe5AA55Be1140, est. time remaining: 0m20s
# Warning: no tvl data found for pool 0x53ad9268a66Cef20A4c458D759EEe5AA55Be1140 on chain ethereum for start period 1733961600, new pool?
# Skipping pool Curve.fi Factory Plain Pool: agEUR/EURT (3763/3794), polygon-0xCEFc3669B7Af16E19579D76a2a8379B69A70141a, TVL: 0, est. time remaining: 0m19s
# Skipping pool Curve.fi Factory USD Metapool: qxccrv (3764/3794), arbitrum-0x7F2d1C7b8911901de7c9785d6E7A7A10d8dEff66, TVL: 0, est. time remaining: 0m19s
# Skipping pool Curve.fi Factory Crypto Pool: xn456 (3765/3794), polygon-0x001C0C30fE53241f6F969223869D35a345f20C03, TVL: 2.2146474275850685, est. time remaining: 0m18s
# Skipping pool Curve.fi Factory Plain Pool: sETH/frxETH (3766/3794), ethereum-0x663aC72a1c3E1C4186CD3dCb184f216291F4878C, TVL: 53.0007345106411, est. time remaining: 0m18s
# Processing wenUSD/USDT/USDC (3767/3794), ethereum-0x7f4D00Eac812F056d1ec5Ef6834Bb5a656B0da3A, est. time remaining: 0m17s
# Skipping pool Curve.fi Factory USD Metapool: US/3CRV (3768/3794), ethereum-0x188aBea43270791F96dC9209e239f7B79E61203B, TVL: 0, est. time remaining: 0m16s
# Skipping pool SETH/ETH (3769/3794), arbitrum-0xfb8b95Fb2296a0Ad4b6b1419fdAA5AA5F13e4009, TVL: 0, est. time remaining: 0m16s
# Skipping pool Curve.fi Factory Crypto Pool: EURS/FRAXBP (3770/3794), ethereum-0x4CC9385d9909d2Bf529A4c1E847Dc4eE01F4927A, TVL: 4.735031933659221, est. time remaining: 0m15s
# Skipping pool Curve.fi Factory Plain Pool: sdCRV (3771/3794), ethereum-0x737bC004136f66aE3F8fd5a1199e81c18388097B, TVL: 0, est. time remaining: 0m14s
# Processing weETH/WETH-ng (3772/3794), ethereum-0xDB74dfDD3BB46bE8Ce6C33dC9D82777BCFc3dEd5, est. time remaining: 0m14s
# Processing Curve.fi Factory USD Metapool: 3CRV/cealv (3773/3794), ethereum-0x8D35ECe39566d65d06c9207C571934DD3C3a3916, est. time remaining: 0m13s
# Failed getting tvl data for pool Curve.fi Factory USD Metapool: 3CRV/cealv (3773/3794): apr 0.43, tvl 332.038761195564, ethereum-0x8D35ECe39566d65d06c9207C571934DD3C3a3916
# Skipping pool USDC.e/USDC (3774/3794), arbitrum-0xFE5b777AC52f39A2F61C618f77099933EeEb633b, TVL: 2.0033365301924473, est. time remaining: 0m12s
# Skipping pool Curve.fi Factory Plain Pool: a2crv (3775/3794), polygon-0x6c9fbb58Bf6c0dde983465b070dC34f66C3849dF, TVL: 0, est. time remaining: 0m12s
# Skipping pool Wftm/usdc (3776/3794), fantom-0xDefAAf9980f88D2507aD9598bcF95155E521E319, TVL: 0, est. time remaining: 0m11s
# Skipping pool Curve.fi Factory Crypto Pool: MATIC/FLEET (3777/3794), ethereum-0x799D141e83D88996C48B98A4f8EB3D96AB422DD3, TVL: 19.832085501450265, est. time remaining: 0m10s
# Skipping pool tst (3778/3794), ethereum-0x2530A8Db43963F97CBb5a4dAaB5aDB79b1967621, TVL: 0, est. time remaining: 0m10s
# Skipping pool Curve.fi Factory Crypto Pool: USV/FRAXBP (3779/3794), ethereum-0x50e29cD32BEdf8ADF6C58cF0f8F2c64CB98C62ac, TVL: 49.202034268922404, est. time remaining: 0m9s
# Skipping pool Crv/gho/vt (3780/3794), ethereum-0x9A267cbCB7B43478c28e66d4D15D14045e3A4D03, TVL: 2.465490433624331, est. time remaining: 0m9s
# Skipping pool Arbuytryum (3781/3794), arbitrum-0x7dd2aa3A99414e25c43b9C7324ae8fAB71A7C083, TVL: 0, est. time remaining: 0m8s
# Skipping pool Curve.fi Factory USD Metapool: ungrund (3782/3794), polygon-0x0f485C761158974470fC803463c36642fb647141, TVL: 0, est. time remaining: 0m7s
# Skipping pool wwCADC (3783/3794), polygon-0xE6bCe0647ED06d498219d42Fe19B3D6D1726C659, TVL: 0, est. time remaining: 0m7s
# Skipping pool fxUSD/USDC.e (3784/3794), arbitrum-0x88E3B6f0c4293Fb74c7249aC3D77Ea83688DC378, TVL: 0, est. time remaining: 0m6s
# Skipping pool Curve.fi Factory Plain Pool: 2eur (agEUR) (3785/3794), optimism-0x43FD45DA6D1E68aE5beaaeBDD634F16b9FA806da, TVL: 0, est. time remaining: 0m5s
# Skipping pool Ethenium (3786/3794), ethereum-0x320e9f0B4040df33B36ED8235865aE7e154BcC25, TVL: 0, est. time remaining: 0m5s
# Skipping pool Curve.fi Factory USD Metapool: thUSD (3787/3794), ethereum-0x8d6ed9bA971CF08441fc542AcECd35f691Afa752, TVL: 0, est. time remaining: 0m4s
# Skipping pool Curve.fi Factory Plain Pool: smc/usdc (3788/3794), polygon-0x918a456616290ee83c31619fD3717db61FbCf351, TVL: 0, est. time remaining: 0m3s
# Processing dgnETH/ETH+ (3789/3794), ethereum-0x5bA541585D6297B756F08B7c61a7E37752123B4F, est. time remaining: 0m3s
# Skipping pool sBTC/weth (3790/3794), optimism-0xEa44df3C58bC179D4B40aacd2ac00e60B3502cdf, TVL: 0.9142779042460188, est. time remaining: 0m2s
# Processing Curve.fi ETH/aETH (3791/3794), ethereum-0xA96A65c051bF88B4095Ee1f2451C2A9d43F53Ae2, est. time remaining: 0m1s
# Skipping pool Curve.fi Factory USD Metapool: Optimium Dollar (3792/3794), optimism-0x47e1261b7c931dF52cf37c57040B2D2DCfc2fc63, TVL: 0, est. time remaining: 0m1s
# Processing Curve.fi Factory Plain Pool: 2jpy (3793/3794), polygon-0xE8dCeA7Fb2Baf7a9F4d9af608F06d78a687F8d9A, est. time remaining: 0m0s
# Skipping pool ESXd/USD (3794/3794), polygon-0xeF16eEdAe685b32F9AC95441d1c378d6F5abF68d, TVL: 0, est. time remaining: 0m0s

# %% [markdown]
# #### Optional, save/load pulled data as csv files

# %%
# SAVE

with open(f'good-pool-data-{epoch_start}-{epoch_end}.txt', 'w') as file:
    file.write(str(good_pool_data))

formatted_pool_data = good_pool_data.copy()

# %%
# LOAD

with open(f'good-pool-data-{epoch_start}-{epoch_end}.txt', 'r') as file:
    formatted_pool_data = literal_eval(file.read())

good_pool_data = formatted_pool_data.copy()

# %% [markdown]
# #### Data Processing

# %%
# Separated data acquisition and processing to make it easier to re-run the processing step
# This processing step may take a few minutes to run the first time, as it has to create a dict of coin image URLs if they exist

# Copy the pool data so we still have the original data
formatted_pool_data = good_pool_data.copy()

# Process each pool in the data set
i = 0
for pool in formatted_pool_data:
    i += 1
    print(f"Processing pool {i} of {len(formatted_pool_data)}")
    
    chain = pool['blockchainId']
    address = pool['address']

    pool_volume = volume_data[chain][address]
    
    pool['assetType'] = 'other'
    coin_str = ""
    pool['crvusd_pool'] = False

    for coin in pool['coins']:
        coin_symbol = coin['symbol'].lower()
        
        # see if it's a crvusd pool
        if (coin_symbol == 'crvusd' or coin_symbol == 'scrvusd') and pool['type'] == 'stableswap':
            pool['crvusd_pool'] = True

        # see if it's a stableswap pool with a known asset type
        if coin_symbol in POOL_TYPES_ASSET_DICT and pool['type'] == 'stableswap':
            pool['assetType'] = POOL_TYPES_ASSET_DICT[coin_symbol]
        
        # see if it's a cryptoswap pool with crv
        elif coin_symbol in POOL_TYPES_ASSET_DICT and pool['type'] == 'cryptoswap' and POOL_TYPES_ASSET_DICT[coin_symbol] == 'crv':
            pool['assetType'] = 'crv'

        coin_image_html, coin_image_html_dict = get_coin_html(coin, chain, coin_image_html_dict, "pool")
        coin_str += coin_image_html

    # If there's more than 4 coins in the pool, just show the pool name
    if len(pool['coins']) > 4:
        coin_str = pool['name']
    
    # make the pool name link
    try:
        # if the chain is xdai, the link to the frontend should actually be the second link in the array, first link is broken
        if chain == 'xdai':
            pool['nameLink'] = make_name_link_html(coin_str, pool['poolUrls']['deposit'][1])
        else:
            pool['nameLink'] = make_name_link_html(coin_str, pool['poolUrls']['deposit'][0])
    except:
        # if there's no deposit link, just show the pool name
        pool['nameLink'] = make_name_link_html(coin_str)

    # make network with icon
    pool['chainWithIcon'] = make_chain_with_icon_html(chain)

    # calculate APYs and stats
    pool['lstApy'] = pool_volume['includedApyPcentFromLsts']
    pool['tradingApy'] = pool_volume['latestWeeklyApyPcent'] - pool['lstApy']
    pool['baseWeeklyApy'] = pool_volume['latestWeeklyApyPcent']
    pool['liqUtilizationDaily'] = 0
    pool['liqUtilizationDaily'] = pool['volumeUsd'] / pool['tvlUsd'] * 100 / 7
    pool['prevLiqUtilizationDaily'] = 0
    pool['newPool'] = False

    # If we have no previous TVL data, assume it's a new pool
    if pool['prevTvlUsd'] != 0:
        pool['prevLiqUtilizationDaily'] = pool['prevVolumeUsd'] / pool['prevTvlUsd'] * 100 / 7
    else:
        pool['newPool'] = True

    # make rewards APYs for the pool
    pool['rewardsMinApy'] = 0
    pool['rewardsMaxApy'] = 0
    if 'gaugeCrvApy' in pool and pool['gaugeCrvApy'] != [] and pool['gaugeCrvApy'] != [None, None]:
        pool['rewardsMinApy'] += pool['gaugeCrvApy'][0]
        pool['rewardsMaxApy'] += pool['gaugeCrvApy'][1]

    if 'gaugeRewards' in pool and pool['gaugeRewards'] != []:
        for reward in pool['gaugeRewards']:
            pool['rewardsMinApy'] += reward['apy']
            pool['rewardsMaxApy'] += reward['apy']

    pool['rewardYieldStr'] =  f"{pool['rewardsMinApy']:,.2f}-{pool['rewardsMaxApy']:,.2f}%"
    
# Make the df from the pool data
pools_df = pd.DataFrame(formatted_pool_data)

# Save/update the curve asset image html dict
with open('curve-assets-image-html.dict', 'w') as file:
    file.write(str(coin_image_html_dict))
# Out:
# Processing pool 1 of 814
# Processing pool 2 of 814
# Processing pool 3 of 814
# Processing pool 4 of 814
# Processing pool 5 of 814
# Processing pool 6 of 814
# Processing pool 7 of 814
# Processing pool 8 of 814
# Processing pool 9 of 814
# Processing pool 10 of 814
# Processing pool 11 of 814
# Processing pool 12 of 814
# Processing pool 13 of 814
# Processing pool 14 of 814
# Processing pool 15 of 814
# Processing pool 16 of 814
# Processing pool 17 of 814
# Processing pool 18 of 814
# Processing pool 19 of 814
# Processing pool 20 of 814
# Processing pool 21 of 814
# Processing pool 22 of 814
# Processing pool 23 of 814
# Processing pool 24 of 814
# Processing pool 25 of 814
# Processing pool 26 of 814
# Processing pool 27 of 814
# Processing pool 28 of 814
# Processing pool 29 of 814
# Processing pool 30 of 814
# Processing pool 31 of 814
# Processing pool 32 of 814
# Processing pool 33 of 814
# Processing pool 34 of 814
# Processing pool 35 of 814
# Processing pool 36 of 814
# Processing pool 37 of 814
# Processing pool 38 of 814
# Processing pool 39 of 814
# Processing pool 40 of 814
# Processing pool 41 of 814
# Processing pool 42 of 814
# Processing pool 43 of 814
# Processing pool 44 of 814
# Processing pool 45 of 814
# Processing pool 46 of 814
# Processing pool 47 of 814
# Processing pool 48 of 814
# Processing pool 49 of 814
# Processing pool 50 of 814
# Processing pool 51 of 814
# Processing pool 52 of 814
# Processing pool 53 of 814
# Processing pool 54 of 814
# Processing pool 55 of 814
# Processing pool 56 of 814
# Processing pool 57 of 814
# Processing pool 58 of 814
# Processing pool 59 of 814
# Processing pool 60 of 814
# Processing pool 61 of 814
# Processing pool 62 of 814
# Processing pool 63 of 814
# Processing pool 64 of 814
# Processing pool 65 of 814
# Processing pool 66 of 814
# Processing pool 67 of 814
# Processing pool 68 of 814
# Processing pool 69 of 814
# Processing pool 70 of 814
# Processing pool 71 of 814
# Processing pool 72 of 814
# Processing pool 73 of 814
# Processing pool 74 of 814
# Processing pool 75 of 814
# Processing pool 76 of 814
# Processing pool 77 of 814
# Processing pool 78 of 814
# Processing pool 79 of 814
# Processing pool 80 of 814
# Processing pool 81 of 814
# Processing pool 82 of 814
# Processing pool 83 of 814
# Processing pool 84 of 814
# Processing pool 85 of 814
# Processing pool 86 of 814
# Processing pool 87 of 814
# Processing pool 88 of 814
# Processing pool 89 of 814
# Processing pool 90 of 814
# Processing pool 91 of 814
# Processing pool 92 of 814
# Processing pool 93 of 814
# Processing pool 94 of 814
# Processing pool 95 of 814
# Processing pool 96 of 814
# Processing pool 97 of 814
# Processing pool 98 of 814
# Processing pool 99 of 814
# Processing pool 100 of 814
# Processing pool 101 of 814
# Processing pool 102 of 814
# Processing pool 103 of 814
# Processing pool 104 of 814
# Processing pool 105 of 814
# Processing pool 106 of 814
# Processing pool 107 of 814
# Processing pool 108 of 814
# Processing pool 109 of 814
# Processing pool 110 of 814
# Processing pool 111 of 814
# Processing pool 112 of 814
# Processing pool 113 of 814
# Processing pool 114 of 814
# Processing pool 115 of 814
# Processing pool 116 of 814
# Processing pool 117 of 814
# Processing pool 118 of 814
# Processing pool 119 of 814
# Processing pool 120 of 814
# Processing pool 121 of 814
# Processing pool 122 of 814
# Processing pool 123 of 814
# Processing pool 124 of 814
# Processing pool 125 of 814
# Processing pool 126 of 814
# Processing pool 127 of 814
# Processing pool 128 of 814
# Processing pool 129 of 814
# Processing pool 130 of 814
# Processing pool 131 of 814
# Processing pool 132 of 814
# Processing pool 133 of 814
# Processing pool 134 of 814
# Processing pool 135 of 814
# Processing pool 136 of 814
# Processing pool 137 of 814
# Processing pool 138 of 814
# Processing pool 139 of 814
# Processing pool 140 of 814
# Processing pool 141 of 814
# Processing pool 142 of 814
# Processing pool 143 of 814
# Processing pool 144 of 814
# Processing pool 145 of 814
# Processing pool 146 of 814
# Processing pool 147 of 814
# Processing pool 148 of 814
# Processing pool 149 of 814
# Processing pool 150 of 814
# Processing pool 151 of 814
# Processing pool 152 of 814
# Processing pool 153 of 814
# Processing pool 154 of 814
# Processing pool 155 of 814
# Processing pool 156 of 814
# Processing pool 157 of 814
# Processing pool 158 of 814
# Processing pool 159 of 814
# Processing pool 160 of 814
# Processing pool 161 of 814
# Processing pool 162 of 814
# Processing pool 163 of 814
# Processing pool 164 of 814
# Processing pool 165 of 814
# Processing pool 166 of 814
# Processing pool 167 of 814
# Processing pool 168 of 814
# Processing pool 169 of 814
# Processing pool 170 of 814
# Processing pool 171 of 814
# Processing pool 172 of 814
# Processing pool 173 of 814
# Processing pool 174 of 814
# Processing pool 175 of 814
# Processing pool 176 of 814
# Processing pool 177 of 814
# Processing pool 178 of 814
# Processing pool 179 of 814
# Processing pool 180 of 814
# Processing pool 181 of 814
# Processing pool 182 of 814
# Processing pool 183 of 814
# Processing pool 184 of 814
# Processing pool 185 of 814
# Processing pool 186 of 814
# Processing pool 187 of 814
# Processing pool 188 of 814
# Processing pool 189 of 814
# Processing pool 190 of 814
# Processing pool 191 of 814
# Processing pool 192 of 814
# Processing pool 193 of 814
# Processing pool 194 of 814
# Processing pool 195 of 814
# Processing pool 196 of 814
# Processing pool 197 of 814
# Processing pool 198 of 814
# Processing pool 199 of 814
# Processing pool 200 of 814
# Processing pool 201 of 814
# Processing pool 202 of 814
# Processing pool 203 of 814
# Processing pool 204 of 814
# Processing pool 205 of 814
# Processing pool 206 of 814
# Processing pool 207 of 814
# Processing pool 208 of 814
# Processing pool 209 of 814
# Processing pool 210 of 814
# Processing pool 211 of 814
# Processing pool 212 of 814
# Processing pool 213 of 814
# Processing pool 214 of 814
# Processing pool 215 of 814
# Processing pool 216 of 814
# Processing pool 217 of 814
# Processing pool 218 of 814
# Processing pool 219 of 814
# Processing pool 220 of 814
# Processing pool 221 of 814
# Processing pool 222 of 814
# Processing pool 223 of 814
# Processing pool 224 of 814
# Processing pool 225 of 814
# Processing pool 226 of 814
# Processing pool 227 of 814
# Processing pool 228 of 814
# Processing pool 229 of 814
# Processing pool 230 of 814
# Processing pool 231 of 814
# Processing pool 232 of 814
# Processing pool 233 of 814
# Processing pool 234 of 814
# Processing pool 235 of 814
# Processing pool 236 of 814
# Processing pool 237 of 814
# Processing pool 238 of 814
# Processing pool 239 of 814
# Processing pool 240 of 814
# Processing pool 241 of 814
# Processing pool 242 of 814
# Processing pool 243 of 814
# Processing pool 244 of 814
# Processing pool 245 of 814
# Processing pool 246 of 814
# Processing pool 247 of 814
# Processing pool 248 of 814
# Processing pool 249 of 814
# Processing pool 250 of 814
# Processing pool 251 of 814
# Processing pool 252 of 814
# Processing pool 253 of 814
# Processing pool 254 of 814
# Processing pool 255 of 814
# Processing pool 256 of 814
# Processing pool 257 of 814
# Processing pool 258 of 814
# Processing pool 259 of 814
# Processing pool 260 of 814
# Processing pool 261 of 814
# Processing pool 262 of 814
# Processing pool 263 of 814
# Processing pool 264 of 814
# Processing pool 265 of 814
# Processing pool 266 of 814
# Processing pool 267 of 814
# Processing pool 268 of 814
# Processing pool 269 of 814
# Processing pool 270 of 814
# Processing pool 271 of 814
# Processing pool 272 of 814
# Processing pool 273 of 814
# Processing pool 274 of 814
# Processing pool 275 of 814
# Processing pool 276 of 814
# Processing pool 277 of 814
# Processing pool 278 of 814
# Processing pool 279 of 814
# Processing pool 280 of 814
# Processing pool 281 of 814
# Processing pool 282 of 814
# Processing pool 283 of 814
# Processing pool 284 of 814
# Processing pool 285 of 814
# Processing pool 286 of 814
# Processing pool 287 of 814
# Processing pool 288 of 814
# Processing pool 289 of 814
# Processing pool 290 of 814
# Processing pool 291 of 814
# Processing pool 292 of 814
# Processing pool 293 of 814
# Processing pool 294 of 814
# Processing pool 295 of 814
# Processing pool 296 of 814
# Processing pool 297 of 814
# Processing pool 298 of 814
# Processing pool 299 of 814
# Processing pool 300 of 814
# Processing pool 301 of 814
# Processing pool 302 of 814
# Processing pool 303 of 814
# Processing pool 304 of 814
# Processing pool 305 of 814
# Processing pool 306 of 814
# Processing pool 307 of 814
# Processing pool 308 of 814
# Processing pool 309 of 814
# Processing pool 310 of 814
# Processing pool 311 of 814
# Processing pool 312 of 814
# Processing pool 313 of 814
# Processing pool 314 of 814
# Processing pool 315 of 814
# Processing pool 316 of 814
# Processing pool 317 of 814
# Processing pool 318 of 814
# Processing pool 319 of 814
# Processing pool 320 of 814
# Processing pool 321 of 814
# Processing pool 322 of 814
# Processing pool 323 of 814
# Processing pool 324 of 814
# Processing pool 325 of 814
# Processing pool 326 of 814
# Processing pool 327 of 814
# Processing pool 328 of 814
# Processing pool 329 of 814
# Processing pool 330 of 814
# Processing pool 331 of 814
# Processing pool 332 of 814
# Processing pool 333 of 814
# Processing pool 334 of 814
# Processing pool 335 of 814
# Processing pool 336 of 814
# Processing pool 337 of 814
# Processing pool 338 of 814
# Processing pool 339 of 814
# Processing pool 340 of 814
# Processing pool 341 of 814
# Processing pool 342 of 814
# Processing pool 343 of 814
# Processing pool 344 of 814
# Processing pool 345 of 814
# Processing pool 346 of 814
# Processing pool 347 of 814
# Processing pool 348 of 814
# Processing pool 349 of 814
# Processing pool 350 of 814
# Processing pool 351 of 814
# Processing pool 352 of 814
# Processing pool 353 of 814
# Processing pool 354 of 814
# Processing pool 355 of 814
# Processing pool 356 of 814
# Processing pool 357 of 814
# Processing pool 358 of 814
# Processing pool 359 of 814
# Processing pool 360 of 814
# Processing pool 361 of 814
# Processing pool 362 of 814
# Processing pool 363 of 814
# Processing pool 364 of 814
# Processing pool 365 of 814
# Processing pool 366 of 814
# Processing pool 367 of 814
# Processing pool 368 of 814
# Processing pool 369 of 814
# Processing pool 370 of 814
# Processing pool 371 of 814
# Processing pool 372 of 814
# Processing pool 373 of 814
# Processing pool 374 of 814
# Processing pool 375 of 814
# Processing pool 376 of 814
# Processing pool 377 of 814
# Processing pool 378 of 814
# Processing pool 379 of 814
# Processing pool 380 of 814
# Processing pool 381 of 814
# Processing pool 382 of 814
# Processing pool 383 of 814
# Processing pool 384 of 814
# Processing pool 385 of 814
# Processing pool 386 of 814
# Processing pool 387 of 814
# Processing pool 388 of 814
# Processing pool 389 of 814
# Processing pool 390 of 814
# Processing pool 391 of 814
# Processing pool 392 of 814
# Processing pool 393 of 814
# Processing pool 394 of 814
# Processing pool 395 of 814
# Processing pool 396 of 814
# Processing pool 397 of 814
# Processing pool 398 of 814
# Processing pool 399 of 814
# Processing pool 400 of 814
# Processing pool 401 of 814
# Processing pool 402 of 814
# Processing pool 403 of 814
# Processing pool 404 of 814
# Processing pool 405 of 814
# Processing pool 406 of 814
# Processing pool 407 of 814
# Processing pool 408 of 814
# Processing pool 409 of 814
# Processing pool 410 of 814
# Processing pool 411 of 814
# Processing pool 412 of 814
# Processing pool 413 of 814
# Processing pool 414 of 814
# Processing pool 415 of 814
# Processing pool 416 of 814
# Processing pool 417 of 814
# Processing pool 418 of 814
# Processing pool 419 of 814
# Processing pool 420 of 814
# Processing pool 421 of 814
# Processing pool 422 of 814
# Processing pool 423 of 814
# Processing pool 424 of 814
# Processing pool 425 of 814
# Processing pool 426 of 814
# Processing pool 427 of 814
# Processing pool 428 of 814
# Processing pool 429 of 814
# Processing pool 430 of 814
# Processing pool 431 of 814
# Processing pool 432 of 814
# Processing pool 433 of 814
# Processing pool 434 of 814
# Processing pool 435 of 814
# Processing pool 436 of 814
# Processing pool 437 of 814
# Processing pool 438 of 814
# Processing pool 439 of 814
# Processing pool 440 of 814
# Processing pool 441 of 814
# Processing pool 442 of 814
# Processing pool 443 of 814
# Processing pool 444 of 814
# Processing pool 445 of 814
# Processing pool 446 of 814
# Processing pool 447 of 814
# Processing pool 448 of 814
# Processing pool 449 of 814
# Processing pool 450 of 814
# Processing pool 451 of 814
# Processing pool 452 of 814
# Processing pool 453 of 814
# Processing pool 454 of 814
# Processing pool 455 of 814
# Processing pool 456 of 814
# Processing pool 457 of 814
# Processing pool 458 of 814
# Processing pool 459 of 814
# Processing pool 460 of 814
# Processing pool 461 of 814
# Processing pool 462 of 814
# Processing pool 463 of 814
# Processing pool 464 of 814
# Processing pool 465 of 814
# Processing pool 466 of 814
# Processing pool 467 of 814
# Processing pool 468 of 814
# Processing pool 469 of 814
# Processing pool 470 of 814
# Processing pool 471 of 814
# Processing pool 472 of 814
# Processing pool 473 of 814
# Processing pool 474 of 814
# Processing pool 475 of 814
# Processing pool 476 of 814
# Processing pool 477 of 814
# Processing pool 478 of 814
# Processing pool 479 of 814
# Processing pool 480 of 814
# Processing pool 481 of 814
# Processing pool 482 of 814
# Processing pool 483 of 814
# Processing pool 484 of 814
# Processing pool 485 of 814
# Processing pool 486 of 814
# Processing pool 487 of 814
# Processing pool 488 of 814
# Processing pool 489 of 814
# Processing pool 490 of 814
# Processing pool 491 of 814
# Processing pool 492 of 814
# Processing pool 493 of 814
# Processing pool 494 of 814
# Processing pool 495 of 814
# Processing pool 496 of 814
# Processing pool 497 of 814
# Processing pool 498 of 814
# Processing pool 499 of 814
# Processing pool 500 of 814
# Processing pool 501 of 814
# Processing pool 502 of 814
# Processing pool 503 of 814
# Processing pool 504 of 814
# Processing pool 505 of 814
# Processing pool 506 of 814
# Processing pool 507 of 814
# Processing pool 508 of 814
# Processing pool 509 of 814
# Processing pool 510 of 814
# Processing pool 511 of 814
# Processing pool 512 of 814
# Processing pool 513 of 814
# Processing pool 514 of 814
# Processing pool 515 of 814
# Processing pool 516 of 814
# Processing pool 517 of 814
# Processing pool 518 of 814
# Processing pool 519 of 814
# Processing pool 520 of 814
# Processing pool 521 of 814
# Processing pool 522 of 814
# Processing pool 523 of 814
# Processing pool 524 of 814
# Processing pool 525 of 814
# Processing pool 526 of 814
# Processing pool 527 of 814
# Processing pool 528 of 814
# Processing pool 529 of 814
# Processing pool 530 of 814
# Processing pool 531 of 814
# Processing pool 532 of 814
# Processing pool 533 of 814
# Processing pool 534 of 814
# Processing pool 535 of 814
# Processing pool 536 of 814
# Processing pool 537 of 814
# Processing pool 538 of 814
# Processing pool 539 of 814
# Processing pool 540 of 814
# Processing pool 541 of 814
# Processing pool 542 of 814
# Processing pool 543 of 814
# Processing pool 544 of 814
# Processing pool 545 of 814
# Processing pool 546 of 814
# Processing pool 547 of 814
# Processing pool 548 of 814
# Processing pool 549 of 814
# Processing pool 550 of 814
# Processing pool 551 of 814
# Processing pool 552 of 814
# Processing pool 553 of 814
# Processing pool 554 of 814
# Processing pool 555 of 814
# Processing pool 556 of 814
# Processing pool 557 of 814
# Processing pool 558 of 814
# Processing pool 559 of 814
# Processing pool 560 of 814
# Processing pool 561 of 814
# Processing pool 562 of 814
# Processing pool 563 of 814
# Processing pool 564 of 814
# Processing pool 565 of 814
# Processing pool 566 of 814
# Processing pool 567 of 814
# Processing pool 568 of 814
# Processing pool 569 of 814
# Processing pool 570 of 814
# Processing pool 571 of 814
# Processing pool 572 of 814
# Processing pool 573 of 814
# Processing pool 574 of 814
# Processing pool 575 of 814
# Processing pool 576 of 814
# Processing pool 577 of 814
# Processing pool 578 of 814
# Processing pool 579 of 814
# Processing pool 580 of 814
# Processing pool 581 of 814
# Processing pool 582 of 814
# Processing pool 583 of 814
# Processing pool 584 of 814
# Processing pool 585 of 814
# Processing pool 586 of 814
# Processing pool 587 of 814
# Processing pool 588 of 814
# Processing pool 589 of 814
# Processing pool 590 of 814
# Processing pool 591 of 814
# Processing pool 592 of 814
# Processing pool 593 of 814
# Processing pool 594 of 814
# Processing pool 595 of 814
# Processing pool 596 of 814
# Processing pool 597 of 814
# Processing pool 598 of 814
# Processing pool 599 of 814
# Processing pool 600 of 814
# Processing pool 601 of 814
# Processing pool 602 of 814
# Processing pool 603 of 814
# Processing pool 604 of 814
# Processing pool 605 of 814
# Processing pool 606 of 814
# Processing pool 607 of 814
# Processing pool 608 of 814
# Processing pool 609 of 814
# Processing pool 610 of 814
# Processing pool 611 of 814
# Processing pool 612 of 814
# Processing pool 613 of 814
# Processing pool 614 of 814
# Processing pool 615 of 814
# Processing pool 616 of 814
# Processing pool 617 of 814
# Processing pool 618 of 814
# Processing pool 619 of 814
# Processing pool 620 of 814
# Processing pool 621 of 814
# Processing pool 622 of 814
# Processing pool 623 of 814
# Processing pool 624 of 814
# Processing pool 625 of 814
# Processing pool 626 of 814
# Processing pool 627 of 814
# Processing pool 628 of 814
# Processing pool 629 of 814
# Processing pool 630 of 814
# Processing pool 631 of 814
# Processing pool 632 of 814
# Processing pool 633 of 814
# Processing pool 634 of 814
# Processing pool 635 of 814
# Processing pool 636 of 814
# Processing pool 637 of 814
# Processing pool 638 of 814
# Processing pool 639 of 814
# Processing pool 640 of 814
# Processing pool 641 of 814
# Processing pool 642 of 814
# Processing pool 643 of 814
# Processing pool 644 of 814
# Processing pool 645 of 814
# Processing pool 646 of 814
# Processing pool 647 of 814
# Processing pool 648 of 814
# Processing pool 649 of 814
# Processing pool 650 of 814
# Processing pool 651 of 814
# Processing pool 652 of 814
# Processing pool 653 of 814
# Processing pool 654 of 814
# Processing pool 655 of 814
# Processing pool 656 of 814
# Processing pool 657 of 814
# Processing pool 658 of 814
# Processing pool 659 of 814
# Processing pool 660 of 814
# Processing pool 661 of 814
# Processing pool 662 of 814
# Processing pool 663 of 814
# Processing pool 664 of 814
# Processing pool 665 of 814
# Processing pool 666 of 814
# Processing pool 667 of 814
# Processing pool 668 of 814
# Processing pool 669 of 814
# Processing pool 670 of 814
# Processing pool 671 of 814
# Processing pool 672 of 814
# Processing pool 673 of 814
# Processing pool 674 of 814
# Processing pool 675 of 814
# Processing pool 676 of 814
# Processing pool 677 of 814
# Processing pool 678 of 814
# Processing pool 679 of 814
# Processing pool 680 of 814
# Processing pool 681 of 814
# Processing pool 682 of 814
# Processing pool 683 of 814
# Processing pool 684 of 814
# Processing pool 685 of 814
# Processing pool 686 of 814
# Processing pool 687 of 814
# Processing pool 688 of 814
# Processing pool 689 of 814
# Processing pool 690 of 814
# Processing pool 691 of 814
# Processing pool 692 of 814
# Processing pool 693 of 814
# Processing pool 694 of 814
# Processing pool 695 of 814
# Processing pool 696 of 814
# Processing pool 697 of 814
# Processing pool 698 of 814
# Processing pool 699 of 814
# Processing pool 700 of 814
# Processing pool 701 of 814
# Processing pool 702 of 814
# Processing pool 703 of 814
# Processing pool 704 of 814
# Processing pool 705 of 814
# Processing pool 706 of 814
# Processing pool 707 of 814
# Processing pool 708 of 814
# Processing pool 709 of 814
# Processing pool 710 of 814
# Processing pool 711 of 814
# Processing pool 712 of 814
# Processing pool 713 of 814
# Processing pool 714 of 814
# Processing pool 715 of 814
# Processing pool 716 of 814
# Processing pool 717 of 814
# Processing pool 718 of 814
# Processing pool 719 of 814
# Processing pool 720 of 814
# Processing pool 721 of 814
# Processing pool 722 of 814
# Processing pool 723 of 814
# Processing pool 724 of 814
# Processing pool 725 of 814
# Processing pool 726 of 814
# Processing pool 727 of 814
# Processing pool 728 of 814
# Processing pool 729 of 814
# Processing pool 730 of 814
# Processing pool 731 of 814
# Processing pool 732 of 814
# Processing pool 733 of 814
# Processing pool 734 of 814
# Processing pool 735 of 814
# Processing pool 736 of 814
# Processing pool 737 of 814
# Processing pool 738 of 814
# Processing pool 739 of 814
# Processing pool 740 of 814
# Processing pool 741 of 814
# Processing pool 742 of 814
# Processing pool 743 of 814
# Processing pool 744 of 814
# Processing pool 745 of 814
# Processing pool 746 of 814
# Processing pool 747 of 814
# Processing pool 748 of 814
# Processing pool 749 of 814
# Processing pool 750 of 814
# Processing pool 751 of 814
# Processing pool 752 of 814
# Processing pool 753 of 814
# Processing pool 754 of 814
# Processing pool 755 of 814
# Processing pool 756 of 814
# Processing pool 757 of 814
# Processing pool 758 of 814
# Processing pool 759 of 814
# Processing pool 760 of 814
# Processing pool 761 of 814
# Processing pool 762 of 814
# Processing pool 763 of 814
# Processing pool 764 of 814
# Processing pool 765 of 814
# Processing pool 766 of 814
# Processing pool 767 of 814
# Processing pool 768 of 814
# Processing pool 769 of 814
# Processing pool 770 of 814
# Processing pool 771 of 814
# Processing pool 772 of 814
# Processing pool 773 of 814
# Processing pool 774 of 814
# Processing pool 775 of 814
# Processing pool 776 of 814
# Processing pool 777 of 814
# Processing pool 778 of 814
# Processing pool 779 of 814
# Processing pool 780 of 814
# Processing pool 781 of 814
# Processing pool 782 of 814
# Processing pool 783 of 814
# Processing pool 784 of 814
# Processing pool 785 of 814
# Processing pool 786 of 814
# Processing pool 787 of 814
# Processing pool 788 of 814
# Processing pool 789 of 814
# Processing pool 790 of 814
# Processing pool 791 of 814
# Processing pool 792 of 814
# Processing pool 793 of 814
# Processing pool 794 of 814
# Processing pool 795 of 814
# Processing pool 796 of 814
# Processing pool 797 of 814
# Processing pool 798 of 814
# Processing pool 799 of 814
# Processing pool 800 of 814
# Processing pool 801 of 814
# Processing pool 802 of 814
# Processing pool 803 of 814
# Processing pool 804 of 814
# Processing pool 805 of 814
# Processing pool 806 of 814
# Processing pool 807 of 814
# Processing pool 808 of 814
# Processing pool 809 of 814
# Processing pool 810 of 814
# Processing pool 811 of 814
# Processing pool 812 of 814
# Processing pool 813 of 814
# Processing pool 814 of 814

# %%
# Sometimes bugged pools will show up in the lists, use this list to filter them at this step
# Set Test_Pools to show extra pools and filter out pools in the filter list
TEST_POOLS = False
POOL_FILTER_LIST = [
    ('fantom', '0x3f833Ed02629545DD78AFc3D585f7F3918a3De62'),
    ('ethereum', '0xC03FEF1c425956A3Cd5762022E511e0d4148B3D6'),
    ('fraxtal', '0xeE454138083b9B9714cac3c7cF12560248d76D6B'),
    ('fraxtal', '0x4Cfc391d75c43Cf1Bdb368e8bF680AEd1228df39'),
    ('ethereum', '0xFE3C78D947b329160496E192b4Cf417bB86272Ed'),
    ('arbitrum', '0xad37295881f53Fe6FDAb54493A06CD84f988646B'),
    ('arbitrum', '0x845C8bc94610807fCbaB5dd2bc7aC9DAbaFf3c55'),
    ('optimism', '0xd8dD9a8b2AcA88E68c46aF9008259d0EC04b7751'),
]

df = pools_df.copy()

# take out pools with base yields greater than 1000% because these will be errors or depegged pools
df = df[df['baseWeeklyApy'] < 1000]

# take out any pools in the filter list
df = df[~df.apply(lambda x: (x['blockchainId'], x['address']) in POOL_FILTER_LIST, axis=1)]

if TEST_POOLS:
    df_test = df.copy()
    df_test['chainAddress'] = df_test.apply(lambda row: f"('{row['blockchainId']}', '{row['address']}')", axis=1)
    df_usd = get_top_pool_yields_pools(df_test, 10, 100000, asset='usd', columns_to_show=['Chain', 'Pool', 'Type', 'Yield', 'chainAddress'])
    df_btc = get_top_pool_yields_pools(df_test, 6, 100000, asset='btc', columns_to_show=['Chain', 'Pool', 'Type', 'Yield', 'chainAddress'])
    df_eth = get_top_pool_yields_pools(df_test, 6, 100000, asset='eth', columns_to_show=['Chain', 'Pool', 'Type', 'Yield', 'chainAddress'])
    df_crv = get_top_pool_yields_pools(df_test, 6, 100000, asset='crv', columns_to_show=['Chain', 'Pool', 'Type', 'Yield', 'chainAddress'])
    df_eur = get_top_pool_yields_pools(df_test, 3, 100000, asset='eur', columns_to_show=['Chain', 'Pool', 'Type', 'Yield', 'chainAddress'])
else:
    df_usd = get_top_pool_yields_pools(df, 3, 100000, asset='usd')
    df_btc = get_top_pool_yields_pools(df, 2, 100000, asset='btc')
    df_eth = get_top_pool_yields_pools(df, 2, 100000, asset='eth')
    df_crv = get_top_pool_yields_pools(df, 2, 100000, asset='crv')
    df_eur = get_top_pool_yields_pools(df, 1, 100000, asset='eur')

top_pool_yields_html = df_to_html(pd.concat([df_usd, df_btc, df_eth, df_crv, df_eur], axis=0), classes='curve-table chain-column pool-column')

display_curve_table(top_pool_yields_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Pool</th>
#       <th>Type</th>
#       <th>Yield</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Fantom src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/fantom.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/fantom/pools/factory-stable-ng-43/deposit'><div class="pool-content">CrossCurve Stable 2</div></a></td>
#       <td>USD</td>
#       <td>101.5%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-307/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0d86883faf4ffd7aeb116390af37746f45b6f378.png' class="token-icon"><span>USD3</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0655977feb2f289a4ab78af67bab0d17aab84367.png' class="token-icon"><span>scrvUSD</span></div></div></a></td>
#       <td>USD</td>
#       <td>50.57%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-228/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0d86883faf4ffd7aeb116390af37746f45b6f378.png' class="token-icon"><span>USD3</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x83f20f44975d03b1b09e64809b757c47f942beea.png' class="token-icon"><span>sDAI</span></div></div></a></td>
#       <td>USD</td>
#       <td>28.92%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-275/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0fa308ae0dde633b6ede22ba719e7e0bc45fc6db.png' class="token-icon"><span>zunBTC</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x18084fba666a33d37592fa2633fd49a74dd93a88.png' class="token-icon"><span>tBTC</span></div></div></a></td>
#       <td>BTC</td>
#       <td>134.5%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Fantom src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/fantom.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/fantom/pools/factory-stable-ng-39/deposit'><div class="pool-content">CrossCurve BTC</div></a></td>
#       <td>BTC</td>
#       <td>34.51%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Fantom src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/fantom.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/fantom/pools/factory-stable-ng-37/deposit'><div class="pool-content">CrossCurve ETH</div></a></td>
#       <td>ETH</td>
#       <td>59.89%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-v2-353/deposit'><div class="pool-content"><div cla

# %% [markdown]
# ### Get Top crvUSD & scrvUSD Yields

# %%
# COMBINE POOL AND LENDING YIELDS FOR CRVUSD YIELDS

top_crvusd_pool_yields_df = get_top_pool_yields_pools(df[df['crvusd_pool'] == True], 4, 100000, columns_to_show=['Chain', 'Pool', 'Yield', 'yieldMin'])
top_crvusd_pool_yields_df['Type'] = 'Pool'
crvusd_pools_df = top_crvusd_pool_yields_df.rename(columns={'Pool': 'Market'})
top_lending_yields_df = get_top_yielding_lending_markets(lending_df, 4, 10000, normalize=True, columns_to_show=['Chain', 'Market', 'Yield', 'yieldMin'])
top_lending_yields_df['Type'] = 'LlamaLend'
crvusd_yield_df = pd.concat([crvusd_pools_df, top_lending_yields_df], axis=0).sort_values('yieldMin', ascending=False).head(8)
top_crvusd_yields_html = df_to_html(crvusd_yield_df[['Chain', 'Market', 'Type', 'Yield']], classes='curve-table chain-column pool-column')

display_curve_table(top_crvusd_yields_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Market</th>
#       <th>Type</th>
#       <th>Yield</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-307/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0d86883faf4ffd7aeb116390af37746f45b6f378.png' class="token-icon"><span>USD3</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0655977feb2f289a4ab78af67bab0d17aab84367.png' class="token-icon"><span>scrvUSD</span></div></div></a></td>
#       <td>Pool</td>
#       <td>50.57%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://lend.curve.fi/#/ethereum/markets/one-way-market-13/vault/deposit'><div class="pool-content"><div class="token-pill-borrow"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x7f39c581f595b53c5cb19bd0b3f8da6c935e2ca0.png' class="token-icon"><span>wstETH</span></div></div></a></td>
#       <td>LlamaLend</td>
#       <td>40.57%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://lend.curve.fi/#/ethereum/markets/one-way-market-8/vault/deposit'><div class="pool-content"><div class="token-pill-borrow"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x55c08ca52497e2f1534b59e2917bf524d4765257.png' class="token-icon"><span>UwU</span></div></div></a></td>
#       <td>LlamaLend</td>
#       <td>32.78%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://lend.curve.fi/#/ethereum/markets/one-way-market-1/vault/deposit'><div class="pool-content"><div class="token-pill-borrow"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png' class="token-icon"><span>WETH</span></div></div></a></td>
#       <td>LlamaLend</td>
#       <td>32.67%</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://lend.curve.fi/#/ethereum/markets/one-way-market-15/vault/deposit'><div class="pool-content"><div class="token-pill-borrow"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD</span></div><div class="token-pill-pool"><img src='https://raw.githubus

# %%
# Highest Pools Volume
columns_to_show = ['chainWithIcon', 'nameLink', 'volumeUsd', 'tvlUsd']
pool_highest_volume_html = sort_pool_df_to_html(df, 4, 'volumeUsd', columns_to_show)

display_curve_table(pool_highest_volume_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Pool</th>
#       <th>Volume</th>
#       <th>TVL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/3pool/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x6b175474e89094c44da98b954eedeac495271d0f.png' class="token-icon"><span>DAI</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png' class="token-icon"><span>USDC</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xdac17f958d2ee523a2206206994597c13d831ec7.png' class="token-icon"><span>USDT</span></div></div></a></td>
#       <td>$624.1M</td>
#       <td>$168.7M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/steth/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee.png' class="token-icon"><span>ETH</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xae7ab96520de3a18e5e111b5eaab095312d7fe84.png' class="token-icon"><span>stETH</span></div></div></a></td>
#       <td>$579.4M</td>
#       <td>$181.4M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-188/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x73a15fed60bf67631dc6cd7bc5b6e8da8190acf5.png' class="token-icon"><span>USD0</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png' class="token-icon"><span>USDC</span></div></div></a></td>
#       <td>$246.8M</td>
#       <td>$76.18M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-102/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x83f20f44975d03b1b09e64809b757c47f942beea.png' class="token-icon"><span>sDAI</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x9d39a5de30e57443bff2a8307a4256c8797a3497.png' class="token-icon"><span>sUSDe</span></div></div></a></td>
#       <td>$197.8M</td>
#       <td>$41.71M</td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
#biggest new pools of the week
columns_to_show = ['chainWithIcon', 'nameLink', 'tvlUsd']
pool_biggest_new_pools_html = sort_pool_df_to_html(df[df['newPool']==True], 4, 'tvlUsd', columns_to_show)

display_curve_table(pool_biggest_new_pools_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Pool</th>
#       <th>TVL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-314/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png' class="token-icon"><span>USDC</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc139190f447e929f090edeb554d95abb8b18ac1c.png' class="token-icon"><span>USDtb</span></div></div></a></td>
#       <td>$19.98M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-319/deposit'><div class="pool-content"><div class="token-pill-pool"><span>USDa</span></div><div class="token-pill-pool"><span>sUSDa</span></div></div></a></td>
#       <td>$5.037M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-315/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x4c9edd5852cd905f086c759e8383e09bff1e68b3.png' class="token-icon"><span>USDe</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc139190f447e929f090edeb554d95abb8b18ac1c.png' class="token-icon"><span>USDtb</span></div></div></a></td>
#       <td>$164.3k</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-stable-ng-275/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0fa308ae0dde633b6ede22ba719e7e0bc45fc6db.png' class="token-icon"><span>zunBTC</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x18084fba666a33d37592fa2633fd49a74dd93a88.png' class="token-icon"><span>tBTC</span></div></div></a></td>
#       <td>$140.8k</td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
# Biggest Pools for fees
columns_to_show = ['chainWithIcon', 'nameLink', 'feesUsd', 'volumeUsd']
pool_biggest_fees_html = sort_pool_df_to_html(df, 3, 'feesUsd', columns_to_show)

display_curve_table(pool_biggest_fees_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Pool</th>
#       <th>Fees</th>
#       <th>Volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/3pool/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x6b175474e89094c44da98b954eedeac495271d0f.png' class="token-icon"><span>DAI</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48.png' class="token-icon"><span>USDC</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xdac17f958d2ee523a2206206994597c13d831ec7.png' class="token-icon"><span>USDT</span></div></div></a></td>
#       <td>$62.4k</td>
#       <td>$624.1M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/steth/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee.png' class="token-icon"><span>ETH</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xae7ab96520de3a18e5e111b5eaab095312d7fe84.png' class="token-icon"><span>stETH</span></div></div></a></td>
#       <td>$57.96k</td>
#       <td>$579.4M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/cvxeth/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png' class="token-icon"><span>WETH</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b.png' class="token-icon"><span>CVX</span></div></div></a></td>
#       <td>$55.43k</td>
#       <td>$15.04M</td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
# Most profitable pools
columns_to_show = ['chainWithIcon', 'nameLink', 'feesUsd', 'tvlUsd']
df['profitability'] = df['feesUsd'] / df['tvlUsd']
pool_most_profitable_html = sort_pool_df_to_html(df[df['tvlUsd']>100000], 3, 'profitability', columns_to_show)

display_curve_table(pool_most_profitable_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table chain-column pool-column">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Chain</th>
#       <th>Pool</th>
#       <th>Fees</th>
#       <th>TVL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/cvxeth/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png' class="token-icon"><span>WETH</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b.png' class="token-icon"><span>CVX</span></div></div></a></td>
#       <td>$55.43k</td>
#       <td>$12.03M</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Ethereum src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/ethereum.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/ethereum/pools/factory-crypto-370/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2.png' class="token-icon"><span>ETH</span></div><div class="token-pill-pool"><span>XYO</span></div></div></a></td>
#       <td>$423.6</td>
#       <td>$107.7k</td>
#     </tr>
#     <tr>
#       <td><div class="network-cell"><img title=Polygon src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/chains/polygon.png' class="network-icon"></div></td>
#       <td><a href='https://curve.fi/#/polygon/pools/factory-crypto-1/deposit'><div class="pool-content"><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets-polygon/0x172370d5cd63279efa6d502dab29171933a610af.png' class="token-icon"><span>CRV</span></div><div class="token-pill-pool"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets-polygon/0xdad97f7713ae9437fa9249920ec8507e5fbb23d3.png' class="token-icon"><span>crvUSDBTCETH</span></div></div></a></td>
#       <td>$9.488k</td>
#       <td>$2.459M</td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
# Need to hardcode the TVL currently, for reasonsss...
pools_tvl = 2166000000
pools_tvl_prev = 2148000000

# %%
# Pools Metrics

pools_transactions_total = prices_chain_transactions['all']['pools']['cur_week_total']
pools_transactions_total_prev = prices_chain_transactions['all']['pools']['prev_week_total']
pools_transaction_ethereum = prices_chain_transactions['ethereum']['pools']['cur_week_total']
pools_transactions_ethereum_prev = prices_chain_transactions['ethereum']['pools']['prev_week_total']

pools_transactions_other = 0
pools_transactions_other_prev = 0
for chain in prices_chain_transactions:
    if chain != 'all' and chain != 'ethereum':
        pools_transactions_other += prices_chain_transactions[chain]['pools']['cur_week_total']
        pools_transactions_other_prev += prices_chain_transactions[chain]['pools']['prev_week_total']

pools_tranactions_per_sec = pools_transactions_total / 604800
pools_tranactions_per_sec_prev = pools_transactions_total_prev / 604800
pools_transactions_l2_ratio = pools_transactions_other / pools_transactions_total * 100
pools_transactions_l2_ratio_prev = pools_transactions_other_prev / pools_transactions_total_prev * 100

pools_fees_weekly = df['feesUsd'].sum()
pools_fees_weekly_prev = df['prevFeesUsd'].sum()

# Make the metrics list
metrics_list = []

metrics_list.append(make_metric_html('TVL', pools_tvl, pools_tvl_prev))
metrics_list.append(make_metric_html('Volume', df['volumeUsd'].sum(), df['prevVolumeUsd'].sum()))
metrics_list.append(make_metric_html('Transactions', pools_transactions_total, pools_transactions_total_prev, customValueFormat=f"{int(pools_transactions_total):,.0f}"))
metrics_list.append(make_metric_html('Total Fees', pools_fees_weekly, pools_fees_weekly_prev)) 
metrics_list.append(make_metric_html('DAO Fees', pools_fees_weekly/2, pools_fees_weekly_prev/2))

pool_metrics_html = df_to_html(pd.DataFrame(metrics_list), classes='curve-table')

display_curve_table(pool_metrics_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Metric</th>
#       <th>Value</th>
#       <th>Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>TVL</td>
#       <td>$2.166B</td>
#       <td><span class="positive-change">+0.84%</span></td>
#     </tr>
#     <tr>
#       <td>Volume</td>
#       <td>$3.031B</td>
#       <td><span class="positive-change">+14.28%</span></td>
#     </tr>
#     <tr>
#       <td>Transactions</td>
#       <td>387,579</td>
#       <td><span class="negative-change">-1.24%</span></td>
#     </tr>
#     <tr>
#       <td>Total Fees</td>
#       <td>$691.8k</td>
#       <td><span class="negative-change">-11.50%</span></td>
#     </tr>
#     <tr>
#       <td>DAO Fees</td>
#       <td>$345.9k</td>
#       <td><span class="negative-change">-11.50%</span></td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %% [markdown]
# ## crvUSD market data

# %%
def prices_get_crvusd_markets(coin_image_html_dict):
    url = "/v1/crvusd/markets/ethereum"
    data = prices_api_request(url)

    crvusd_markets = {}
    for contract in data['data']:
        address = contract['address']
        market_data = prices_get_crvusd_market_snapshots(address)
        contract['rate'] = market_data[1]['rate']
        contract['total_debt'] = market_data[0]['total_debt']
        contract['collateral_amount_usd'] = market_data[0]['total_collateral_usd']
        contract['n_loans'] = market_data[0]['n_loans']
        contract['prev_rate'] = market_data[3]['rate']
        contract['prev_collateral_amount_usd'] = market_data[2]['total_collateral_usd']
        contract['prev_total_debt'] = market_data[2]['total_debt']
        contract['prev_n_loans'] = market_data[2]['n_loans']
        contract['snapshot_data'] = market_data
        link = CRVUSD_MARKET_LINKS[address]['link']
        name = CRVUSD_MARKET_LINKS[address]['name']
        contract['marketName'] = name
        image_link, coin_image_html_dict = get_coin_image_url(contract['collateral_token']['address'], 'ethereum', coin_image_html_dict)
        contract['nameLink'] = make_name_link_html(name, link, image_link)
        crvusd_markets[address] = contract

    url = "/v1/dao/fees/crvusd/weekly"
    data = prices_api_request(url)
    for fee in data['fees']:
        address = fee['controller']
        ts = epoch_time_formatter(fee['timestamp'])
        if epoch_end - ts < 7*86400:
            continue
        if 'fees' not in crvusd_markets[address]:
            crvusd_markets[address]['fees'] = fee['fees_usd']
        elif 'prev_fees' not in crvusd_markets[address]:
            crvusd_markets[address]['prev_fees'] = fee['fees_usd']
    
    # Old sfrxETH pool doesn't have fees in prices API, need to estimate them from the rate and debt
    address = '0x8472A9A7632b173c8Cf3a86D3afec50c35548e76'
    crvusd_markets[address]['fees'] = (crvusd_markets[address]['total_debt'] * crvusd_markets[address]['rate']) /365 * 7
    crvusd_markets[address]['prev_fees'] = (crvusd_markets[address]['prev_total_debt'] * crvusd_markets[address]['prev_rate']) /365 * 7

    # Aggregate all the markets into a single 'all' market
    crvusd_markets['all'] = { \
        'fees': 0, \
        'total_debt': 0, \
        'rate': 0, \
        'collateral_amount_usd': 0, \
        'prev_fees': 0, \
        'prev_total_debt': 0, \
        'prev_rate': 0, \
        'prev_collateral_amount_usd': 0, \
        'n_loans': 0, \
        'prev_n_loans': 0, \
    }
    
    for address in crvusd_markets:
        market = crvusd_markets[address]
        if address == 'all':
            continue
        crvusd_markets['all']['fees'] += market['fees']
        crvusd_markets['all']['total_debt'] += market['total_debt']
        crvusd_markets['all']['collateral_amount_usd'] += market['collateral_amount_usd']
        crvusd_markets['all']['prev_fees'] += market['prev_fees']
        crvusd_markets['all']['prev_total_debt'] += market['prev_total_debt']
        crvusd_markets['all']['prev_collateral_amount_usd'] += market['prev_collateral_amount_usd']
        crvusd_markets['all']['prev_rate'] += market['prev_rate'] * market['prev_total_debt']
        crvusd_markets['all']['rate'] += market['rate'] * market['total_debt']
        crvusd_markets['all']['n_loans'] += market['n_loans']
        crvusd_markets['all']['prev_n_loans'] += market['prev_n_loans']

    link = CRVUSD_MARKET_LINKS['all']['link']
    name = CRVUSD_MARKET_LINKS['all']['name']
    crvusd_markets['all']['marketName'] = name
    crvusd_markets['all']['nameLink'] = make_name_link_html(name, link)
    crvusd_markets['all']['rate'] /= crvusd_markets['all']['total_debt']
    crvusd_markets['all']['prev_rate'] /= crvusd_markets['all']['prev_total_debt']

    return crvusd_markets

prices_crvusd_markets = prices_get_crvusd_markets(coin_image_html_dict)

# %%
def prices_get_pegkeeper_debt():
    url = "/v1/crvusd/pegkeepers/ethereum"
    data = prices_api_request(url)
    debt = 0
    for pk in data['keepers']:
        debt += pk['total_debt']
    return debt

pk_debt = prices_get_pegkeeper_debt()

# %%
def prices_get_scrvusd_snapshots(crv_markets_all, start, end):
    url = f"/v1/crvusd/savings/yield?agg_number=1&agg_units=hour&start={start}&end={end}"
    data = prices_api_request(url)
    scrvusd_data = {
        'prev_staked_crvusd': data['data'][0]['assets'],
        'staked_crvusd': data['data'][-1]['assets'],
        'prev_apy': data['data'][0]['proj_apy'],
        'cur_apy': data['data'][-1]['proj_apy'],
        'prev_staking_ratio': data['data'][0]['assets'] / crv_markets_all['prev_total_debt'],
        'staking_ratio': data['data'][-1]['assets'] / crv_markets_all['total_debt'],
    }
    return scrvusd_data

prices_scrvusd_data = prices_get_scrvusd_snapshots(prices_crvusd_markets['all'], epoch_start, int(time.time()))

# %%
def prices_get_crvusd_peg(start, end):
    url = f"/v1/usd_price/ethereum/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e/history?start={start}&end={end}"
    data = prices_api_request(url)
        
    return {'price': data['data'][-1]['price'], 'prev_price': data['data'][0]['price']}

prices_crvusd_peg = prices_get_crvusd_peg(epoch_start, int(time.time()))

# %%
scrvusd_image_link, coin_image_html_dict = get_coin_image_url(CRVUSD_ADDR_LIST['scrvUSD'], 'ethereum', coin_image_html_dict)
crvusd_image_link, coin_image_html_dict = get_coin_image_url(CRVUSD_ADDR_LIST['crvUSD'], 'ethereum', coin_image_html_dict)

crvusd_metrics = []

# crvusd supply
metric_name = make_metric_name_with_images([
    {'type': 'img_html', 'content': crvusd_image_link},
    {'type': 'text', 'content': 'crvUSD Supply'}
])
crvusd_metrics.append(make_metric_html(metric_name, prices_crvusd_markets['all']['total_debt'], prices_crvusd_markets['all']['prev_total_debt']))

# scrvusd apy
metric_name = make_metric_name_with_images([
    {'type': 'img_html', 'content': scrvusd_image_link},
    {'type': 'text', 'content': 'scrvUSD Yield'}
])
value = f"{format_number(prices_scrvusd_data['cur_apy'], 4, 2)}% APY"
crvusd_metrics.append(make_metric_html(
    metric_name, 
    prices_scrvusd_data['cur_apy'], 
    prices_scrvusd_data['prev_apy'],
    showPercentChange=False,
    valuePostfix="%",
    customValueFormat=value
))

# staked crvusd ratio
metric_name = make_metric_name_with_images([
    {'type': 'img_html', 'content': crvusd_image_link},
    {'type': 'text', 'content': 'crvUSD in'},
    {'type': 'img_html', 'content': scrvusd_image_link},
    {'type': 'text', 'content': 'scrvUSD'}
])
value = f"{format_number(prices_scrvusd_data['staking_ratio']*100, 4, 2)}%"
crvusd_metrics.append(make_metric_html(
    metric_name,
    prices_scrvusd_data['staking_ratio']*100,
    prices_scrvusd_data['prev_staking_ratio']*100,
    showPercentChange=False,
    valuePostfix="%",
    changeFormatting=",.2f",
    customValueFormat=value
))


# crvusd peg
metric_name = make_metric_name_with_images([
    {'type': 'img_html', 'content': crvusd_image_link},
    {'type': 'text', 'content': 'crvUSD Peg'}
])
value = f"${prices_crvusd_peg['price']:.4f}"
crvusd_metrics.append(make_metric_html(
    metric_name,
    prices_crvusd_peg['price'],
    prices_crvusd_peg['prev_price'],
    showPercentChange=False,
    valuePrefix="$",
    changeFormatting=",.4f",
    customValueFormat=value
))

crvUSD_metrics_html = df_to_html(pd.DataFrame(crvusd_metrics), classes='curve-table')

display_curve_table(crvUSD_metrics_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Metric</th>
#       <th>Value</th>
#       <th>Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div class="metrics-name-cell"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD Supply</span></div></td>
#       <td>$77.9M</td>
#       <td><span class="negative-change">-0.73%</span></td>
#     </tr>
#     <tr>
#       <td><div class="metrics-name-cell"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0655977feb2f289a4ab78af67bab0d17aab84367.png' class="token-icon"><span>scrvUSD Yield</span></div></td>
#       <td>15.87% APY</td>
#       <td><span class="positive-change">+1.43%</span></td>
#     </tr>
#     <tr>
#       <td><div class="metrics-name-cell"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD in</span><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0x0655977feb2f289a4ab78af67bab0d17aab84367.png' class="token-icon"><span>scrvUSD</span></div></td>
#       <td>24.48%</td>
#       <td><span class="positive-change">+0.97%</span></td>
#     </tr>
#     <tr>
#       <td><div class="metrics-name-cell"><img src='https://raw.githubusercontent.com/curvefi/curve-assets/refs/heads/main/images/assets/0xf939e0a03fb07f59a73314e73794be0e57ac1b4e.png' class="token-icon"><span>crvUSD Peg</span></div></td>
#       <td>$0.9980</td>
#       <td><span class="negative-change">-$0.0001</span></td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
## crvUSD Loan Stats
crvusd_loan_metrics = []

# crvusd rate
metric_name = f"""Avg. Borrow Rate"""
value = f"{format_number(prices_crvusd_markets['all']['rate']*100, 4, 3)}%"
crvusd_loan_metrics.append(make_metric_html(
    metric_name,
    prices_crvusd_markets['all']['rate']*100,
    prices_crvusd_markets['all']['prev_rate']*100,
    showPercentChange=False,
    valuePostfix="%",
    customValueFormat=value,
))

# borrowed
crvusd_loan_metrics.append(make_metric_html('crvUSD Borrowed', prices_crvusd_markets['all']['total_debt'], prices_crvusd_markets['all']['prev_total_debt']))

# crvusd collateral
crvusd_loan_metrics.append(make_metric_html(
    'Collateral',
    prices_crvusd_markets['all']['collateral_amount_usd'],
    prices_crvusd_markets['all']['prev_collateral_amount_usd']
))

# total loans
crvusd_loan_metrics.append(make_metric_html(
    'Loans', 
    prices_crvusd_markets['all']['n_loans'], 
    prices_crvusd_markets['all']['prev_n_loans'],
    showPercentChange=False,
    changeFormatting=",.0f",
    customValueFormat=prices_crvusd_markets['all']['n_loans']
))

# total fees
crvusd_loan_metrics.append(make_metric_html(
    'Fees',
    prices_crvusd_markets['all']['fees'],
    prices_crvusd_markets['all']['prev_fees']
))

# Pegkeeper debt
metric_name = f"""Pegkeeper Debt"""
value = f"${format_number(pk_debt, 4, 3)}"
change = '-'
crvusd_loan_metrics.append({'Metric': metric_name, 'Value': value, 'Change': change})

crvusd_loan_metrics_html = df_to_html(pd.DataFrame(crvusd_loan_metrics), classes='curve-table')

display_curve_table(crvusd_loan_metrics_html, HTML_STYLING)
# Out:
#     <div class="gh-content gh-canvas">
#         <style>
#
# .negative-change {
#   color: red;
# }
#
# .metric-table td:first-child {
#     background-color: #F7F7F7;
# }
#
# .chain-column td:first-child {
#     width: 50px;
# }
#
# .crvusd-metric-column td:first-child {
#     min-width: 250px;
# }
#
# .pool-column td:nth-child(2) {
#     min-width: 150px;
# }
#
# .gh-content table.curve-table {
#     width: 100% !important;
#     max-width: 100% !important;
#     margin: 0 auto !important;
#     display: table !important;
# }
#
# .curve-table-container {
#     position: relative !important;
#     width: 100% !important;
#     overflow-x: auto !important;
#     -webkit-overflow-scrolling: touch !important;
#     margin-bottom: 1rem !important;
# }
#
# .curve-table {
#     border-collapse: collapse !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     margin-left: auto !important;
#     margin-right: auto !important;
#     vertical-align: middle;
# }
#
# .gh-content.gh-canvas {
#   scrollbar-width: none; /* Firefox */
#   -ms-overflow-style: none; /* IE and Edge */
# }
#
# .gh-content.gh-canvas::-webkit-scrollbar {
#   display: none; /* WebKit (Chrome/Safari) */
# }
#
# .curve-table .network-cell {
#   display: flex;
#   align-items: center;
#   gap: 8px;
#   width: fit-content;
#   margin: 0 auto;
#   vertical-align: middle;
# }
#
# .curve-table .metrics-name-cell {
#   display: flex;
#   align-items: left;
#   gap: 8px;
#   width: fit-content;
#   vertical-align: middle;
# }
#
# .curve-table .network-icon {
#   width: 24px;
#   height: 24px;
#   flex-shrink: 0;
# }
#
# .curve-table .pool-link {
#   text-decoration: none !important;
#   color: inherit;
#   display: block;
#   width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .pool-content {
#   display: flex;
#   flex-wrap: wrap;
#   gap: 8px;
#   width: fit-content;
#   max-width: 100%;
#   vertical-align: middle;
# }
#
# .curve-table .token-pill-pool {
#   background-color: #EEECEB;
# }
#
# .curve-table .token-pill-borrow {
#   background-color: #BBEDC0;
#
# }
#
# .curve-table .token-pill-collateral {
#   background-color: #DEDBD8;
# }
#
# .token-pill-pool, .token-pill.collateral, .token-pill-borrow{
#   font-weight: bold !important;
#   display: inline-flex;
#   flex: 0 0 auto;
#   align-items: center;
#   gap: 4px;
#   width: fit-content;
#   white-space: nowrap;
#   text-decoration: none !important;
#   padding: 4px 8px;
#   border-radius: 99999px;
# }
#
# .token-pill-pool:hover, .token-pill.collateral:hover, .token-pill-borrow:hover{
#   background-color: #DEDBD8 !important;
#   font-weight: bold !important;
#
# }
#
# .curve-table .token-icon {
#   width: 24px;
#   height: 24px;
#   border-radius: 50%;
#   flex-shrink: 0;
# }
#
# /* Scope the th and td styles to our specific table */
# .curve-table th,
# .curve-table td {
#   text-align: left;
#   padding: 8px;
#   border: 1px solid #e0e0e0;
#   vertical-align: middle;
# }
#
# a{
#   text-decoration: none;
# }
#
# a:hover{
# }
#
# thead{
#   background-color: #DEDBD8 !important;
#   text-align: left;
#   font-weight: bold !important;
# }
#
# th{
#   background-color: #DEDBD8 !important;
# }
#
# tr th:last-child{
#   text-align: right !important;
# }
#
# tr td:first-child{
#   font-weight: bold;
# }
# tr td:last-child{
#   font-weight: bold;
#   text-align: right !important;
# }
#
# .curve-table th {
#   font-weight: bold;
#   background-color: #f6f6f6;
# }
#
#
# .curve-table td a {
#     text-decoration: none !important;
#     color: inherit !important;
# }
#
# .curve-table td a:hover {
#      color: #1F1E1B !important;
# }
#
# .curve-table td .pool-content {
#   width: fit-content !important;
#   display: flex !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-pool {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-borrow {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
#
# .curve-table td .token-pill-collateral {
#   width: fit-content !important;
#   flex: 0 0 auto !important;
#   vertical-align: middle;
# }
# </style>
#         <div class='curve-table-container'><div class="curve-table-container"><table class="curve-table" class="dataframe curve-table">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Metric</th>
#       <th>Value</th>
#       <th>Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Avg. Borrow Rate</td>
#       <td>14.66%</td>
#       <td><span class="negative-change">-5.02%</span></td>
#     </tr>
#     <tr>
#       <td>crvUSD Borrowed</td>
#       <td>$77.4M</td>
#       <td><span class="negative-change">-1.35%</span></td>
#     </tr>
#     <tr>
#       <td>Collateral</td>
#       <td>$140.9M</td>
#       <td><span class="negative-change">-11.39%</span></td>
#     </tr>
#     <tr>
#       <td>Loans</td>
#       <td>642</td>
#       <td><span class="positive-change">+7</span></td>
#     </tr>
#     <tr>
#       <td>Fees</td>
#       <td>$188.7k</td>
#       <td><span class="negative-change">-32.04%</span></td>
#     </tr>
#     <tr>
#       <td>Pegkeeper Debt</td>
#       <td>$0</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table></div></div>
#     </div>

# %%
full_report_md = f"""## Market Overview

This weekly update highlights the most compelling opportunities across the Curve ecosystem.

> Risk Advisory: References to specific pools or Llamalend markets do not constitute endorsements of their safety. We strongly encourage conducting personal risk analysis before engaging with any pools or markets. Please review our detailed risk disclaimers: [Pool Risk Disclaimer](https://resources.curve.fi/risks-security/risks/pool/), [Llamalend Risk Disclaimer](https://resources.curve.fi/risks-security/risks/lending/), [crvUSD Risk Disclaimer](https://resources.curve.fi/risks-security/risks/crvusd/).

## Top Yields

*Note: for pools with less than $100k TVL, the yield has been calculated as if the pool has $100k TVL.*

### Top Performing Pools by Asset Class

{top_pool_yields_html}

### crvUSD & scrvUSD Yield Opportunities

{top_crvusd_yields_html}

## Ecosystem Metrics

*All changes (shown with + or -) represent the difference compared to values from one week ago.*

### crvUSD & scrvUSD Performance

{crvUSD_metrics_html}

### Pool Statistics

{pool_metrics_html}

### crvUSD Loan Metrics

{crvusd_loan_metrics_html}

### LlamaLend Performance

{lending_metrics_html}

## Notable Pool Activity

### Highest Volume Pools

{pool_highest_volume_html}

### Recently Launched Pools

{pool_biggest_new_pools_html}

### Highest Fee Generating Pools

{pool_biggest_fees_html}

### Most Profitable Pools

*Note: Minimum $100k TVL, profitability is measured by fees per $1 of liquidity*

{pool_most_profitable_html}

---

***Curve's ecosystem continues to expand rapidly, welcoming new teams and pools weekly. If you're interested in launching a pool, lending market, or simply want to connect with the community, join us on [Telegram](https://t.me/curvefi) or [Discord](https://discord.gg/twUngQYz85).**
"""

with open('weekly_report.md', 'w') as f:
    f.write(full_report_md)
    f.close()

with open('weekly_report_html_styling.css', 'w') as f:
    f.write(HTML_STYLING)
    f.close()
